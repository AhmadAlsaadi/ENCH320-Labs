# %% [markdown]
# # Lab 6: File I/O and Error Handling
#
# ## Learning Objectives
# By the end of this lab, you will be able to:
# - Read and write text files
# - Work with file paths
# - Handle errors using try-except blocks
# - Use different error types
# - Work with context managers (with statement)
# - Process file data
#
# ---
#
# ## 1. Reading Files
#
# ### Reading Entire File

# %%
# Reading entire file content
# First, let's create a sample file
with open('sample.txt', 'w') as f:
    f.write("Hello World!\n")
    f.write("This is line 2\n")
    f.write("This is line 3")

# Now read it
with open('sample.txt', 'r') as f:
    content = f.read()
    print("File content:")
    print(content)

# %% [markdown]
# ### Reading Line by Line

# %% [markdown]
# # Reading line by line
# with open('sample.txt', 'r') as f:
#     lines = f.readlines()
#     print("Using readlines():")
#     for i, line in enumerate(lines):
#         print(f"  Line {i+1}: {line.strip()}")

# %% [markdown]
# # Iterating through lines
# with open('sample.txt', 'r') as f:
#     print("Iterating through file:")
#     for line in f:
#         print(f"  {line.strip()}")

# %% [markdown]
# ## 2. Writing Files
#
# ### Creating and Writing to Files

# %% [markdown]
# # Writing to a new file (overwrites if exists)
# with open('output.txt', 'w') as f:
#     f.write("Line 1\n")
#     f.write("Line 2\n")
#     f.write("Line 3\n")
#
# print("File 'output.txt' created")
#
# # Read it back
# with open('output.txt', 'r') as f:
#     print("\nContent:")
#     print(f.read())

# %% [markdown]
# ### Appending to Files

# %% [markdown]
# # Appending to existing file (adds to end)
# with open('output.txt', 'a') as f:
#     f.write("Line 4\n")
#     f.write("Line 5\n")
#
# print("Lines appended")
#
# # Read it back
# with open('output.txt', 'r') as f:
#     print("\nUpdated content:")
#     print(f.read())

# %% [markdown]
# ## 3. Error Handling
#
# ### Basic try-except

# %% [markdown]
# # Basic try-except
# try:
#     number = int("not a number")
# except ValueError:
#     print("Error: That's not a valid integer!")
#
# print("Program continued")

# %% [markdown]
# ### Multiple Exceptions

# %% [markdown]
# # Handling multiple exceptions
# try:
#     file = open('nonexistent.txt', 'r')
#     data = file.read()
# except FileNotFoundError:
#     print("Error: File not found!")
# except IOError:
#     print("Error: Cannot read file!")

# %% [markdown]
# ### try-except-else-finally

# %% [markdown]
# # Complete try-except structure
# try:
#     with open('sample.txt', 'r') as f:
#         content = f.read()
#     print("File read successfully")
# except FileNotFoundError:
#     print("File not found")
# except IOError:
#     print("Error reading file")
# else:
#     print(f"Content length: {len(content)} characters")
# finally:
#     print("Cleanup (always executes)")

# %% [markdown]
# ## 4. Working with CSV Data

# %% [markdown]
# # Creating and reading CSV files
# with open('students.csv', 'w') as f:
#     f.write("Name,Age,Grade\n")
#     f.write("Alice,20,85\n")
#     f.write("Bob,21,90\n")
#     f.write("Charlie,20,78\n")
#
# print("CSV file created\n")
#
# # Reading CSV and processing
# with open('students.csv', 'r') as f:
#     header = f.readline().strip().split(',')
#     print(f"Header: {header}")
#     print("\nStudents:")
#     for line in f:
#         name, age, grade = line.strip().split(',')
#         print(f"  {name}: Age {age}, Grade {grade}")

# %% [markdown]
# ---
#
# ## Exercises
#
# ### Exercise 1: Write and Read a File
# 1. Create a file named "numbers.txt"
# 2. Write numbers 1-10, each on a new line
# 3. Read the file and print its content

# %% [markdown]
# # TODO: Exercise 1 - Write and read file

# %% [markdown]
# ### Exercise 2: Append to File
# 1. Append "11" and "12" to numbers.txt
# 2. Read and print the updated content

# %% [markdown]
# # TODO: Exercise 2 - Append to file

# %% [markdown]
# ### Exercise 3: Handle File Not Found
# Try to read a non-existent file and handle the FileNotFoundError gracefully

# %% [markdown]
# # TODO: Exercise 3 - Handle FileNotFoundError

# %% [markdown]
# ### Exercise 4: Count Lines in File
# Write a program that:
# 1. Reads a file
# 2. Counts total lines
# 3. Counts words in each line
# 4. Handles if file doesn't exist

# %% [markdown]
# # TODO: Exercise 4 - Count lines and words

# %% [markdown]
# ### Exercise 5: Type Conversion with Error Handling
# Read numbers from a file and:
# 1. Try to convert each line to an integer
# 2. Handle ValueError if conversion fails
# 3. Print converted numbers and errors

# %% [markdown]
# # TODO: Exercise 5 - Type conversion with error handling

# %% [markdown]
# ---
#
# ## Summary
#
# You've learned:
# - ✅ Reading files (read(), readlines(), iteration)
# - ✅ Writing and appending to files
# - ✅ Using context managers (with statement)
# - ✅ Handling errors with try-except
# - ✅ Multiple exception handling
# - ✅ try-except-else-finally structure
# - ✅ Processing CSV and text data
#
# **Next Lab**: Advanced Functions - Comprehensions and Higher-Order Functions

# %% [markdown]
# ---
#
# ## 🚀 Open in Google Colab
#
# Click the button below to run this notebook in Google Colab:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AhmadAlsaadi/ENCH320-Labs/blob/main/Notebook_06_File_IO_and_Errors.ipynb)

# %% [markdown]
# ---
#
# ## 🎓 Lab 6 Summary
#
# You have successfully learned:
# - ✅ **File Operations** - Reading and writing files
# - ✅ **File Modes** - Understanding open, read, write, and append modes
# - ✅ **Working with Data** - Processing file content
# - ✅ **Error Handling** - Using try-except blocks
# - ✅ **Exception Types** - Handling different kinds of errors
# - ✅ **Best Practices** - Writing robust file-handling code
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ---
#
# ## 🎓 ملخص Lab 6
#
# لقد تعلمت بنجاح:
# - ✅ **عمليات الملفات** - قراءة وكتابة الملفات
# - ✅ **أنماط الملفات** - فهم أنماط الفتح والقراءة والكتابة والإضافة
# - ✅ **العمل مع البيانات** - معالجة محتوى الملف
# - ✅ **معالجة الأخطاء** - استخدام كتل try-except
# - ✅ **أنواع الاستثناءات** - التعامل مع أنواع مختلفة من الأخطاء
# - ✅ **أفضل الممارسات** - كتابة رمز قوي للتعامل مع الملفات
#
# </div>
# </details>
