# %% [markdown]
# ## 📝 Important Instructions for Students
#
# ### Step 1: Make Your Own Copy
# When you open this notebook in Google Colab, you will be viewing a **read-only** version. To complete the assignments, you must:
#
# 1. Click **"File" → "Save a copy in Drive"** from the menu
# 2. This creates your personal copy in your Google Drive
# 3. Work on **your copy only** - all your answers will be saved there automatically
#
# ### Step 2: Rename Your Notebook
# After creating your copy, rename it to include your student ID:
#
# 1. Click on the notebook name at the top (currently "Copy of Lab_10_Numerical_Differentiation (1).ipynb")
# 2. Rename it to: **`Lab_10_Numerical_Differentiation_YourStudentID.ipynb`**
# 3. Example: `Lab_10_Numerical_Differentiation_12345678.ipynb`
#
# ### Step 3: Add Your Information right after these instructions
#
# ### Step 4: Share for Grading
# After completing all tasks, share your notebook with the instructor:
#
# 1. Click the **"Share"** button (top-right corner)
# 2. Enter instructor's email: **ahmad.alsaadi@kaust.edu.sa**
# 3. Set permission to **"Editor"**
# 4. Click **"Send"**
#
# **⚠️ Important:** Make sure to share **your copy** from Google Drive, not the original!
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## 📝 تعليمات مهمة للطلاب
#
# ### الخطوة 1: إنشاء نسخة خاصة بك
# عند فتح هذا الدفتر في Google Colab، ستشاهد نسخة **للقراءة فقط**. لإكمال المهام، يجب عليك:
#
# 1. انقر على **"File" ← "Save a copy in Drive"** من القائمة
# 2. سيتم إنشاء نسخة شخصية في Google Drive الخاص بك
# 3. اعمل على **نسختك فقط** - سيتم حفظ جميع إجاباتك تلقائياً
#
# ### الخطوة 2: إعادة تسمية الدفتر
# بعد إنشاء نسختك، قم بإعادة تسميتها لتتضمن رقم الطالب الخاص بك:
#
# 1. انقر على اسم الدفتر في الأعلى (حالياً "Copy of Lab_10_Numerical_Differentiation (1).ipynb")
# 2. أعد تسميته إلى: **`Lab_10_Numerical_Differentiation_رقم_الطالب.ipynb`**
# 3. مثال: `Lab_10_Numerical_Differentiation_12345678.ipynb`
#
# ### الخطوة 3: أضف معلوماتك مباشرة بعد هذه التعليمات
#
# ### الخطوة 4: المشاركة للتقييم
# بعد إكمال جميع المهام، شارك دفترك مع المدرس:
#
# 1. انقر على زر **"Share"** (في الزاوية العلوية اليمنى)
# 2. أدخل البريد الإلكتروني للمدرس: **ahmad.alsaadi@kaust.edu.sa**
# 3. اضبط الصلاحية على **"Editor"**
# 4. انقر على **"Send"**
#
# **⚠️ مهم:** تأكد من مشاركة **نسختك** من Google Drive، وليس النسخة الأصلية!
#
# </div>
#
# </details>

# %% [markdown]
# **Student Name:**
# **Student ID:**
# **Date:**

# %% [markdown]
# # Numerical Differentiation
#
# ---
#
# <details open>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# # التفاضل العددي
#
# </div>
# </details>

# %% [markdown]
# Numerical differentiation is a technique used to estimate the derivative of a function using discrete data points rather than an analytical expression. This method is particularly useful when the function is complex, not explicitly known, or when only sampled data is available.
#
# ---
#
# <details open>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# التفاضل العددي هو أسلوب يُستخدم لتقدير مشتقة الدالة باستخدام نقاط بيانات متقطعة بدلًا من الصيغة التحليلية المباشرة. وتكون هذه الطريقة مفيدة جدًا عندما تكون الدالة معقدة، أو غير معروفة بصيغة صريحة، أو عندما تكون البيانات المتاحة عبارة عن قيم مُعيَّنة (عينات) فقط.
#
# </div>
# </details>

# %% [markdown]
# ## What is Differentiation?
#
# ---
#
# <details open>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## ما هو التفاضل؟
#
# </div>
# </details>

# %% [markdown]
# Differentiation is the process of finding the derivative of a function, which represents the rate of change of the function with respect to its variable. For a function $f(x)$, the derivative $f'(x)$ is defined as:
# $$f'(x)=\lim_{h→0}\frac{f(x+h)-f(x)}{h}$$
#
# ---
#
# <details open>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# التفاضل هو عملية إيجاد مشتقة الدالة، والتي تمثل معدل تغيّر الدالة بالنسبة لمتغيرها. وبالنسبة للدالة $f(x)$، فإن المشتقة $f'(x)$ تُعرَّف كما يلي:
# $$f'(x)=\lim_{h→0}\frac{f(x+h)-f(x)}{h}$$
#
# </div>
# </details>

# %% [markdown]
# ## Basic Concepts
#
# ---
#
# <details open>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## المفاهيم الأساسية
#
# </div>
# </details>

# %% [markdown]
# The derivative at a point gives the slope of the tangent line to the function at that point. It can be interpreted both geometrically and physically (as the instantaneous rate of change).
#
# ---
#
# <details open>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# تعطي المشتقة عند نقطة معيّنة ميل المماس للدالة عند تلك النقطة. ويمكن تفسيرها هندسيًا وفيزيائيًا على أنها معدل التغيّر اللحظي.
#
# </div>
# </details>

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ---
#
# <details open>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ![image.png](attachment:image.png)
#
# </div>
# </details>

# %% [markdown]
# Numerical differentiation uses finite differences around a point rather than trying to find the limit near that point to approximate the derivative there. For small values of $h$:
# - **Forward Difference**:
# <center>
#
# ![image.png](attachment:image.png)
#
# </center>
#
# $$f'(x)≈\frac{f(x+h) -f(x)}{h}$$
#
# - **Backward Difference**:
#
# <center>
#
# ![image-2.png](attachment:image-2.png)
#
# </center>
#
# $$f'(x)≈\frac{f(x) -f(x-h)}{h}$$
#
# - **Central Difference**:
#
# <center>
#
# ![image-3.png](attachment:image-3.png)
#
# </center>
#
# $$f'(x)≈\frac{f(x+h) -f(x-h)}{2h}$$
#
# ---
#
# <details open>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# يستخدم التفاضل العددي فروقًا منتهية حول نقطة معيّنة بدلًا من حساب النهاية مباشرةً عند تلك النقطة، وذلك لتقريب المشتقة. وعند قيم صغيرة من $h$:
#
# - **الفرق الأمامي (Forward Difference)**:
# <center>
#
# ![image.png](attachment:image.png)
#
# </center>
#
# $$f'(x)≈\frac{f(x+h) -f(x)}{h}$$
#
# - **الفرق الخلفي (Backward Difference)**:
#
# <center>
#
# ![image-2.png](attachment:image-2.png)
#
# </center>
#
# $$f'(x)≈\frac{f(x) -f(x-h)}{h}$$
#
# - **الفرق المركزي (Central Difference)**:
#
# <center>
#
# ![image-3.png](attachment:image-3.png)
#
# </center>
#
# $$f'(x)≈\frac{f(x+h) -f(x-h)}{2h}$$
#
# </div>
# </details>

# %% [markdown]
# **Task 1**
# A. Write python function named `fdiff` that implement the forward difference which takes three parameters:
# - `f`: function that we need to approximate its derivative.
# - `p`: point that we want to find the derivative at.
# - `h`: step size.
#
# B. Test your function for finding the derivative of $f(x)=x^2+2$ at $x=1$?
# C. Compare your result with analytical solution to $f(x)=x^2+2$ at $x=1$?
# D. Test the effect of the step size $h$ on your function accuracy?
#
# ---
#
# <details open>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 1**
# A. اكتب دالة بايثون باسم `fdiff` تطبّق صيغة الفرق الأمامي، وتأخذ ثلاث معاملات:
# - `f`: الدالة المطلوب تقريب مشتقتها.
# - `p`: النقطة التي نريد إيجاد المشتقة عندها.
# - `h`: حجم الخطوة.
#
# B. اختبر دالتك لإيجاد مشتقة $f(x)=x^2+2$ عند $x=1$.
# C. قارن نتيجتك مع الحل التحليلي لمشتقة $f(x)=x^2+2$ عند $x=1$.
# D. اختبر تأثير حجم الخطوة $h$ على دقة الدالة.
#
# </div>
# </details>

# %%
## write your code below for part A

# %%
## write your code below for part B

# %%
## write your code below for part C

# %%
## write your code below for part D

# %% [markdown]
# **Task 2**
# Repeat task 1 for the backward difference formula.
#
# ---
#
# <details open>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 2**
# كرّر المهمة 1 باستخدام صيغة الفرق الخلفي (Backward Difference).
#
# </div>
# </details>

# %%
## write your code below for part A

# %%
## write your code below for part B

# %%
## write your code below for part C

# %%
## write your code below for part D

# %% [markdown]
# **Task 3**
# Repeat task 1 for the central difference formula.
#
# ---
#
# <details open>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 3**
# كرّر المهمة 1 باستخدام صيغة الفرق المركزي (Central Difference).
#
# </div>
# </details>

# %%
## write your code below for part A

# %%
## write your code below for part B

# %%
## write your code below for part C

# %%
## write your code below for part D

# %% [markdown]
# **Task 4**
# A. Use your function `cdiff` to approximate the derivative of $f(x)=\sin(x)$ at 100 points in the interval $[0,2\pi]$.
# **Hint**: use numpy array for `p` parameter.
#
# B. Prove that your approximate derivative obtained in part A lies on the curve $f(x)=\cos(x)$ by plotting your result in part A and $f(x)=\cos(x)$ on a single plot.
#
# ---
#
# <details open>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 4**
# A. استخدم دالتك `cdiff` لتقريب مشتقة $f(x)=\sin(x)$ عند 100 نقطة ضمن المجال $[0,2\pi]$.
# **تلميح**: استخدم مصفوفة `numpy` للمعامل `p`.
#
# B. أثبت أن المشتقة التقريبية الناتجة في الجزء A تقع على منحنى $f(x)=\cos(x)$، وذلك برسم نتيجة الجزء A مع الدالة $f(x)=\cos(x)$ في مخطط واحد.
#
# </div>
# </details>

# %%
## write your code below for part A

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# import numpy as np
# x=np.linspace(0,2*np.pi,100)
# cdiff(np.sin,x,0.01)
# ```
# </details>
#
# ---
#
# <details open>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <details>
# <summary>انقر للكشف عن الإجابة</summary>
#
# ```python
# import numpy as np
# x=np.linspace(0,2*np.pi,100)
# cdiff(np.sin,x,0.01)
# ```
# </details>
#
# </div>
# </details>

# %%
## write your code below for part B

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# x=np.linspace(0,2*np.pi,50)
# plt.plot(x,np.cos(x),color="r")
# plt.scatter(x,cdiff(np.sin,x,0.01))
# ```
# </details>
#
# ---
#
# <details open>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <details>
# <summary>انقر للكشف عن الإجابة</summary>
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# x=np.linspace(0,2*np.pi,50)
# plt.plot(x,np.cos(x),color="r")
# plt.scatter(x,cdiff(np.sin,x,0.01))
# ```
# </details>
#
# </div>
# </details>
