# %% [markdown]
# ## 📝 Important Instructions for Students
#
# ### Step 1: Make Your Own Copy
# When you open this notebook in Google Colab, you will be viewing a **read-only** version. To complete the assignments, you must:
#
# 1. Click **"File" → "Save a copy in Drive"** from the menu
# 2. This creates your personal copy in your Google Drive
# 3. Work on **your copy only** - all your answers will be saved there automatically
#
# ### Step 2: Rename Your Notebook
# After creating your copy, rename it to include your student ID:
#
# 1. Click on the notebook name at the top (currently "Copy of Lab_05_Data_Structures.ipynb")
# 2. Rename it to: **`Lab_05_Data_Structures_YourStudentID.ipynb`**
# 3. Example: `Lab_05_Data_Structures_12345678.ipynb`
#
# ### Step 3: Add Your Information right after these instructions
#
# ### Step 4: Share for Grading
# After completing all tasks, share your notebook with the instructor:
#
# 1. Click the **"Share"** button (top-right corner)
# 2. Enter instructor's email: **ahmad.alsaadi@kaust.edu.sa**
# 3. Set permission to **"Editor"**
# 4. Click **"Send"**
#
# **⚠️ Important:** Make sure to share **your copy** from Google Drive, not the original!
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## 📝 تعليمات مهمة للطلاب
#
# ### الخطوة 1: إنشاء نسخة خاصة بك
# عند فتح هذا الدفتر في Google Colab، ستشاهد نسخة **للقراءة فقط**. لإكمال المهام، يجب عليك:
#
# 1. انقر على **"File" ← "Save a copy in Drive"** من القائمة
# 2. سيتم إنشاء نسخة شخصية في Google Drive الخاص بك
# 3. اعمل على **نسختك فقط** - سيتم حفظ جميع إجاباتك تلقائياً
#
# ### الخطوة 2: إعادة تسمية الدفتر
# بعد إنشاء نسختك، قم بإعادة تسميتها لتتضمن رقم الطالب الخاص بك:
#
# 1. انقر على اسم الدفتر في الأعلى (حالياً "Copy of Lab_05_Data_Structures.ipynb")
# 2. أعد تسميته إلى: **`Lab_05_Data_Structures_رقم_الطالب.ipynb`**
# 3. مثال: `Lab_05_Data_Structures_12345678.ipynb`
#
# ### الخطوة 3: أضف معلوماتك مباشرة بعد هذه التعليمات
#
# ### الخطوة 4: المشاركة للتقييم
# بعد إكمال جميع المهام، شارك دفترك مع المدرس:
#
# 1. انقر على زر **"Share"** (في الزاوية العلوية اليمنى)
# 2. أدخل البريد الإلكتروني للمدرس: **ahmad.alsaadi@kaust.edu.sa**
# 3. اضبط الصلاحية على **"Editor"**
# 4. انقر على **"Send"**
#
# **⚠️ مهم:** تأكد من مشاركة **نسختك** من Google Drive، وليس النسخة الأصلية!
#
# </div>
#
# </details>

# %% [markdown]
# **Student Name:**
# **Student ID:**
# **Date:**

# %% [markdown]
# # Lab 05: Data Structures — Micro‑Learning Edition
#
# ## Learning Objectives
# By the end of this lab, you will be able to:
# - Create and manipulate lists
# - Use tuples for fixed sequences
# - Create and work with dictionaries
# - Use sets and their operations
# - Perform common operations: indexing, slicing, iteration
# - Choose the right data structure for different tasks
#
# **⏱️ Estimated time: 60–75 minutes**
#
# ---
#
# ## How this lab works
# Each micro‑lesson includes:
# 1. A short idea (2–4 minutes)
# 2. A tiny example
# 3. A Quick Check (predict the output)
# 4. A Try It task (edit/run code)
#
# ---
#
# ## Micro‑Lesson 1: Lists (Create)
# Lists are **ordered** and **mutable** collections.
#
# **Quick Check:** What type is `mixed`?
#
# **Try It:** Add a new item to `fruits`.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# # معمل 05: تراكيب البيانات — بأسلوب التعلم المصغّر
#
# ## أهداف التعلم
# بنهاية هذا المختبر، ستكون قادراً على:
# - إنشاء القوائم ومعالجتها
# - استخدام الـ tuples للتسلسلات الثابتة
# - إنشاء القواميس والعمل بها
# - استخدام المجموعات وعملياتها
# - تنفيذ عمليات شائعة: الفهرسة، الشرائح، التكرار
# - اختيار البنية المناسبة للمهام المختلفة
#
# **⏱️ الوقت المقدر: 60–75 دقيقة**
#
# ---
#
# ## كيف يعمل هذا المختبر
# كل درس مصغّر يحتوي على:
# 1. فكرة قصيرة (2–4 دقائق)
# 2. مثال صغير
# 3. تحقق سريع (توقع الناتج)
# 4. مهمة جرّبها (عدّل الكود وشغّله)
#
# ---
#
# ## الدرس المصغّر 1: القوائم (الإنشاء)
# القوائم **مرتبة** و**قابلة للتعديل**.
#
# **تحقق سريع:** ما نوع `mixed`؟
#
# **جرّبها:** أضف عنصراً جديداً إلى `fruits`.
#
# </div>
# </details>

# %%
# Creating empty lists
empty_list = []

# %%
# Creating lists of strings
fruits = ["apple", "banana", "cherry"]
fruits

# %%
# Creating lists of numbers
numbers = [1, 2, 3, 4, 5]
numbers

# %%
# Creating lists of mixed types
mixed = [1, "hello", 3.14, True]
mixed

# %% [markdown]
# ### Micro‑Lesson 1.1: Indexing and Slicing
# Access items by position (0‑based) and take slices.
#
# **Quick Check:** What is `fruits[-1]`?
#
# **Try It:** Slice the first two items.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### الدرس المصغّر 1.1: الفهرسة والشرائح
# الوصول للعناصر حسب الموقع (يبدأ من 0) وأخذ شرائح من القائمة.
#
# **تحقق سريع:** ما قيمة `fruits[-1]`؟
#
# **جرّبها:** خذ شريحة من أول عنصرين.
#
# </div>
# </details>

# %%
# Indexing (0-based)
fruits = ["apple", "banana", "cherry", "date", "elderberry"]

print(f"First fruit: {fruits[0]}")
print(f"Last fruit: {fruits[-1]}")
print(f"Second to last: {fruits[-2]}")

# Slicing
print(f"\nFirst three: {fruits[0:3]}")
print(f"From index 2 to end: {fruits[2:]}")
print(f"Every second fruit: {fruits[::2]}")
print(f"Reversed: {fruits[::-1]}")

# %% [markdown]
# ### Micro‑Lesson 1.2: List Methods
# Lists have built‑in methods for common tasks.
#
# **Quick Check:** What does `numbers.append(5)` do?
#
# **Try It:** Use `insert` to add a value at index 2.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### الدرس المصغّر 1.2: دوال القوائم
# القوائم تحتوي على دوال مدمجة لمهام شائعة.
#
# **تحقق سريع:** ماذا تفعل `numbers.append(5)`؟
#
# **جرّبها:** استخدم `insert` لإضافة قيمة عند الفهرس 2.
#
# </div>
# </details>

# %%
# List methods
numbers = [1, 2, 3, 2, 4]

print(f"Original list: {numbers}")
print(f"Length: {len(numbers)}")
print(f"Count of 2: {numbers.count(2)}")
print(f"Index of 3: {numbers.index(3)}")

# Modify list
numbers.append(5)
print(f"After append(5): {numbers}")

numbers.insert(0, 0)
print(f"After insert(0, 0): {numbers}")

numbers.remove(2)
print(f"After remove(2): {numbers}")

popped = numbers.pop()
print(f"After pop(): {numbers}, popped: {popped}")

numbers.sort()
print(f"After sort(): {numbers}")

# %% [markdown]
# ### Micro‑Lesson 1.3: List Iteration
# Loop through items (or index + item) using `for` and `enumerate`.
#
# **Quick Check:** What does `enumerate` return?
#
# **Try It:** Print items in uppercase.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### الدرس المصغّر 1.3: التكرار على القوائم
# كرّر على العناصر باستخدام `for` أو استخدم `enumerate` للحصول على الفهرس والعنصر.
#
# **تحقق سريع:** ماذا تعيد `enumerate`؟
#
# **جرّبها:** اطبع العناصر بحروف كبيرة.
#
# </div>
# </details>

# %%
# Iterating through lists
fruits = ["apple", "banana", "cherry"]

print("Simple iteration:")
for fruit in fruits:
    print(f"  - {fruit}")

print("\nWith enumerate (index and value):")
for index, fruit in enumerate(fruits):
    print(f"  {index}: {fruit}")

# %% [markdown]
# ---
#
# ## Micro‑Lesson 2: Tuples (Create)
# Tuples are **ordered** but **immutable** collections.
#
# **Quick Check:** Why does `(42,)` need a comma?
#
# **Try It:** Create a tuple with 2 colors.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## الدرس المصغّر 2: الـ Tuples (الإنشاء)
# الـ tuples **مرتبة** لكنها **غير قابلة للتعديل**.
#
# **تحقق سريع:** لماذا نحتاج فاصلة في `(42,)`؟
#
# **جرّبها:** أنشئ tuple يحتوي على لونين.
#
# </div>
# </details>

# %%
# Creating tuples
coordinates = (10, 20)
colors = ("red", "green", "blue")
mixed = (1, "hello", 3.14)
single = (42,)  # Comma needed for single-element tuple

print(f"Coordinates: {coordinates}")
print(f"Colors: {colors}")
print(f"Type of coordinates: {type(coordinates)}")

# Indexing and slicing work like lists
print(f"First coordinate: {coordinates[0]}")
print(f"Last color: {colors[-1]}")
print(f"First two colors: {colors[:2]}")

# %% [markdown]
# ### Micro‑Lesson 2.1: Tuple Unpacking
# Unpack values into variables in one line.
#
# **Quick Check:** After swapping, what are `a` and `b`?
#
# **Try It:** Unpack `(1, 2)` into `x, y`.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### الدرس المصغّر 2.1: فكّ القيم (Unpacking)
# فكّ القيم إلى متغيرات في سطر واحد.
#
# **تحقق سريع:** بعد التبديل، ما قيمتا `a` و `b`؟
#
# **جرّبها:** فكّ `(1, 2)` إلى `x, y`.
#
# </div>
# </details>

# %%
# Tuple unpacking
point = (5, 10)
x, y = point
print(f"Point: x={x}, y={y}")

# Swapping variables
a, b = 5, 10
print(f"Before swap: a={a}, b={b}")
a, b = b, a
print(f"After swap: a={a}, b={b}")

# %% [markdown]
# ### Micro‑Lesson 2.2: Immutability
# Tuples can’t be changed after creation.
#
# **Quick Check:** Why does `colors[0] = ...` fail?
#
# **Try It:** Use `count` and `index` on a tuple.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### الدرس المصغّر 2.2: عدم القابلية للتعديل
# لا يمكن تغيير الـ tuple بعد إنشائه.
#
# **تحقق سريع:** لماذا تفشل `colors[0] = ...`؟
#
# **جرّبها:** استخدم `count` و `index` على tuple.
#
# </div>
# </details>

# %%
# Tuples are immutable
colors = ("red", "green", "blue")

print(f"Original: {colors}")
print(f"Count of 'red': {colors.count('red')}")
print(f"Index of 'green': {colors.index('green')}")

# This would cause an error:
# colors[0] = "yellow"  # TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ---
#
# ## Micro‑Lesson 3: Dictionaries (Create)
# Dictionaries store **key → value** pairs.
#
# **Quick Check:** What type is `student`?
#
# **Try It:** Add a new key to `student`.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## الدرس المصغّر 3: القواميس (الإنشاء)
# القواميس تخزّن أزواج **مفتاح → قيمة**.
#
# **تحقق سريع:** ما نوع `student`؟
#
# **جرّبها:** أضف مفتاحاً جديداً إلى `student`.
#
# </div>
# </details>

# %%
# Creating dictionaries
student = {"name": "Alice", "age": 20, "gpa": 3.8}
phone_book = {"Alice": "555-1234", "Bob": "555-5678"}
empty_dict = {}

print(f"Student: {student}")
print(f"Phone book: {phone_book}")
print(f"Empty dict: {empty_dict}")

# %% [markdown]
# ### Micro‑Lesson 3.1: Access Values
# Use `dict[key]` or safer `get()`.
#
# **Quick Check:** What does `get('major', 'Not specified')` return?
#
# **Try It:** Access a key that doesn’t exist using `get()`.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### الدرس المصغّر 3.1: الوصول للقيم
# استخدم `dict[key]` أو `get()` بشكل آمن.
#
# **تحقق سريع:** ماذا تعيد `get('major', 'Not specified')`؟
#
# **جرّبها:** استخدم `get()` لمفتاح غير موجود.
#
# </div>
# </details>

# %%
# Accessing values
student = {"name": "Alice", "age": 20, "gpa": 3.8}

print(f"Name: {student['name']}")
print(f"Age: {student['age']}")

# Using get() method (safer)
major = student.get('major', 'Not specified')
print(f"Major: {major}")

# %% [markdown]
# ### Micro‑Lesson 3.2: Modify Dictionaries
# Add, update, delete, and `pop` key‑value pairs.
#
# **Quick Check:** What does `pop('age')` return?
#
# **Try It:** Add a new key, then delete it.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### الدرس المصغّر 3.2: تعديل القواميس
# أضف وحدّث واحذف الأزواج، واستخدم `pop`.
#
# **تحقق سريع:** ماذا تعيد `pop('age')`؟
#
# **جرّبها:** أضف مفتاحاً جديداً ثم احذفه.
#
# </div>
# </details>

# %%
# Adding and modifying key-value pairs
student = {"name": "Alice", "age": 20}

print(f"Original: {student}")

# Add new key
student['gpa'] = 3.8
print(f"After adding GPA: {student}")

# Modify existing key
student['age'] = 21
print(f"After updating age: {student}")

# Delete key-value pair
del student['gpa']
print(f"After deleting GPA: {student}")

# Pop (removes and returns value)
age = student.pop('age')
print(f"Popped age: {age}")
print(f"After pop: {student}")

# %% [markdown]
# ### Micro‑Lesson 3.3: Dictionary Iteration
# Iterate over keys or key‑value pairs with `.items()`.
#
# **Quick Check:** What does `student.keys()` return?
#
# **Try It:** Print only the values.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### الدرس المصغّر 3.3: التكرار على القواميس
# كرّر على المفاتيح أو أزواج المفتاح والقيمة باستخدام `.items()`.
#
# **تحقق سريع:** ماذا تعيد `student.keys()`؟
#
# **جرّبها:** اطبع القيم فقط.
#
# </div>
# </details>

# %%
# Iterating through dictionaries
student = {"name": "Alice", "age": 20, "gpa": 3.8}

print("Iterating through keys:")
for key in student:
    print(f"  {key}")

print("\nIterating through items:")
for key, value in student.items():
    print(f"  {key}: {value}")

print("\nKeys and values:")
print(f"  Keys: {student.keys()}")
print(f"  Values: {student.values()}")

# %% [markdown]
# ---
#
# ## Micro‑Lesson 4: Sets (Create)
# A set is like a dictionary **without values**: both use `{}` and enforce **unique keys/elements**, but a set stores only elements (no key:value pairs).
# A set is unlike a list: lists keep **order** and **duplicates**, while sets are **unordered** and **unique**.
# Elements must be hashable (numbers, strings, tuples), so no lists or dicts.
#
# **Quick Check:** Why does `numbers` lose duplicates?
#
# **Try It:** Add one new element to `colors`.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## الدرس المصغّر 4: المجموعات (الإنشاء)
# المجموعة تشبه القاموس **بدون قيم**: كلاهما يستخدم `{}` ويُطبّق **تفرد العناصر/المفاتيح**، لكن المجموعة تخزّن العناصر فقط (ولا تحتوي أزواج مفتاح:قيمة).
# المجموعة تختلف عن القائمة: القوائم تحفظ **الترتيب** و**التكرار**، بينما المجموعات **غير مرتبة** و**فريدة**.
# يجب أن تكون العناصر قابلة للتهشير (أرقام، نصوص، أو tuples)، لذلك لا تُستخدم القوائم أو القواميس.
#
# **تحقق سريع:** لماذا تختفي التكرارات من `numbers`؟
#
# **جرّبها:** أضف عنصراً جديداً إلى `colors`.
#
# </div>
# </details>

# %%
# Creating sets and comparing with dict/list
colors = {"red", "blue", "green"}
numbers = {1, 2, 3, 2, 1}  # Duplicates removed
empty_set = set()

print(f"Colors (set): {colors}")
print(f"Numbers (set): {numbers}")
print(f"Length (set): {len(numbers)}")

# Set vs dict: both use {}, dict has key:value pairs
dict_like = {"red": 1, "blue": 2}
set_like = {"red", "blue"}
print(f"Dict uses key:value: {dict_like}")
print(f"Set stores elements only: {set_like}")

# Set vs list: list keeps order and duplicates
list_like = [1, 2, 3, 2, 1]
print(f"List keeps duplicates: {list_like}")
print(f"Set removes duplicates: {set(list_like)}")

# Hashable elements only
valid = {(1, 2), "a"}
print(f"Valid set: {valid}")
try:
    bad = {[1, 2]}
except TypeError as exc:
    print(f"Unhashable error: {exc}")

# Empty set and membership
print(f"Empty set type: {type(empty_set).__name__}")
print(f"'red' in colors? {'red' in colors}")

# %% [markdown]
# ### Micro‑Lesson 4.1: Set Operations
# Use union, intersection, and difference.
#
# **Quick Check:** Which values are in `set_a & set_b`?
#
# **Try It:** Add a line to compute symmetric difference.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### الدرس المصغّر 4.1: عمليات المجموعات
# استخدم الاتحاد والتقاطع والفرق.
#
# **تحقق سريع:** ما العناصر الموجودة في `set_a & set_b`؟
#
# **جرّبها:** أضف سطراً لحساب الفرق المتماثل.
#
# </div>
# </details>

# %%
# Set operations
set_a = {1, 2, 3, 4}
set_b = {3, 4, 5, 6}

print(f"Set A: {set_a}")
print(f"Set B: {set_b}")

# Union (all elements)
print(f"Union: {set_a | set_b}")

# Intersection (common elements)
print(f"Intersection: {set_a & set_b}")

# Difference (in A but not in B)
print(f"Difference: {set_a - set_b}")

# %% [markdown]
# ### Micro‑Lesson 4.2: Set Methods
# Add, remove, and membership checks.
#
# **Quick Check:** What does `'apple' in fruits` return?
#
# **Try It:** Remove a different item.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### الدرس المصغّر 4.2: دوال المجموعات
# أضف واحذف وتحقق من وجود عنصر.
#
# **تحقق سريع:** ماذا تعيد `'apple' in fruits`؟
#
# **جرّبها:** احذف عنصراً مختلفاً.
#
# </div>
# </details>

# %% [markdown]
# ---
#
# ## ✅ Micro‑Exercises
# Complete each task in the code cell directly below it.
#
# **Tip:** Use the provided data to test your work.
#
# ### Exercise 1: List Operations
# Create a list of 5 numbers. Then:
# 1. Print the first and last elements
# 2. Add a new number at the end
# 3. Insert a number at the beginning
# 4. Remove the middle element
# 5. Print the final list
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## ✅ تمارين مصغّرة
# أكمل كل مهمة في خلية الكود التي تليها مباشرة.
#
# **نصيحة:** استخدم البيانات المرفقة للاختبار.
#
# ### التمرين 1: عمليات على القوائم
# أنشئ قائمة من 5 أرقام، ثم:
# 1. اطبع أول وآخر عنصر
# 2. أضف رقماً جديداً في النهاية
# 3. أدرج رقماً في البداية
# 4. احذف العنصر الأوسط
# 5. اطبع القائمة النهائية
#
# </div>
# </details>

# %%
# TODO: Exercise 1 - List operations
numbers = [10, 20, 30, 40, 50]

# Your code here

# %% [markdown]
# ### Exercise 2: Grade Analysis
# Create a list of grades. Find and print:
# 1. The highest grade
# 2. The lowest grade
# 3. The average grade
# 4. How many grades are above 80
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### التمرين 2: تحليل الدرجات
# أنشئ قائمة درجات، ثم احسب واطبع:
# 1. أعلى درجة
# 2. أقل درجة
# 3. متوسط الدرجات
# 4. عدد الدرجات الأعلى من 80
#
# </div>
# </details>

# %%
# TODO: Exercise 2 - Grade analysis
grades = [85, 92, 78, 90, 88, 76, 91]

# Your code here

# %% [markdown]
# ### Exercise 3: Tuple Unpacking
# Create a tuple with 3 elements (name, age, city).
# Unpack it into three variables and print them in a formatted way.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### التمرين 3: فكّ قيم الـ Tuple
# أنشئ tuple بثلاث قيم (الاسم، العمر، المدينة).
# فكّها إلى ثلاثة متغيرات واطبعها بصيغة منظمة.
#
# </div>
# </details>

# %%
# TODO: Exercise 3 - Tuple unpacking
person = ("Alice", 25, "New York")

# Your code here

# %% [markdown]
# ### Exercise 4: Dictionary Creation and Access
# Create a dictionary for a book with keys: title, author, year, pages.
# 1. Print each key‑value pair
# 2. Add a new key `rating` with value 4.5
# 3. Update the `year` value
# 4. Print the updated dictionary
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### التمرين 4: إنشاء قاموس والوصول إليه
# أنشئ قاموساً لكتاب بالمفاتيح: العنوان، المؤلف، السنة، الصفحات.
# 1. اطبع كل زوج مفتاح‑قيمة
# 2. أضف مفتاح `rating` بقيمة 4.5
# 3. حدّث قيمة `year`
# 4. اطبع القاموس بعد التحديث
#
# </div>
# </details>

# %%
# TODO: Exercise 4 - Book dictionary
book = {"title": "Python Basics", "author": "John Doe", "year": 2020, "pages": 300}

# Your code here

# %% [markdown]
# ### Exercise 5: Dictionary of Students
# Create a dictionary where keys are student names and values are their grades.
# 1. Print all student names
# 2. Print all grades
# 3. Find the student with the highest grade
# 4. Calculate the class average
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### التمرين 5: قاموس الطلاب
# أنشئ قاموساً تكون المفاتيح فيه أسماء الطلاب والقيم درجاتهم.
# 1. اطبع أسماء الطلاب
# 2. اطبع الدرجات
# 3. اعثر على الطالب صاحب أعلى درجة
# 4. احسب متوسط الصف
#
# </div>
# </details>

# %%
# TODO: Exercise 5 - Student grades dictionary
students = {"Alice": 92, "Bob": 85, "Charlie": 78, "Diana": 95}

# Your code here

# %% [markdown]
# ### Exercise 6: Set Operations
# Create two sets of numbers.
# 1. Find the union (all numbers from both sets)
# 2. Find the intersection (numbers in both sets)
# 3. Find the difference (numbers in first set but not second)
# 4. Check if a number is in either set
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### التمرين 6: عمليات المجموعات
# أنشئ مجموعتين من الأرقام.
# 1. احسب الاتحاد (كل الأرقام في المجموعتين)
# 2. احسب التقاطع (الأرقام المشتركة)
# 3. احسب الفرق (في المجموعة الأولى وليس الثانية)
# 4. تحقق إن كان رقم موجوداً في أي مجموعة
#
# </div>
# </details>

# %%
# TODO: Exercise 6 - Set operations
set_a = {1, 3, 5, 7, 9}
set_b = {3, 6, 9, 12}

# Your code here

# %% [markdown]
# ### Exercise 7: Remove Duplicates from List
# Given a list with duplicates, create a new list with only unique values.
#
# Example: [1, 2, 2, 3, 3, 3, 4] becomes [1, 2, 3, 4]
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### التمرين 7: إزالة التكرارات من القائمة
# لديك قائمة تحتوي على تكرارات. أنشئ قائمة جديدة بالقيم الفريدة فقط.
#
# مثال: [1, 2, 2, 3, 3, 3, 4] تصبح [1, 2, 3, 4]
#
# </div>
# </details>

# %%
# TODO: Exercise 7 - Remove duplicates
numbers = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]

# Your code here

# %% [markdown]
# ---
#
# ## ⭐ Challenge Problems
# Tackle these only after finishing the exercises.
#
# ### Challenge 1: Nested Structures
# Create a list of dictionaries representing students (name, age, grades as list).
# Calculate the average grade for each student.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## ⭐ مسائل التحدي
# ابدأ بها بعد إنهاء التمارين الأساسية.
#
# ### التحدي 1: تراكيب متداخلة
# أنشئ قائمة من القواميس تمثل الطلاب (الاسم، العمر، الدرجات كقائمة).
# احسب متوسط درجة كل طالب.
#
# </div>
# </details>

# %%
# TODO: Challenge 1 - Nested structures
students = [
    {"name": "Alice", "age": 20, "grades": [85, 90, 88]},
    {"name": "Bob", "age": 21, "grades": [78, 82, 80]}
]

# Your code here

# %% [markdown]
# ### Challenge 2: Word Frequency Counter
# Given a sentence, count how many times each word appears.
# Use a dictionary to store word counts.
#
# Example: "hello world hello python" → {"hello": 2, "world": 1, "python": 1}
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### التحدي 2: عدّ تكرار الكلمات
# أعطيت جملة، احسب عدد مرات ظهور كل كلمة.
# استخدم قاموساً لتخزين التكرارات.
#
# مثال: "hello world hello python" → {"hello": 2, "world": 1, "python": 1}
#
# </div>
# </details>

# %%
# TODO: Challenge 2 - Word frequency
text = "python python is great python is awesome"

# Your code here

# %% [markdown]
# ---
#
# ## 🎓 Lab 05 Summary
#
# You have successfully learned:
# - ✅ **Lists** — storing collections and manipulating them
# - ✅ **Tuples** — immutable sequences and unpacking
# - ✅ **Dictionaries** — key‑value data organization
# - ✅ **Sets** — unique, unordered collections
# - ✅ **Core Operations** — add, remove, access, iterate
# - ✅ **Choosing Structures** — pick the right tool for the task
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## 🎓 ملخص Lab 05
#
# لقد تعلمت بنجاح:
# - ✅ **القوائم** — تخزين المجموعات ومعالجتها
# - ✅ **الـ Tuples** — تسلسلات غير قابلة للتعديل وفكّ القيم
# - ✅ **القواميس** — تنظيم البيانات بأزواج مفتاح‑قيمة
# - ✅ **المجموعات** — مجموعات فريدة وغير مرتبة
# - ✅ **العمليات الأساسية** — إضافة، إزالة، وصول، تكرار
# - ✅ **اختيار البنية** — اختيار الأداة المناسبة للمهمة
#
# </div>
# </details>
