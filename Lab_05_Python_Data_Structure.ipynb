# %% [markdown]
# ## 📝 Important Instructions for Students
#
# ### Step 1: Make Your Own Copy
# When you open this notebook in Google Colab, you will be viewing a **read-only** version. To complete the assignments, you must:
#
# 1. Click **"File" → "Save a copy in Drive"** from the menu
# 2. This creates your personal copy in your Google Drive
# 3. Work on **your copy only** - all your answers will be saved there automatically
#
# ### Step 2: Rename Your Notebook
# After creating your copy, rename it to include your student ID:
#
# 1. Click on the notebook name at the top (currently "Copy of Lab_04_Functions.ipynb")
# 2. Rename it to: **`Lab_05_Python_Data_Structure.ipynb`**
# 3. Example: `Lab_05_Python_Data_Structure_12345678.ipynb`
#
# ### Step 3: Add Your Information right after these instructions
#
# ### Step 4: Share for Grading
# After completing all tasks, share your notebook with the instructor:
#
# 1. Click the **"Share"** button (top-right corner)
# 2. Enter instructor's email: **ahmad.alsaadi@kaust.edu.sa**
# 3. Set permission to **"Editor"**
# 4. Click **"Send"**
#
# **⚠️ Important:** Make sure to share **your copy** from Google Drive, not the original!
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## 📝 تعليمات مهمة للطلاب
#
# ### الخطوة 1: إنشاء نسخة خاصة بك
# عند فتح هذا الدفتر في Google Colab، ستشاهد نسخة **للقراءة فقط**. لإكمال المهام، يجب عليك:
#
# 1. انقر على **"File" ← "Save a copy in Drive"** من القائمة
# 2. سيتم إنشاء نسخة شخصية في Google Drive الخاص بك
# 3. اعمل على **نسختك فقط** - سيتم حفظ جميع إجاباتك تلقائياً
#
# ### الخطوة 2: إعادة تسمية الدفتر
# بعد إنشاء نسختك، قم بإعادة تسميتها لتتضمن رقم الطالب الخاص بك:
#
# 1. انقر على اسم الدفتر في الأعلى (حالياً "Copy of Lab_04_Functions.ipynb")
# 2. أعد تسميته إلى: **`Lab_05_Python_Data_Structure_رقم_الطالب.ipynb`**
# 3. مثال: `Lab_05_Python_Data_Structure_12345678.ipynb`
#
# ### الخطوة 3: أضف معلوماتك مباشرة بعد هذه التعليمات
#
# ### الخطوة 4: المشاركة للتقييم
# بعد إكمال جميع المهام، شارك دفترك مع المدرس:
#
# 1. انقر على زر **"Share"** (في الزاوية العلوية اليمنى)
# 2. أدخل البريد الإلكتروني للمدرس: **ahmad.alsaadi@kaust.edu.sa**
# 3. اضبط الصلاحية على **"Editor"**
# 4. انقر على **"Send"**
#
# **⚠️ مهم:** تأكد من مشاركة **نسختك** من Google Drive، وليس النسخة الأصلية!
#
# </div>
#
# </details>

# %% [markdown]
# # Lab 5: Python Data Structure

# %% [markdown]
# In the previous chapter, we learned how to handle basic data, where each item stands on its own. In this chapter, we broaden the idea by organizing those basic items into structured groups, so each group becomes a unit of data by itself.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# في الفصل السابق تعلمنا كيفية التعامل مع البيانات الأساسية وكان كل بيان من تلك البيانات يمثل معلومة مستقلة بذاتها. اما في هذا الفصل فسوف نوسع مفهوم البيانات الى نطاق أوسع بحيث يتم ترتيب هذه البيانات الأساسية بطريقة خاصة في مجموعات فتصبح هذه البيانات مستقلة بذاتها.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# ## Learning Objectives
# By the end of this chapter, you should be able to:
# - Identify data sturcture and its main types.
# - Work with the basic types of data structure.
# - Distinguish the basic types of data structure by understanding the properties of each type.
# - Expand your understanding of textual data and how to work with it.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## أهداف الفصل
# عند اتمام هذا الفصل يجب ان يكون لديك المام بالآتي:
# - التعرف على البيانات التجمعية وأنواعها الرئيسية.
# - معرفة التعامل مع الانواع الأساسية للبيانات التجميعية.
# - التمييز بين الانواع الأساسية للبيانات التجميعية من خلال معرفة خصائص كل نوع.
# - التوسع في معرفة البيانات النصية وكيفية التعامل معها.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# ## Definition of Data Structure

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## تعريف البيانات التحميعية
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# In Python, data structure refers to basic data (numeric, text, or boolean) grouped under a set of specific, defined properties, so they become independent units that Python handles in a special way. These collection data are divided into four main types:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# المقصود بالبيانات التجميعية في لغة بايثون هي بيانات أساسية (سواء كانت عددية او نصية او منطقية) اندرجت تحت مجموعة لها خصائص معينه ومحددة فأصبحت بيانات مستقلة بذاتها يتعامل معها مفسر بايثون بطريقة خاصة. وتنقسم هذه البيانات التجميعية الى أربعة أنواع رئيسية:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# - Lists
# - Tuples
# - Dictionaries
# - Sets

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# - القوائم (lists)
# - الصفوف (tuples)
# - القواميس (dictionaries)
# - المجموعات (sets)
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# ## Lists

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## القوائم Lists
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# Lists in Python are a collection of mixed data placed between square brackets and separated by commas, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# القوائم في لغة بايثون هي عبارة عن مجموعة من بيانات مختلطة توضع بين قوسين مربعين ويفصل بين كل بيان وآخر بفاصلة كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
data=['Ahmad', 2019, True, 23.5]

# %% [markdown]
# The term "mixed" here means lists can contain more than one data type. In the previous example, the list contained text, numeric, and boolean data. Lists are a temporary way to store data that makes it easier to work with when we want to process or analyze it.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# فالبيانات "المختلطة" في هذا التعريف تشير الى ان القوائم يمكن ان تحتوي على اكثر من نوع من البيانات فالقائمة في المثال السابق احتوت على بيانات نصية وبيانات عددية وبيانات منطقية. وتعتبر القوائم وسيلة مؤقتة لتخزين البيانات تهدف الى تسهيل التعامل مع البيانات متى ما اردنا معالجتها او تحليلها.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# ### Creating Lists

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### أنشاء القوائم
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# Besides the earlier method for creating the list `data`, there is another way using the `list()` function. For example, you can create a list from text using `list()` as shown in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# بالاضافة الى الطريقة التي السابقة التي اتبعناها في إنشاء القائمة data هناك طريقة اخرى تعتمد على استخدام الدالة ()list. فمثلا يمكن إنشاء قائمة من نص باستخدام الدالة ()list كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
list("hello python")
# Out:
# ['h', 'e', 'l', 'l', 'o', ' ', 'p', 'y', 't', 'h', 'o', 'n']

# %% [markdown]
# You can use the same function to create an empty list by calling `list()` with no value between the parentheses, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ويمكن استخدام الدالة ذاتها لانشاء قائمة فارغة وذلك بعدم اعطاء الدالة ()list اي قيمة بين قوسيها
#  كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
mylist=list()
mylist
# Out:
# []

# %% [markdown]
# You can also create an empty list more simply by using empty square brackets after the variable name, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كما يمكن انشاء قائمة فارغة بطريقة اسهل من الدالة السابقة وذلك باستخدام قوسين مربعين فارغين بعد اسم المتغير كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
mylist2=[]
mylist2
# Out:
# []

# %% [markdown]
# ### List Index

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### مؤشر القوئم List index
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# Positions in a list are identified by integers called list indices. They start at 0 from the left and increase by 1. In the previous `data` list, the first value has index 0, the second has index 1, and so on to the end, as shown in the following table.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# يتم الإشارة الى مكان البيانات في القائمة بارقام صحيحة تسمى مؤشر القائمة List Index تبدأ من اليسار بالقيمة صفر وتتزايد بالقيمة 1. فالقائمة data السابقة يشار الى القيمة الأولى فيها بالرقم 0 والقيمة الثانية بالرقم 1 وهكذا الى نهاية القيم في القائمة كما هو موضح في الجدول التالي.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# <table style="width:20%">
#
#   <tr>
#     <td border="0"><center>List Index</td>
#     <td><center>Value</td>
#   </tr>
#   <tr>
#     <td><center>0</td>
#     <td><center>"Ahmad</td>
#   </tr>
#   <tr>
#     <td><center>1</td>
#     <td><center>1990</td>
#   </tr>
#   <tr>
#     <td><center>2</td>
#     <td><center>True</td>
#   </tr>
#   <tr>
#     <td><center>3</td>
#     <td><center>23.5</td>
#   </tr>
#
# </table>

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <table style="width:20%">
#
#   <tr>
#     <td border="0"><center>مؤشر القائمة</td>
#     <td><center>القيمة</td>
#   </tr>
#   <tr>
#     <td><center>0</td>
#     <td><center>"Ahmad</td>
#   </tr>
#   <tr>
#     <td><center>1</td>
#     <td><center>1990</td>
#   </tr>
#   <tr>
#     <td><center>2</td>
#     <td><center>True</td>
#   </tr>
#   <tr>
#     <td><center>3</td>
#     <td><center>23.5</td>
#   </tr>
#
# </table>
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# To get a specific value from a list, write the list name followed by square brackets containing the index. For example, to get the first value in the previous `data` list, use:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# وللحصول على قيمة معينة من قائمة فإننا نقوم بكتابة اسم القائمة متبوعاً بقوسين مربعين يوضع بينهما رقم مؤشر القائمة. فعلى سبيل المثال عندما نريد القيمة الأولى من قائمة data السابقة فإننا نكتب الكود التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
data=['Ahmad', 2019, True, 23.5]
data[0]
# Out:
# 'Ahmad'

# %% [markdown]
# When we want the third value, for example, we write the following code:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# وعندما نريد القيمة الثالثة مثلاً فإننا نكتب الكود التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
data=['Ahmad', 2019, True, 23.5]
data[2]
# Out:
# True

# %% [markdown]
# You can also reference list values from right to left, meaning from the last value in the list. To do this, we use a list index that starts at -1 and decreases by 1, as shown in the following table:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كما يمكن الإشارة إلى القيم في قائمة من اليمين إلى اليسار أيضاً أي بمعنى آخر من آخر قيمة في القائمة. وللقيام بذلك نقوم باستخدم مؤشر قائمة يبدأ من القيمة 1- ويتناقص بالقيمة 1- كما هو موضح في الجدول التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# <table style="width:20%">
#
#   <tr>
#     <td border="0"><center>List Index</td>
#     <td><center>Value</td>
#   </tr>
#   <tr>
#     <td><center>-4</td>
#     <td><center>"Ahmad</td>
#   </tr>
#   <tr>
#     <td><center>-3</td>
#     <td><center>1990</td>
#   </tr>
#   <tr>
#     <td><center>-2</td>
#     <td><center>True</td>
#   </tr>
#   <tr>
#     <td><center>-1</td>
#     <td><center>23.5</td>
#   </tr>
#
# </table>

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <table style="width:20%">
#
#   <tr>
#     <td border="0"><center>مؤشر القائمة</td>
#     <td><center>القيمة</td>
#   </tr>
#   <tr>
#     <td><center>-4</td>
#     <td><center>"Ahmad</td>
#   </tr>
#   <tr>
#     <td><center>-3</td>
#     <td><center>1990</td>
#   </tr>
#   <tr>
#     <td><center>-2</td>
#     <td><center>True</td>
#   </tr>
#   <tr>
#     <td><center>-1</td>
#     <td><center>23.5</td>
#   </tr>
#
# </table>
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# To get the last value in the previous `data` list, write the following code:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
#  فللحصول على آخر قيمة في القائمة data السابقة نكتب الكود التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
data=['Ahmad', 2019, True, 23.5]
data[-1]
# Out:
# 23.5

# %% [markdown]
# To get the second-to-last value in a list, use index -2 inside the brackets, -3 for the next one, and so on.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# وللحصول على القيمة قبل الأخيرة في قائمة فإننا نستخدم المؤشر 2- داخل القوسين المربعين و 3- للقيمة التي بعدها وهكذا لباقي القيم في القائمة.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
data=['Ahmad', 2019, True, 23.5]
data[-2]
# Out:
# True

# %%
data=['Ahmad', 2019, True, 23.5]
data[-3]
# Out:
# 2019

# %% [markdown]
# ### List Operations

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### العمليات على القوائم
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# To add data to an empty list or a list that already has items, use `append()`. The added item is always placed at the end of the list, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لإضافة بيانات لقائمة قارغة أو قائمة تحتوي على بيانات سابقة يمكن استخدام الدالة  ()append
#  بحيث يكون البيان المضاف دائما في آخر القائمة كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
list1=[]
list1.append('Sunday')
list1.append('Monday')
list1.append('Tuesday')
list1
# Out:
# ['Sunday', 'Monday', 'Tuesday']

# %% [markdown]
# Notice the dot after the list name to call the method. It means: add the value "Sunday" to the list `list1`.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ استخدام النقطة بعد اسم القائمة لتنفيذ الدالة. فهي تعنى قم بإضافة القيمة "Sunday" مثلاً لللقائمة list1.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# We can also change values in a list using the assignment operator (=), as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كما يمكننا أن نغير قيم البيانات داخل قائمة باستخدام معامل الإسناد (=) كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
Ahmad=5
list2=[Ahmad,1990,True,23.5]
list2[0]="Omar"
list2
# Out:
# ['Omar', 1990, True, 23.5]

# %% [markdown]
# That is why lists in Python are called mutable, meaning they can be changed.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لذلك يطلق على القوائم في بايثون مصطلح mutable أي قابلة للتغيير.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# To find the index of an item in a list, use `index()` and place the item inside the parentheses, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ولمعرفة مؤشر بيان ما داخل قائمة فإننا نستخدم الدالة ()index بحيث نضع البيان المراد معرفة مؤشره داخل قوسي الدالة كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
list2=["Ahmad",1990,True,23.5]
list2.index(1990)

# %% [markdown]
# To find the number of items in a list, use `len()` as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ولمعرفة عدد البيانات في قائمة فإننا نستخدم الدالة ()len كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
list2=['Ahmad', 1990, 'Hello', True, 23.5]
len(list2)

# %% [markdown]
# In a previous example we used `append()` to add an item at the end of a list. If we want to add an item at a specific position, use `insert()`. Provide the index where the new item should go, then the value, as shown below:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# في مثال سابق تعلمنا كيف نضيف بيان الى قائمة باستخدام الامر ()append وعلمنا ان هذا الامر يقوم بإضافة البيان الى اخر القائمة. لكن ماذا لو أردنا ان نضيف بياناً في مكان معين من قائمة. لأداء هذه المهمة نستخدم الامر ()insert وكيفية استخدام هذا الامر يتطلب أولا ادخال مؤشر البيان داخل القائمة التي سوف يحتلها البيان المراد إدخاله ومن ثم قيمة البيان كما هو موضح في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
list2=['Ahmad', 1990, True, 23.5]
list2.insert(2,"Hello")
list2

# %% [markdown]
# To remove an item from a list, there are several methods. To remove the last item, use `pop()` as shown below:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ولإزالة بيان من قائمة فان هناك عدة دوال تساعدنا على القيام بذلك بطرق مختلفة. فعندما نريد إزالة اخر بيان في قائمة فإننا نستخدم الدالة ()pop كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
list2=['Ahmad', 1990, 'Hello', True, 23.5]
item_removed=list2.pop()
print(list2)
print(item_removed)
# Out:
# ['Ahmad', 1990, 'Hello', True]
# 23.5

# %% [markdown]
# Here `pop()` removed the last item and returned it, so we can assign the removed value to a variable as in the previous example. The deleted value was assigned to `item_removed`, which we printed in the last line.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# هنا الدالة ()pop قامت بحذف اخر بيان من القائمة وارجعت البيان الذي تم حذفه بحيث اصبح بإمكاننا اسناد ما تم حذفه الى متغير كما فعلنا في المثال السابق. فالقيمة التي تم حذفها تم اسنادها الى المتغير item_remove والذي قمنا بطباعة قيمته في اخر سطر من البرنامج السابق.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# You can also remove a specific element from a list using `remove()` by specifying the value to delete, as shown below:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# وكذلك يمكن إزالة عنصر معين من القائمة باستخدام الدالة ()remove وذلك بتحديد البيان المراد حذفه كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
list2=['Ahmad', 1990, 'Hello']
item_removed=list2.remove("Ahmad")
print(list2)
print(item_removed)
# Out:
# [1990, 'Hello']
# None

# %% [markdown]
# Notice that `remove()` does not return the removed item like `pop()`. The value `None` means `remove()` did not return anything; it only deleted the item.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ ان الدالة ()remove لم تقم بارجاع البيان الذي تم حذفه كما هو الحال مع الدلة ()pop. فالقيمة None تعنى ان الدالة ()remove لم تقم بارجاع اي شيئ وانما اكتفت فقط بحذف العنصر المراد حذفه من القائمة.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# You can also use the `del` statement to remove an item, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كما انه بالإمكان استخدام الامر del لإزالة البيان المراد كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
list2=['Ahmad', 1990, 'Hello', True, 23.5]
del list2[1]
list2
# Out:
# ['Ahmad', 'Hello', True, 23.5]

# %% [markdown]
# Finally, you can empty the entire list using `clear()` after the list name, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# وأخيرا يمكن افراغ القائمة من البيانات بالكامل باستخدام الدالة ()clear بعد اسم القائمة كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
list2=['Ahmad', 'Hello', True, 23.5]
list2.clear()
list2

# %% [markdown]
# Note that lists allow duplicate elements, meaning the same item can be stored more than once, as in the example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# يجب ملاحظة ان القائمة تسمح بتكرار العناصر بمعنى انه يمكن تخزين نفس البيان في قائمة اكثر من مرة كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
greatings=["hello","hello","hello"]
greatings

# %% [markdown]
# To find how many times an item is repeated in a list, use `count()` after specifying the item, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ولمعرفة عدد العناصر المكررة في قائمة نستخدم الدالة ()count بعد تحديد البيان المراد معرفة عدد مرات تكراره كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
greatings=['hello', 'hello', 'hello', 'Hi', 'Hi']
greatings.count("hello")

# %%
greatings=['hello', 'hello', 'hello', 'Hi', 'Hi']
greatings.count("Hi")

# %%
greatings=['hello', 'hello', 'hello', 'Hi', 'Hi']
greatings.count("bye")

# %% [markdown]
# Previously we used `append()` to add a single item to the end of a list. It can also add a whole list at the end, so the added list appears as a nested list inside the main list, as in the example below:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# في مثال سابق تعلمنا كيف نستخدم الدالة ()append لإضافة بيان واحد الى اخر القائمة. ولان نريد ان نوسع معرفتنا بهذه الدالة ونتعرف على ان هذه الدالة باستطاعتها إضافة قائمة الى اخر القائمة بحيث تظهر القائمة كقائمة جزئية داخل قائمة رئيسية كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
numbers=[1,2,3,4]
numbers.append(['a','b','c'])
numbers

# %% [markdown]
# Note that the main list is the one before `append()`, and the sublist is inside the parentheses. If we want to merge the sublist items into the main list so they become one list, we can use the `+` operator between the two lists, as shown below:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ ان القائمة الرئيسية هي القائمة التي تسبق ()append والقائمة الفرعية هي التي بداخل قوسي ()append. لكن ماذا لو أردنا ان ندمج عناصر القائمة الفرعية مع عناصر القائمة الرئيسية بحيث تصبح كأنها قائمة رئيسية واحدة. للقيام بذلك يمكننا استخدام علامة الجمع بين القائمتين كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
numbers=[1, 2, 3, 4]
list3=numbers+['a','b','c']
list3

# %%
numbers=[1, 2, 3, 4]
list3=['a','b','c']+numbers
list3

# %% [markdown]
# Notice that the order of items depends on how the two lists are combined.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ ان ترتيب البيانات يعتمد على الطريقة التي تمت بها عملية الجمع السابقة.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# We can also use `extend()` to do the same task by placing the sublist inside the parentheses, as in the example below:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كما يمكننا ان نستخدم الدالة ()extend لأداء نفس المهمة بحيث نضع القائمة الفرعية المراد دمجها داخل قوسي الدالة كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
numbers=[1,2,3,4]
numbers.extend(['a','b','c'])
numbers

# %% [markdown]
# You can multiply a list, and the result is:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# يمكن اجراء عملية ضرب على قائمة فتكون النتيجة كالتالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
[1,2,3]*4

# %% [markdown]
# Note that multiplication here simply repeats the items in the list.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ ان عملية الضرب هنا هي مجرد تكرار للبيانات داخل القائمة.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# You can reverse the order of items in a list using `reverse()` as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ويمكن عكس ترتيب البيانات في قائمة باستخدام الدالة ()reverse كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
numbers=[1, 2, 3, 4, 'a', 'b', 'c']
numbers.reverse()
numbers

# %% [markdown]
# To reorder items in a list, use `sort()`. It sorts in ascending order by default (alphabetical order for strings), as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ولإعادة ترتيب البيانات داخل قائمة فإننا نستخدم الدالة ()sort بحيث تقوم هذه الدالة بترتيب البيانات تصاعديا بشكل تلقائي على حسب ترتيب الحروف الابجدية   كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
cars = ['Ford', 'BMW', 'Volvo']
cars.sort()
cars

# %% [markdown]
# Or sort them in ascending order based on numeric values, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# او ترتيبها تصاعديا بحسب قيم الاعداد التي بداخلها كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
num=[1,89,3,8,24]
num.sort()
num
# Out:
# [1, 3, 8, 24, 89]

# %% [markdown]
# Notice that in the previous example the sorting happened in the original lists `cars` and `num`. To sort into a new list while keeping the original unchanged, use `sorted()` as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ ان في المثال السابق تم اعادة ترتيب البيانات على نفس القائمة الاصلية cars و num. ولاجراء عملية اعادة الترتيب في قائمة جديدة بحيث تبقى القائمة الاصلية كما هي نستخدم الدالة ()sorted كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
cars=["Ford","BMW","Volvo"]
print(sorted(cars))
print(cars)
# Out:
# ['BMW', 'Ford', 'Volvo']
# ['Ford', 'BMW', 'Volvo']

# %%
num=[1,89,3,8,24]
print(sorted(num))
print(num)
# Out:
# [1, 3, 8, 24, 89]
# [1, 89, 3, 8, 24]

# %% [markdown]
# To reverse the order so it is descending, use the `reverse=True` option inside the previous two functions, as in the following examples:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ولعكس الترتيب بحيث يكون تنازليا نستخدم الخيار reverse=True داخل قوسي الدالتين السابقتين كما في المثالين التاليين:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
cars = ['Ford', 'BMW', 'Volvo']
cars.sort(reverse=True)
cars

# %%
cars = ['Ford', 'BMW', 'Volvo']
cars2=sorted(cars,reverse=True)
cars2

# %% [markdown]
# You can also specify a custom sorting method, but that is a more advanced topic that we will not cover here.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ويمكن أيضا تحدد طريقة الترتيب بحسب الكيفية التي نرغب بها ولكن هذه الخاصية متقدمة قليلا ولا نستطيع الحديث عنها هنا الان.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# To check whether a specific item exists in a list, use `in` between the item and the list name. The expression means “is x in list y”, and the result is either `True` or `False`, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ولمعرفة ما اذا كان بيان معين موجود في قائمة فإننا نستخدم in بين البيان المراد البحث عنه واسم القائمة ليكون معنى التركيب اللغوي "هل البيان x موجود في القائمة y" فيكون ناتج العملية اما بصح True او خطأ False كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
colors=['green','red','blue']
'green' in colors

# %%
colors=['green','red','blue']
'yellow' in colors

# %% [markdown]
# To make a copy of a list, use `copy()` as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ولعمل نسخه من القائمة نستخدم الدالة ()copy كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
cars = ['Ford', 'BMW', 'Volvo']
cars2=cars.copy()
cars2

# %% [markdown]
# You might think copying with `copy()` is unnecessary because assigning a list to a new variable seems enough, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# قد يتبادر الى الاذهان ان عملية النسخ باستخدام الدالة ()copy غير ضرورية لان اجراء عملية اسناد قائمة لمتغير جديد سوف تفي بالغرض كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
cars = ['Ford', 'BMW', 'Volvo']
cars2=cars
cars2

# %% [markdown]
# But there is a key difference between `copy()` and assignment. Assignment does not create an independent list; any change to one variable affects the other list, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لكن في حقيقة الامر هناك اختلاف جوهري بين استخدام الدالة ()copy وعملية الاسناد. فعملية الاسناد لا تعني تكوين قائمة مستقلة عن القائمة الاولى. بل ان اجراء أي تغيير في أي متغير سوف يؤثر على القائمة الاخرى كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
cars = ['Ford', 'BMW', 'Volvo']
cars2=cars # عملية الاسناد الى متغير جديد
cars.append("GMC")
print(cars)
print(cars2)

# %% [markdown]
# Notice that when we add an item to `cars`, the same change appears in `cars2`. That is because there is only one list in memory, and assignment just creates another name that points to the same list, as shown in the figure:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ انه عند إضافة بيان الى القائمة cars تم احداث نفس التغيير في المتغير cars2 ايضاً. وذلك لأنه في حقيقة الامر لا يوجد قائمتين في ذاكرة الكمبيوتر أصلا. ان ذاكرة الكمبيوتر تحتفظ بقائمة واحدة فقط وعملية الاسناد قامت فقط بتكوين متغير يشير الى نفس القائمة كما في الشكل التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# <img src="https://github.com/AhmadAlsaadi/ENCH320-Labs/blob/main/img/ref.png?raw=1">

# %% [markdown]
# Using `copy()` creates an independent list in memory, as shown in the figure:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# اما عملية النسخ بالدالة ()copy فانها تقوم بإنشاء قائمة مستقلة عن القائمة الاولى في داكرة الكمبيوتر كما في الشكل التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# <img src="https://github.com/AhmadAlsaadi/ENCH320-Labs/blob/main/img/copy.png?raw=1">

# %% [markdown]
# Rewriting the previous example using `copy()` confirms this, as shown below:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# اعادة كتابة المثال السابق باستخدام الدالة ()copy يثبت صحة هذه المعلومة كما يلي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
cars = ['Ford', 'BMW', 'Volvo']
cars2=cars.copy() # عمل نسخة من القائمة
cars.append("GMC")
print(cars)
print(cars2)

# %% [markdown]
# Therefore, when you change the list copied with `copy()`, the change does not affect the original list, and vice versa, as shown in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لذلك عند اجراء تغيير على القائمة التي نسخت بالدالة ()copy فان هذا التغيير لا يؤثر على القائمة الاصلية والعكس صحيح اي ان التغيير في القائمة الاصلية بعد عملية النسخ لا يؤثر على القائمة المنسوخة كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
cars = ['Ford', 'BMW', 'Volvo']
cars2=cars.copy() # عملية النسخ
cars.append([1,2,3]) # عملية التغيير على القائمة الاصلية
print(cars)
print(cars2)

# %% [markdown]
# You can get the same copy behavior as `copy()` by using the list constructor `list()`, which we mentioned earlier, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ويمكن الحصول على نفس وظيفة النسخ بالدالة ()copy باستخدام دالة تعريف القائمة ()list التي ذكرناها في بداية الفصل كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
numbers=[1,2,3,4]
numbers2=list(numbers)
numbers2.pop()
print(numbers)
print(numbers2)

# %% [markdown]
# ### List Slicing

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### تجزئة القوائم
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# You can slice a list into smaller lists in different ways. For example, to take the first three items from ['a','b','c','d','e','f','g'], do the following:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ويمكن تجزئة قائمة (list slicing) الى قوائم أصغر بعدة طرق.  فمثلا اذا اردنا اخذ الثلاثة البيانات الاولى من القائمة <br>[ ‘a’ , ’b’ , ’c’ , ’d’ , ’e’ , ’f’’ , ’g’ ] فإننا نقوم بالتالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
letters=['a','b','c','d','e','f','g']
letters[0:3]

# %% [markdown]
# In the previous example, we used the start index, then a colon, then the index of the first item we do not want to include. The end index is exclusive. Here, the first wanted item is 'a' at index 0 and the first unwanted item is 'd' at index 3, so we got ['a','b','c']. You can get the same result by leaving the start index empty to begin from the list start, as shown below:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ما قمنا به في المثال السابق هو اننا استخدمنا مؤشر البيان الذي نريد ان تبتدأ به القائمة الجزئية داخل قوسين مربعين ثم وضعنا نقطتين فوق بعض (:) ثم وضعنا مؤشر آخر بيان لا نريد ان يكون في القائمة الجزئية. ففي المثال السابق اول بيان نريده في القائمة الجزئية هو ‘a’ ومؤشره 0 وآخر بيان لا نريده ان يكون في القائمة الجزئية هو ‘d’ ومؤشره هو 3 . لذلك حصلنا على القائمة الجزئية [ ‘a’ , ’b’ , ’c’ ] . ويكمن الحصول على نفس المهمة بترك مؤشر البيان الذي سوف تبتدأ به القائمة الجزئية فارغ لأن مفسر بايثون سوف يفترض انك تريد ان تبتدأ القائمة الجزئية من بداية القائمة الرئيسية كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
letters=['a','b','c','d','e','f','g']
letters[:3]

# %% [markdown]
# To get a sublist that starts at 'e' and goes to the end, provide the start index and leave the end index empty, because Python assumes you want the rest of the list, as shown below:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# وللحصول على قائمة جزئية تبتدأ مثلاً من الحرف ‘e’ وتنتهي بآخر بيان في القائمة السابقة نكتفي بتحديد مؤشر العدد الذي نريد ان تبتدأ به القائمة الجزئية ونترك المؤشر الاخر فارغ لأن مفسر بايثون يفترض انك تريد بقية البيانات في القائمة الرئيسية كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
letters=['a','b','c','d','e','f','g']
letters[4:]
# Out:
# ['e', 'f', 'g']

# %% [markdown]
# You can also unpack a list into regular variables, using one variable for each item in the list, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كما يمكن فك القائمة الى متغيرات اعتيادية باسخدام متغير واحد لكل بيان موجود في القائمة كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
numbers=[1,2,3]
a,b,c=numbers
print(a)
print(b)
print(c)

# %% [markdown]
# If you use fewer or more variables than the number of items in the list, Python raises an error stating that the number of values does not match the number of variables, as in the next two examples:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# في حال استخدامنا لمتغيرات اقل او اكثر من عدد البيانات الموجودة في القائمة فان مفسر بايثون يعطينا رسالة بوجود خطا في الكود البرمجي يفيد بأن عدد القيم في القائمة اكثر او اقل من عدد المتغيرات المعطى كما في المثاليين التاليين:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
numbers=[1,2,3]
a,b=numbers

# %%
numbers=[1,2]
a,b,c = numbers

# %% [markdown]
# You can avoid the previous unpacking errors by using an asterisk before the last variable, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# يمكن تلافي اخطاء الفك السابقة باستخدام علامة النجمة قبل المتغير الاخير كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
numbers=[1,2,3]
a,*b=numbers
print(a)
print(b)

# %% [markdown]
# Even though the list has more items than variables in the previous example, using the asterisk before `b` tells Python to assign the remaining items to `b`, so `b` becomes a list while `a` gets the first item.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# على الرغم من ان عدد البيانات في القائمة اكثر من عدد المتغيرات المعطاه في المثال السابق الا ان استخدام النجمة قبل المتغير b اعطى تعليمات لمفسر بايثون بان يسند كل ما تبقى من بيانات في القائمة للمتغير b فتكون لدينا قائمة مكونه عنصرين اسندت للتمتغير b بينما تم فك البيان الاول وتم اسناده للمتغير a.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# If the number of variables is greater than the number of items, using an asterisk on the extra variable tells Python to collect the remaining items there. If nothing remains, that variable becomes an empty list, as shown below:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# في الحالة التي يكون فيها عدد المتغيرات اكثر من عدد البيانات الموجودة في قائمة فان استخدام النجمة مع المتغير c يعطى تعليمات الى مفسر بايثون بان يضع كل ما تبقى من بيانات في هذا المتغير. وبما ان عمليه الفك لا تبقى شي للمتغير c فان مفسر بايثون سوف يسند للمغير c قائمة فارغة كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
numbers=[1,2]
a,b,*c=numbers
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# []

# %% [markdown]
# ### Exploratory Activities

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### أنشطة استكشافية
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# 1) Explore what `letters[:]` returns for the previous list.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ١-استكشف ماذا ينتج عن استخدام [:]letters للقائمة السابقة؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
letters=['a','b','c','d','e','f','g']
## اكتب الحل هنا

# %% [markdown]
# 2) Explore what `letters[2:-2]` returns for the previous list.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ٢- استكشف ماذا ينتج عن استخدام letters[2:-2] للقائمة السابقة؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
letters=['a','b','c','d','e','f','g']
## اكتب الحل هنا

# %% [markdown]
# 3) Explore what `letters[::]` returns for the previous list. Assign the result to `letters2`, and find out whether slicing changes the original list or creates an independent copy.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ٣-استكشف ماذا ينتج عن استخدام [::]letters للقائمة السابقة باسناد الناتج الى المتغير letters2 وتعرف على ما اذا كانت عملية التجزئة تقوم بعملية التغيير على نفس القائمة الاصلية ام انها تقوم بعمل نسخة مستقلة عنها؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
letters=['a','b','c','d','e','f','g']
## اكتب الحل هنا

# %% [markdown]
# Spacer (blank in Arabic source).

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# 4) Explore what `letters[::-1]` returns for the previous list. Try to recall which function we learned earlier performs the same task.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ٤-استكشف ماذا ينتج عن استخدام letters[::-1] للقائمة السابقة؟ حاول تتذكر أي دالة من الدوال التي تعلمناها سابقا تقوم بنفس المهمة؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
letters=['a','b','c','d','e','f','g']
## اكتب الحل هنا

# %% [markdown]
# 5) Explore what `letters[::1]` returns for the previous list.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ٥-استكشف ماذا ينتج عن استخدام letters[::1] للقائمة السابقة؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
letters=['a','b','c','d','e','f','g']
## اكتب الحل هنا

# %% [markdown]
# 6) Explore what `letters[::2]` returns for the previous list.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ٦-استكشف ماذا ينتج عن استخدام letters[::2] للقائمة السابقة؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
letters=['a','b','c','d','e','f','g']
## اكتب الحل هنا

# %% [markdown]
# 7) Explore how to unpack the `letters` list into three variables: the first variable holds the first value, the second variable holds all items except the last, and the third variable holds the last value.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 7-استكشف كيف يتم فك القائمة letters السابقة الى ثلاث متغيرات المتغير الاول يشير القيمة الاولى من القائمة والمتغير الثاني يشير الى كل عناصر القائمة ماعد القيمة الاخيرة والمتغير الثالث يشير الى آخر قيمة في القائمة ؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
letters=['a','b','c','d','e','f','g']
## اكتب الحل هنا

# %% [markdown]
# 8) Try using `dir()` with a list name inside the parentheses, and discover the methods available for that list.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 8-جرب استخدام الامر ()dir واضعا بين قوسيه اسما لقائمة و تعرف على الدوال التي يمكن استخدامها مع هذه القائمة؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
## اكتب الحل هنا

# %% [markdown]
# ## Tuples

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## الصفوف (tuples)
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# In Python, tuples are a collection of items that are immutable. They are written with parentheses, items separated by commas, and referenced by a single variable as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# الصفوف في لغة بايثون هي عبارة عن مجموعة من البيانات غير قابلة للتغيير توضع بين قوسين منحنيين يفصل بين كل بيان وآخر بفاصلة ويشار اليها بمتغير واحد كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
fruits=("banana","orange","apple")
numbers=(1,2,3,4)
values=(True,False,False,True)

# %% [markdown]
# Even if you do not write parentheses around comma-separated values, Python will still treat them as a tuple and display parentheses, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# حتى لو لم نكتب القوسين المنحنيين عند كتابتنا للبيانات التي تم فصلها عن بعض بفاصله فان مفسر بايثون سوف يفترض انك تريد كتابة صف من البيانات ويظهر لك النتيجة بقوسين منحنيين كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
colors='blue','red','orange'
colors

# %% [markdown]
# You can create a tuple from a list with `tuple()`, and a list from a tuple with `list()`, as in the following two examples:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ويمكن انشاء صف من قائمة باستخدام الدالة ()tuple و قائمة من صف باستخدام الدالة ()list كما في المثالين التاليين:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
colors=["red","yellow","blue"]
mytuple=tuple(colors)
type(mytuple)

# %%
numbers=(1,2,3,4)
mylist=list(numbers)
type(mylist)

# %% [markdown]
# Note that a single-item tuple must include a trailing comma, with or without parentheses, otherwise Python treats it as a normal variable, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كما يجب ملاحظة ان كتابة صف من بيان واحد لا يمكن القيام به الا بعد ان نضيف فاصلة بعد البيان سواء استخدمنا القوسين او لم نستخدمها وذلك لان مفسر بايثون سوف يعتقد ان المبرمج يريد تكوين متغير اعتيادي وليس صف كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
colors="blue"
numbers=(1)
print(type(colors))
print(type(numbers))

# %%
colors="blue",
numbers=(1,)
print(type(colors))
print(type(numbers))

# %% [markdown]
# To create an empty tuple, use the following:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# وللحصول على صف فارغ يمكننا ان نستخدم الطريقة التالية:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
houses=()

# %% [markdown]
# As with lists, you can access tuple items by index using square brackets after the tuple variable, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# وكما هو الحال في القوائم فان البيانات في الصفوف يتم الحصول عليها بتحديد مؤشر البيان داخل قوسين مربعين بعد اسم متغير الصف كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
fruits=("banana","orange","apple")
fruits[0]

# %%
fruits[2]

# %% [markdown]
# Tuple slicing works the same way as list slicing, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# وكذلك عملية تجزئة الصفوف تتم بنفس الطريقة التي تعلمناها في تجزئة القوائم كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
colors=('red','green','blue','yellow','orange')
colors[2:4]

# %%
colors[:4]

# %%
colors[:]

# %% [markdown]
# Tuple concatenation and repetition work the same way as with lists, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# وكذلك عملية الجمع والضرب بين صفين تتم بنفس الطريقة التي تعلمناها مع القوائم كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
colors=('red','green','blue','yellow','orange')
colors+(1,2,3)

# %%
letters=('a','b','c')
letters*3

# %% [markdown]
# Similar to lists, you can get the number of items in a tuple using `len()` as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# بشكل مشابه للقوائم يمكن معرفة عدد البيانات في صف باستخدام الدالة len() كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
colors=('red','green','blue','yellow','orange')
len(colors)

# %% [markdown]
# To ask whether an item exists in a tuple, use `in` the same way as with lists, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# وللسؤال عما إذا كان بيان ما موجود في صف فإننا نتبع نفس الطريقة المستخدمة مع القوائم باستخدام in كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
colors=('red','green','blue','yellow','orange')
'blue' in colors

# %%
'pink' in colors

# %% [markdown]
# From the above, you can see tuples are similar to lists, but the key difference is that tuple items cannot be changed. If we try to change one, Python raises an error indicating tuples are immutable, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# من خلال ماسبق لاحظت ان الصفوف تشبه القوائم بشكل كبير ولكن هناك فرق جوهري بين الاثنين وهو ان البيانات في الصفوف لا يمكن تغييرها ولو حاولنا ذلك نجد ان مفسر بايثون يعطينا رسالة بوجود خطأ مفاده ان الصفوف غير قابلة للتغيير immutable كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
fruits=("banana","orange","apple")
fruits[0]="grapes"

# %% [markdown]
# Tuple unpacking works the same way as list unpacking, as shown in the following examples:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# يتم التعامل مع فك الصفوف الى متغيرات بنفس الطريقة التى تعلمناها فيما يخص القوائم كما في الامثلة التالية:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
numbers=(1,2,3,4)
a,*b=numbers
print(a)
print(b)

# %%
numbers=(1,2)
a,b,*c=numbers
print(a)
print(b)
print(c)

# %%
numbers=(1,2,3,4,5,6)
a,*b,c=numbers
print(a)
print(b)
print(c)

# %% [markdown]
# ### Exploratory Activities

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### أنشطة استكشافية
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# 1) Try using a list method that changes data on a tuple, like `remove()` or `append()`. What do you notice, and why?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ١-حاول ان تستخدم احد الدوال التي استخدمناها مع القوائم لاحداث تغيير على صف كاستخدام الدالة ()remove او ()append مثلا ماذا تلاحظ ولماذا؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# 2) Try using non-mutating tuple methods like `count()` and `index()`. What do you notice?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ٢-حاول ان تستخدم الدوال التي لا تحدث تعديلا على بيانات الصف كالدالة ()count و الدالة ()index ماذا تلاحظ؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# 3) Try using `del` on a tuple. What do you notice?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ٣-جرب استخدام الامر del على صف ماذا تلاحظ؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# 4) Try using the `dir()` command with a tuple name inside the parentheses and see which methods can be used with tuples.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ٤-جرب استخدام الامر ()dir واضعا بين قوسيه اسما لصف و تعرف على الدوال التي يمكن استخدامها مع الصف؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## القواميس(dictionaries)
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# Dictionaries are a collection of data enclosed in curly braces and separated by commas. Each entry has two parts: the key and the value, separated by a colon, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# القواميس عبارة عن مجموعة من البيانات توضع بين قوسين متعرجين ويفصل بين كل بيان واخر بفاصلة بحيث يتكون كل بيان من جزأين. الجزء الاول يسمى المفتاح (key) والجزء الاخر يسمى القيمة (value) ويفصل بين المفتاح والقيمة بنقطتين فوق بعض كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# A key in a dictionary must be unique. If you try to create a dictionary with duplicate keys, the first value is overwritten and the last value remains, as in the following example:

# %%
info={'name':'Hassan','Age':22,'Job':'student'}

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# المفتاح في القاموس يجب ان يكون مميزا عن غيره من المفاتيح وإذا حاولنا كتابة قاموس يحتوي على مفتاحين متشابهين فان القيمة الاولى سوف يتم حذفها وتبقى القيمة الأخيرة داخل القاموس كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# Dictionary values can be repeated; Python does not mind duplicate values as long as the keys are different, as in the following example:

# %%
info={'name':'Ali','Age':22,'Job':'student','name':'Waleed'}
info

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# اما قيم القاموس فيمكن ان تتشابه ولا يعترض مفسر بايثون على تشابه القيم طالما المفاتيح مختلفة كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# Dictionary keys must be immutable data, such as strings, numbers, or tuples, but they cannot be lists, as in the following example:

# %%
example={1:'odd',2:'even',3:'odd'}
example

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# مفاتيح القاموس يجب ان تكون بيانات غير قابلة للتغير فيمكن ان تكون نصا او رقما او صفا ولكن لا يمكن ان تكون قائمة كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
keys_types={23:'number','Hello':'string',(1,2,3):'tuples'}
keys_types

# %%
list_dict={[1,2]:'list'}

# %% [markdown]
# Notice that when we used a list as a dictionary key, Python raised a `TypeError` indicating an invalid data type. You can create an empty dictionary in either of the following ways:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ انه عندما استخدمنا القائمة كمفتاح في القاموس اظهر لنا مفسر بايثون رسالة بوجود خطأ من النوع TypeError والذي يفيد بوجود خطأ في نوعية البيانات المستخدمة.
# ويمكن كتابة قاموس فارغ بإحدى الطريقتين التاليتين:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
info={}

# %%
info2=dict()

# %% [markdown]
# You can get the value of a key in a dictionary using square brackets after the dictionary name with the key inside, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ويمكن الحصول على قيمة لمفتاح ما في قاموس باستخدام قوسين مربعين توضع بعد اسم القاموس ويكتب داخلها اسم المفتاح كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
info={'name':'Ahmad','Age':22,'Job':'student'}
info['Age']

# %%
info["name"]

# %% [markdown]
# If you use the previous syntax for a key that does not exist, Python raises a `KeyError`, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# وعند استخدام التركيب اللغوي السابق للحصول على قيمة مفتاح غير موجود في القاموس فان محرر بايثون يعطينا رسالة بوجود خطأ من النوع KeyError كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
info={'name':'Ahmad','Age':22,'Job':'student'}
info['birth_date']

# %% [markdown]
# You can use the `get()` method to retrieve the value of a key in a dictionary, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ويمكن استخدام الدالة ()get للحصول على قيمة مفتاح في قاموس كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
info={'name':'Ahmad','Age':22,'Job':'student'}
info.get('name')

# %% [markdown]
# The difference between using square brackets and `get()` is that `get()` does not raise an error when the key does not exist, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# الفرق بين استخدام القوسين المربعين واستخدام الدالة ()get في الحصول على قيمة مفتاح في قاموس هو ان الدالة ()get لا تعطينا رسالة بوجود خطأ عندما يكون المفتاح غير موجود في القاموس كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
info={'name':'Ahmad','Age':22,'Job':'student'}
info.get('birth_date')

# %% [markdown]
# Dictionaries, like lists, can be modified. For example, to change the value of the `Age` key in the previous dictionary, do the following:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# القواميس مثل القوائم يمكن تعديل البيانات الموجودة بداخلها فمثلا إذا أردنا تعديل قيمة المفتاح “Age” في القاموس السابق فإننا نقوم بالآتي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
info={'name':'Ahmad','Age':22,'Job':'student'}
info['Age']=40
info

# %% [markdown]
# You can also add new data to a dictionary as follows:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كما يمكن إضافة بيانات جديدة الى قاموس بالطريقة التالية:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
info={'name':'Ahmad','Age':22,'Job':'student'}
info['car']='Ford'
info

# %% [markdown]
# To find the number of entries in a dictionary, use `len()` as we did for lists and tuples:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لمعرفة عدد البيانات في قاموس فاننا نستخدم الدالة ()len كما فعلنا في القوائم والصفوف:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
info={'name':'Ahmad','Age':22,'Job':'student'}
len(info)

# %% [markdown]
# To check whether a key exists in a dictionary, use `in` as we learned earlier with lists and tuples:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ولمعرفة ما اذا كان هناك بيان ما موجود في قاموس فاننا نستخدم in كما تعلمنا سابقا في القوائم والصفوف:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
info={'name':'Ahmad','Age':22,'Job':'student'}
'Age' in info

# %%
'car' in info

# %% [markdown]
# To delete an entry from a dictionary, use `del` as we did with lists:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لحذف بيان من قاموس فإننا نستخدم الامر del كما فعلنا في القوائم:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
info={'name':'Ahmad','Age':22,'Job':'student'}
del info['Job']

# %% [markdown]
# You can also use `pop()` to do the same task and return the removed value so you can store it in a variable, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كما يمكن استخدام الدالة ()pop لاداء نفس المهمة مع امكانية ارجاع قيمة المفتاح المحذوف واضافته لمتغير لاستخدامه في عمليات اخرى كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
info={'name':'Ahmad','Age':22,'Job':'student'}
removed_item=info.pop("name")
print(info)

# %%
removed_item

# %% [markdown]
# You can also use `popitem()` to delete the last added entry in a dictionary and return its key and value for reuse, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كما يمكن استخدام الدالة ()popitem لحذف اخر بيان تم اضافته للقاموس مع امكانية ارجاع المفتاح المحذوف وقيمته لاستخدامهما في عمليات اخرى كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
info={'name':'Ahmad','Age':22,'Job':'student'}
removed_item=info.popitem()
print(info)
print(removed_item)

# %% [markdown]
# To clear all data from a dictionary, use `clear()` as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ولتفريغ القاموس من البيانات بالكامل نستخدم الدالة ()clear كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
info={'name':'Ahmad','Age':22}
info.clear()
info

# %% [markdown]
# To list all keys in a dictionary, use `keys()` as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ولمعرفة كافة المفاتيح في قاموس ما نستخدم الدالة ()keys كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
info={'name': 'Ahmad', 'Age': 22, 'Job': 'student'}
info.keys()

# %% [markdown]
# To list all values in a dictionary, use `values()` as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ولمعرفة كافة القيم في القاموس نستخدم الدالة ()values كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
info={'name': 'Ahmad', 'Age': 22, 'Job': 'student'}
info.values()

# %% [markdown]
# To merge two dictionaries, use `update()` as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ولدمج بيانات قاموسين نستخدم الدالة ()update كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
info={'name': 'Ahmad', 'Age': 22, 'Job': 'student'}
info2={'title':'Mr','phone':'00000'}
info.update(info2)
info

# %% [markdown]
# Notice that the dictionary before the method is the base dictionary, and the dictionary inside the parentheses is the one whose data is merged. You can also nest a sub-dictionary inside a main dictionary like this:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ ان القاموس الذي يسبق الدالة هو القاموس الأساسي والقاموس الذي بداخل قوسي الدالة هو القاموس الذي تم دمج البيانات منه. يجب ملاحظ ان بالإمكان وضع قاموس فرعي داخل قاموس رئيسي كما يلي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
info={'name': 'Ahmad', 'Age': 22, 'Job': 'student'}
info2={'title':'Mr','phone':'00000'}
info['more_data']=info2
info

# %% [markdown]
# In the previous example, the sub-dictionary was added using a new key named `more_data`, as we learned earlier about adding new entries to a dictionary.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# في المثال السابق تم إضافة القاموس الفرعي باستخدام مفتاح جديد اسميناه more_data كما تعلمنا سابقا عن كيفية إضافة بيان جديد الى قاموس.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# You can use `items()` to display all entries in a dictionary; each entry appears as a tuple of key and value, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ويمكن استخدام الدالة ()items لعرض جميع البيانات في قاموس كقائمة كل بيان يظهر كصف مكون من مفتاح وقيمة كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
info={'name': 'Ahmad', 'Age': 22, 'Job': 'student'}
info.items()

# %% [markdown]
# Everything we learned about copying lists also applies to dictionaries, as shown in the next two examples:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كل ما ينطبق على القوائم من عمليات النسخ يمكن تطبيقة على القواميس كما في المثالين التاليين:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
cars={"name":"Ford", "model":2015, "color":"white"}
cars2=cars
cars2["milage"]=100000
print(cars)
print(cars2)

# %%
cars={"name":"Ford", "model":2015, "color":"white"}
cars2=cars.copy()
cars2["milage"]=100000
print(cars)
print(cars2)

# %%
cars={"name":"Ford", "model":2015, "color":"white"}
cars2=dict(cars)
cars2["milage"]=100000
print(cars)
print(cars2)

# %% [markdown]
# ### Exploratory Activities

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### تمارين استكشافية
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# 1) Explore whether the multiplication and addition operations we used with lists can be used with dictionaries.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ١- استكشف ماذا كان عمليات الضرب والجمع التي قمنا بها مع القوائم يمكن استخدامها مع القواميس؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# 2) Try using the `dir()` command with a dictionary name inside the parentheses and see which methods can be used with dictionaries.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ٢-جرب استخدام الامر ()dir واضعا بين قوسيه اسما لقاموس و تعرف على الدوال التي يمكن استخدامها مع القاموس؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# 3) Explore how the `popitem()` method works on a dictionary.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ٣- استكشف الية عمل الدالة ()popitem على القاموس؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# 4) Use the `help()` function with a dictionary method name to learn how it works. Hint: write `dict_name.method` without parentheses inside `help()`.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ٤- استخدم الدالة ()help واضعاً بين قوسيها اسما لدالة تعمل عملا ما على القاموس محاولاً معرفة كيفية عمل تلك الدالة؟ تلميح: يجب كتابة اسم قاموس مفصولا بنقطة بينه وبين الدالة المراد معرفة معلومات عنها بدون كتابة قوسيها داخل قوسي الدالة ()help.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# ## Sets

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## المجموعات (sets)
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# Sets in Python are collections of non-repeating data enclosed in curly braces `{}` and separated by commas, referenced by a single variable, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# المجموعات في لغة بايثون هي عبارة عن تجمع لبيانات غير قابلة للتكرار توضع بين قوسين متعرجين {} يفصل بين كل بيان واخر بفاصلة ويشار اليها بمتغير واحد كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
numbers={1,2,3,4,1,3}
print(numbers)
{1, 2, 3, 4}

# %% [markdown]
# Notice in the previous example that we tried to create a set with repeated items, but Python removed the duplicates because sets do not allow repeated values. Also notice the similarity between sets and dictionaries in their braces; the difference is that dictionaries store key-value pairs separated by a colon, while sets store plain values.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ في المثال السابق اننا حاولنا تكوين مجموعة بيانات متكررة لكن محرر بايثون حذف البيانات المتكررة من المجموعة لان المجموعات في بايثون لا تسمح بتكرار البيانات المتشابهة. لاحظ أيضا التشابه بين المجموعات والقواميس من حيث الاقواس. الاختلاف بين القواميس والمجموعات يكمن في طريقة كتابة البيانات فالقواميس كل بيان يتكون من مفتاح وقيمة مفصولين بنقطتين فوق بعض اما المجموعات فهي بيانات اعتيادية.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# You can create a set either using the braces as before or by using `set()` and passing a list of items, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ويمكن انشاء مجموعة اما بالطريقة التي استخدمناها في المثال السابق او باستخدام الدالة set() وإدخال قائمة من البيانات داخل قوسي الدالة كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
letters=set(['a','b','c'])
letters

# %% [markdown]
# If you want to create an empty set, you cannot use empty curly braces because that syntax is reserved for dictionaries. Instead, use `set()` with no arguments, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# واذا اردنا ان ننشئ مجموعة فارغة فإننا لا نستطيع ان نستخدم قوسين فارغين لأن هذا التركيب اللغوي محجوز للقواميس ولكن بوسعنا ان نستخدم الدالة set() بدون ان ندخل أي شيء بين قوسيها كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
numbers={}   #استخدام القوسين المتعرجين محجوز للقواميس
type(numbers)

# %%
letters=set()
letters

# %% [markdown]
# To add an item to an empty set or an existing set, use `add()` as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ولإضافة بيان الي مجموعة فارغة او مجموعة محتوية على بيانات سابقة نستخدم الدالة ()add كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
letters=set()
letters.add('Ahmad')
letters.add('Waleed')
letters

# %% [markdown]
# Notice that the order of items in a set does not necessarily match the insertion order, because sets do not use indexing. If you try to index a set, Python raises an error, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ ان ترتيب البيانات في المجموعات ليس بالضرورة ان يكون بنفس الترتيب الذي ادخلنا فيه البيانات وذلك لان المجموعات لا تستخدم مؤشر البيانات للإشارة الى البيانات بداخلها واذا حاولنا القيام بذلك فان مفسر بايثون سوف يظهر لنا رسالة تفيد بان المجموعات لا تستخدم مؤشر البيانات كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
letters={'Hassan', 'Ahmad', 'Waleed'}
letters[1]

# %% [markdown]
# To add one set into another, use `update()` as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ولاضافة مجموعة الى مجموعة اخرى نستخدم الدالة ()update كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
set_A={1,2,3,4}
set_B={1,2,5,7}
set_A.update(set_B)
print(set_A)

# %% [markdown]
# Notice that order matters in the previous example: `update()` adds items from `set_B` into `set_A` only if they are not already present.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ ان عملية الترتيب في المثال السابق مهمة فالدالة ()update تضيف بيانات المجموعة set_B الى بيانات المجموعة set_A اذا كانت غير موجودة مسبقا فيها.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# To delete an item from a set, there are several options. You can use `remove()` as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ولحذف بيان من مجموعة هناك عدة خيارات لاداء هذه المهمة. فيمكن استخدم الدالة  ()remove كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
letters={'Hassan', 'Ahmad', 'Waleed'}
letters.remove('Ahmad')
letters

# %% [markdown]
# You can also use `discard()` to remove an item from a set, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ويمكن ايضا استخدام الدالة ()discard لحذف بيان من مجموعة كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
letters={2, (3, 4), 'Hassan', 'Waleed'}
letters.discard(2)
letters

# %% [markdown]
# The difference between `remove()` and `discard()` is that `discard()` does not raise an error when the item is missing, while `remove()` raises a `KeyError` if the item does not exist, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# الفرق بين استخدام الدالة ()remove والدالة ()discard هو ان الدالة ()discard لا تعطينا رسالة بوجود خطأ عندما نطلب حذف بيان ليس موجود داخل مجموعة اما الدالة ()remove فسوف تظهر لنا رسالة خطأ KeyError عند عندم وجود البيان داخل المجموعة كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
letters={(3, 4), 'Hassan', 'Waleed'}
letters.discard('Ahmad')  # لم تظهر لنا أي رسالة رغم ان البيان غير موجود

# %%
letters.remove('Ahmad')

# %% [markdown]
# You can also use `pop()` to remove a random item from a set, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كما يمكن أيضا استخدام الدالة ()pop لحذف بيان عشوائي من مجموعة كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
letters={(3, 4), 'Hassan', 'Waleed'}
letters.pop()

# %% [markdown]
# Notice that the removed item is not necessarily the last one, as it would be in lists; it is chosen randomly, as in the previous example.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ ان البيان الذي يتم حذفه ليس بالضرورة ان يكون في اخر المجموعة كما هو الحال في القوائم وانما يتم اختياره بشكل عشوائي كما حصل في المثال السابق حيث تم حذف بيان من وسط المجموعة وليس من اخرها.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# You can also use `clear()` to remove all items from a set, just as we did with lists and tuples, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كما يمكن استخدام الدالة ()clear كما فعلنا بالقوائم والصفوف لحذف جميع البيانات من مجموعة كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
letters={'Hassan', 'Waleed'}
letters.clear()
letters

# %% [markdown]
# We mentioned that we can add or delete items from a set, but we cannot reassign items inside a set like we do with lists. Therefore, items in a set must be immutable, such as strings, tuples, and numbers. If you try to add a mutable item like a list, Python raises an error, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ذكرنا سابقا اننا نستطيع إضافة بيان الى مجموعة وكذلك باستطاعتنا حذفه لكن ليس باستطاعتنا إعادة تعيين قيم البيانات داخل المجموعات كما كنا نفعل بالبيانات داخل القوائم. لذلك يجب ان تكون البيانات المدخلة للمجموعة غير قابلة لإعادة التعيين كالبيانات النصية والصفوف والأرقام. وإذا حاولنا إضافة بيان قابل للتغيير كالقوائم مثلا فان بايثون يظهر لنا رسالة بوجود خطأ كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
letters={'Hassan', 'Waleed'}
letters.add(2)
letters.add((3,4))
letters

# %%
letters.add([2,4,6])

# %% [markdown]
# You can check whether an item exists in a set using `in`, as we did with lists and tuples. Here is an example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ويكمن التعرف على ما اذا كان هناك بيان موجود في مجموعة باستخدام الامر in كما فعلنا سابقا في القوائم والصفوف وهذا مثال عليه هنا:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
set_1={1,2,'a','b'}
1 in set_1

# %%
3 in set_1

# %% [markdown]
# You can perform a union of two sets to get all items from both sets without duplicates using `union()`, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ويمكن اجراء عملية التقاطع بين مجموعتين للحصول على جميع البيانات الموجودة في كلا المجموعتين بعد حذف التكرار باستخدام الدالة ()union كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
set_1={1,2,'a','b'}
set_2={'c','d',1,2}
set_1.union(set_2)

# %% [markdown]
# If you want only the shared items, use `intersection()` as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# اما اذا اردنا ان نحصل على البيانات المتشابهة فقط فاننا نستخدم الدالة ()intersection كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
set_1={1,2,'a','b'}
set_2={'c','d',1,2}
set_1.intersection(set_2)

# %% [markdown]
# To get items that exist in one set but not in another, use `difference()` as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# وللحصول على البيانات الموجود في مجموعة شريطة ان هذا البيانات غير موجودة في مجموعة ثانية نستخدم الدالة ()difference كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
set_1={1,2,'a','b'}
set_2={'c','d',1,2}
set_1.difference(set_2)

# %% [markdown]
# To get all items from both sets except the common ones, use `symmetric_difference()` as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# وللحصول على جميع البيانات داخل مجموعتين بعد حذف العناصر المتشابهة نستخدم الدالة ()symmetric_difference كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
set_1={1,2,'a','b'}
set_2={'c','d',1,2}
set_1.symmetric_difference(set_2)

# %% [markdown]
# Notice that the four functions above create a new set to reflect the change and do not modify the original sets. You can confirm this with the following examples:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ ان جميع الدوال الاربعة السابقة تقوم بتكون مجموعة جديد لاحداث التغيير لا تغير في المجموعات الاصلية ولتأكد من ذلك يمكن ملاحظة ناتج الامثلة التالية:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
set_1={1,2,'a','b'}
set_2={'c','d',1,2}
result=set_1.union(set_2)
print(result)
print(set_1)
print(set_2)

# %%
set_1={1,2,'a','b'}
set_2={'c','d',1,2}
result=set_1.intersection(set_2)
print(result)
print(set_1)
print(set_2)

# %%
set_1={1,2,'a','b'}
set_2={'c','d',1,2}
result=set_1.difference(set_2)
print(result)
print(set_1)
print(set_2)

# %%
set_1={1,2,'a','b'}
set_2={'c','d',1,2}
result=set_1.symmetric_difference(set_2)
print(result)
print(set_1)
print(set_2)

# %% [markdown]
# To modify the original set directly, use the in-place methods below: `intersection_update()`, `difference_update()`, and `symmetric_difference_update()`, instead of the previous methods, as in the following examples:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ولاحداث تغيير مباشر في المجموعة الاصلية نستخدم الدوال التالية:
# <ul><li>
#     ()intersection_update</li>
#     <li>()difference_update </li>
#     <li>()symmetric_difference_update </li>
#     بدلا من الدوال السابقة للقيام بهذه المهمة كما في الامثلة التالية:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
set_1={1,2,'a','b'}
set_2={'c','d',1,2}
set_1.intersection_update(set_2)
print(set_1)
print(set_2)

# %%
set_1={1,2,'a','b'}
set_2={'c','d',1,2}
result=set_1.difference_update(set_2)
print(set_1)
print(set_2)

# %%
set_1={1,2,'a','b'}
set_2={'c','d',1,2}
result=set_1.symmetric_difference_update(set_2)
print(set_1)
print(set_2)

# %% [markdown]
# You can use `issubset()` to check whether one set is a subset of another, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كما يمكن استخدام الدالة ()issubset للسؤال عن ما اذا كانت مجموعة ما هي مجموعة جزئية من مجموعة أخرى كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
set_1={1,2,'a','b'}
set_2={1, 'd', 2, 'c'}
set_3={'a','b'}
set_3.issubset(set_1)

# %%
set_2.issubset(set_1)

# %% [markdown]
# You can use `issuperset()` to check whether a set contains all items of another set, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كما يمكن استخدام الدالة ()issuperset للسؤال عن ما اذا كانت مجموعة ما هي مجموعة مشتملة على جميع بيانات مجموعة أخرى كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
set_1={1,2,'a','b'}
set_2={1, 'd', 2, 'c'}
set_3={'a','b'}
set_1.issuperset(set_3)

# %%
set_2.issuperset(set_1)

# %% [markdown]
# You can use `isdisjoint()` to check whether two sets have no items in common, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كما يمكن استخدام الدالة ()isdisjoint للسؤال عن ما اذا كانت مجموعة ما منفصلة عن مجموعة أخرى كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
set_1={1,2,'a','b'}
set_2={1, 'd', 2, 'c'}
set_3={'c','d'}
set_1.isdisjoint(set_3)

# %%
set_1.isdisjoint(set_2)

# %% [markdown]
# Everything we learned about copying lists can be applied to sets as well.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كل ما ينطبق على القوائم من عمليات النسخ يمكن تطبيقه على المجموعات.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
cars={"Ford", 2015, "white"}
cars2=cars
cars2.add(100000)
print(cars)
print(cars2)

# %%
cars={"Ford", 2015, "white"}
cars2=cars.copy()
cars2.add(100000)
print(cars)
print(cars2)

# %%
cars={"Ford", 2015, "white"}
cars2=set(cars)
cars2.add(100000)
print(cars)
print(cars2)

# %% [markdown]
# There is also a `frozenset`, which is an immutable set. If you try to add or remove items from a frozenset, Python raises an error, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# وهناك ما يدعى بالمجموعة المجمدة frozenset والتي لا تسمح بتغيير باجراء اي تغيير عليها. فعند محالة اضافة عنصر لهذه المجموعة المجمدة فان مفسر بايثون يعطي رسالة خطأ تفيد بعدم قابلية المجموعة المجمدة للاضافة كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
set_A=frozenset([1,2,4])
type(set_A)

# %%
set_A.add(7)

# %%
set_A.remove(1)

# %% [markdown]
# ### Exploratory Activities

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### تمارين استكشافية
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# 1) Use `pop()` to remove a random item from an empty set. What do you notice?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ١- استخدم الدالة ()pop لحذف بيان عشوائي من مجموعة فارغة؟ ماذا تلاحظ؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# 2) Explore whether you can add a set to another set.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ٢- استكشف إمكانية إضافة مجموعة الى مجموعة ؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# 3) Use two sets to explore the difference between `set_1.difference(set_2)` and `set_2.difference(set_1)`.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ٣- استخدم محموعتين للتعرف على الفرق بين استخدم set_1.difference(set_2) واستخدام set_2.difference(set_1) ؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# 4) Use two sets to explore the difference between `union()` and `symmetric_difference()`.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ٤- ١ستخدم مجموعتين للتعرف على الفرق بين استخدام الدالة ()union والدالة ()symmetric_difference؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# 5) Try using the `dir()` command with a set name inside the parentheses and see which methods can be used with sets.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ٥- جرب استخدام الامر ()dir واضعا بين قوسيه اسما لمجموعة و تعرف على الدوال التي يمكن استخدامها مع المجموعة؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# ## Strings

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## البيانات النصية (String)
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# In Chapter 2 we learned some string basics and postponed part of them until we learned lists at the start of this chapter. Now we will continue those basics and learn some operations, slicing, and formatting for printing.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# تعرفنا في الفصل الثاني على بعض اساسيات البيانات النصية واجلنا جزء من هذه الأساسيات الى حين التعرف على مفهوم القوائم في بايثون  والذي قمنا به في بداية هذا الفصل والان سوف نكمل ما بدأناه من اساسيات البيانات النصية فنتعرف على بعض العمليات التي يمكن اجراؤها عليها وطريقة تجزئتها وتهيئتها للطباعة.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# Although strings are a primary data type in Python, they can be treated like collections and handled similarly to lists. You can create an empty string using any type of quotes, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# على الرغم من البيانات النصية هي أحد النوع البيانات الرئيسية في بايثون الا انه يمكن اعتبارها بيانات تجميعية بحيث يمكن التعامل معها بنفس الطريقة التي تعاملنا بها مع القوائم. فيمكن انشاء نص فارغ باستخدام أحد أنواع علامات التنصيص التي تعلمناها سابقا كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
text=''

# %%
text=""

# %%
text=''''''

# %% [markdown]
# To find the length of the string "Hello python", use `len()` as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ولمعرفة عدد سلسلة الحروف الموجودة في النص “Hello python” نقوم باستخدام الدالة ()len كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
len("Hello python")

# %% [markdown]
# You can slice strings the same way we did with lists, as shown below:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كما يمكن تجزئة النص بنفس الطريقة التي تعلمناها عن القوائم كما يلي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
text="Hello python"
text[0]

# %%
text[-1]

# %%
text[6:8]

# %% [markdown]
# You can concatenate strings using the plus sign, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ويمكن دمج البيانات النصية باستخدام علامة الجمع كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
name="Ahmad"
txt="Hello"
space=" "
txt+space+name

# %% [markdown]
# You can also use `join()` to combine strings, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# وكذلك يمكن استخدام الدالة ()join للقيام بنفس المهمة كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
name="Ahmad"
txt="Hello"
" ".join([txt,name])

# %% [markdown]
# Notice that in the previous example we used `" "` before `join()` as the separator for the list items. You can use any separator you like; for example, an underscore:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ اننا في المثال السابق استخدمنا الدالة ()join مسبوقة بفراغ موجود بين علامتي التنصيص ليكون رابطاً لعناصر القائمة الموجود داخل قوسي الدالة. كما يجب ملاحظة انه يمكن استخدام أي رابط اخر نرغب فيه فمثلا لو أردنا استخدام الشرطة السفلية فإننا نكتب المثال السابق كالتالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
"_".join([txt,name])

# %%
".".join([txt,name])

# %% [markdown]
# You can use `count()` to find how many times a character or substring appears in a string, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ويمكن استخدام الدالة ()count كما فلعنا مع القوائم لمعرفة عدد تكرار حرف او جزء من نص في بيان نصي كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
text="Hello python"
text.count("l")

# %%
text.count("p")

# %%
text.count("P")

# %% [markdown]
# You can use `index()` to find the position of the first occurrence of a character or substring in a string, as shown below:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# وكذلك يمكن استخدام الدالة ()index لمعرفة مؤشر أول ظهور لحرف او جزء من نص داخل بيان نصي كما يلي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
text="Hello python"
text.index("H")

# %%
text.index("n")

# %%
text.index("py")

# %% [markdown]
# ### Exploratory Activities

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### تمارين استكشافية
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# 1) Create a variable named `name` with a value like "Ali". Try to print the phrase "Hello name" using `print()`. What do you notice? Did Python use the value of `name`? If not, why?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 1- اكتب متغيرا وليكن name واجعل قيمته أي اسم تختاره وليكن “Ali” حاول ان تطبع العبارة “Hello name” باستخدام الدالة ()print؟ ماذا تلاحظ؟ هل قام بايثون باستخدام قيمة name عند اجراء عملية الطباعة؟ اذا كانت الإجابة بلا فما السبب في رأيك؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# A variable name inside quotes is treated as plain text, not a variable. To insert variable values into a string, Python provides several techniques. The first is using `%` formatting (from C), as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ان وجود اسم متغير داخل علامة تنصيص لا يعتبره بايثون على انه متغير وانما يتعامل معه على انه نص كأي نص اخر. ولكي نجعل بايثون يستخدم قيمة متغير دخال علامة تنصيص فان هناك عدة حيل في بايثون تمكنا من القيام بذلك. اول هذه الحيل هي استخدام النسبة المئوية دخال النص متبوعة بنوع البيان المراد إدخاله وهو أسلوب قديم تم استيراده من لغة C كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
name="Hassan"
greating = "Hello, %s" % name
print(greating)

# %% [markdown]
# Notice that the percent sign marks where the variable value is inserted, and `s` indicates a string type. You can use the same method for numeric values, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ ان علامة النسبة المئوية استخدمت لتحديد مكان ادخال قيمة المتغير وحرف s استخدم للدلالة على نوع القيمة التي يحتويها المتغير والذي تم وضعه بعد النص مفصول عنه بعلامة النسبة المئوية.
# كما يمكن استخدام هذه الطريقة لإدخال قيم متغيرات رقمية كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
speed = 120
print("You exceeded the speed limit of %d km/hour" % speed)

# %%
print("You exceeded the speed limit of %f km/hour" % speed)

# %%
print("You exceeded the speed limit of %5.2f km/hour" % speed)

# %% [markdown]
# Notice that `d` is used for integers and `f` for floating-point numbers. You can also control the total width and the number of decimal places as shown in the last example.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ في المثال السابق ان الحرف d يستخدم للدلالة على الاعداد الصحيحة بينما الحرف f يدل على استخدام الاعداد العشرية. كما يجب ملاحظة ان عدد الخانات الرقمية يمكن التحكم فيه بتحديد عدد الخانات الكلي وعدد الأجزاء العشرية كما موضح في المثال الأخير.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# You can insert values from multiple variables, whether numeric or text, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ويمكن ادخال قيم أكثر من متغير سواء كانت عدديا أو نصيا كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
name="Ahmad"
speed=120
fine=300
print("Dear %s, You violated the speed limit of %d. You have to pay %5.2f Riyals" % (name,speed,fine))

# %% [markdown]
# Notice that we used a tuple after the percent sign; the order of values in that tuple matters for correct placement in the string.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ استخدامنا للصف في المثال السابق بعد علامة النسبة المئوية ولاحظ اهمية الترتيب للبيانات داخل الصف لتوظيفها بشكل مناسب داخل النص.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# There is a more modern way to do the same task using `format()`, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# وهناك طريقة حديثة للقيام بنفس المهام السابقة وذلك باستخدام الدالة ()format كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
name="Ahmad"
speed=120
fine=300
print("Dear {}, You violated the speed limit of {} km/hr. You have to pay {} Riyals".format(name,speed,fine))

# %% [markdown]
# The order of variables inside `format()` matters unless you use named placeholders or positional indexes inside the braces, as in the following examples:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# وترتيب المتغيرات بين قوسي الدالة ()format يجب مراعاته أيضا هنا الا اذا كتبنا اسم المتغيرات بين القوسين المتعرجين او استخدمنا مؤشر ترتيب المتغير كما في المثالين التاليين:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
print("Dear {2}, You violated the speed limit of {0} km/hr. You have to pay {1} Riyals".format(speed,fine,name))

# %%
print("Dear {name}, You violated the speed limit of {speed} km/hr.\
You have to pay {fine} Riyals".format(speed=speed,fine=fine,name=name))

# %% [markdown]
# In Python 3.6 and later, you can also use literal formatting (f-strings), which is similar to `format()`, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# وفي اصدارة بايثون 3.6 وما بعدها تم إضافة طريقة أخرى لتهيئة النصوص تسمى literal formatting وهي تشبه الى حد كبير استخدام الدالة ()format كما هو موضح في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
print(f"Dear {name}, You violated the speed limit of {speed} km/hr. You have to pay {fine} Riyals")

# %% [markdown]
# All you need is to add `f` before the string and place variable names inside curly braces.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# فكل ما تحتاجه عند استخدام هذه الطريقة هو إضافة حرف f قبل النص وكتابة أسماء المتغيرات التي تريد التعويض بقيمها داخل قوسين متعرجين فقظ.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# To split a string into smaller pieces inside a list, use `split()` as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لتجزئة نص الي بيانات نصية صغيرة داخل قائمة يمكن استخدام الدالة ()split كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
text="one two three four five six seven"
text.split(" ")

# %%
colors="yellow,green,blue,red,white,black"
colors.split(",")

# %% [markdown]
# Notice that in the previous example we used a space or a comma inside quotes to tell Python where to split the text.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ اننا ستخدمنا في المثال السابق الفراغ والفاصلة لتخبر مفسر بايثون بأماكن فصل النص ووضعنا هاتين العلامتين داخل علامة تنصيص بين قوسي الدالة ()split.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# You can convert text to uppercase or lowercase using `upper()` and `lower()` respectively, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ويمكن تحويل النص الى حروف كبير او صغيرة باستخدام الدالتين ()upper و ()lower على التوالي كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
colors="yellow,green,blue,red,white,black"
colors.upper()

# %%
numbers="ONE TWO THREE FOUR"
numbers.lower()

# %% [markdown]
# You can remove leading and trailing spaces using `strip()`, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كما يمكن إزالة الفراغات الموجود في بداية النص ونهايته باستخدام الدالة ()strip كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
text="     Hello python       "
text.strip()

# %% [markdown]
# You can replace a character or part of a string using `replace()`, as in the following example:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كما يمكننا أيضا استبدال حرف او جزء من نص باخر باستخدام الدالة ()replace كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
text="Hello python"
text.replace('l','s')

# %% [markdown]
# Finally, note that strings are immutable, unlike lists. The modifications in the previous examples create new strings rather than changing the original. The next example demonstrates this:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ونختم هذا الفصل بان نخبرك ان البيانات النصية تختلف عن القوائم في انها غير قابلة للتغيير immutable. بمعنى ان ما قمنا به في الأمثلة السابقة من تعديلات على النص لم يكمن بالفعل على نفس النص وانما قام مفسر بايثون بإنشاء بيان نصي جديد يحتوي على التعديلات التي قمنا بها وقام بطباعتها على الشاشة بينما البيان الأصلي لم يتغير وسف نثبت لك ذلك في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
numbers="one two three four"
numbers.upper()

# %%
numbers

# %% [markdown]
# Notice that converting `numbers` to uppercase created a temporary string and printed it, but the original string stayed unchanged. This does not apply to lists; list operations modify the original list, as shown below:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ انه عندما قمنا بتحويل النص numbers الى حروف كبيرة قام بايثون بانشاء متغير مؤقت وطبع النص بعد التعديل على الشاشة. ولكن عندما طلبنا من بايثون طباعة النص الأصلي فان النص مازال كما هو بحروفه الصغيرة. هذا الخاصية لا تنطبق على القوائم. فعندما نقوم بالتعديل على القوائم فان بايثون يجري عملية التعديل على القائمة الاصلية كما في المثال التالي:
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
numbers=["one","two","three","four"]
numbers.pop()
numbers

# %% [markdown]
# Notice that when we removed the last item from `numbers` using `pop()`, Python removed it from the original list.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لاحظ انه عندما حذفنا البيان الأخير من القائمة numbers باستخدام الدالة ()pop قام بايثون بحذف البيان من القائمة الاصلية.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# ## Chapter Summary

# %% [markdown]
# - Lists are ordered and mutable; you used indexing, slicing, adding/removing items, sorting, and copying.
# - Tuples are ordered but immutable; you practiced packing/unpacking and using them for fixed data.
# - Dictionaries map unique keys to values; you accessed, updated, and explored common dictionary methods and nested structures.
# - Sets store unique items; you applied union/intersection/difference, membership tests, and learned about `frozenset`.
# - Strings are immutable sequences; you used slicing, concatenation, formatting, and common methods like `split()`, `join()`, `replace()`, `strip()`, and case changes.
# - You compared mutability and ordering across structures to choose the best fit for a task.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## ملخص الفصل
#
# - القوائم مرتبة وقابلة للتغيير؛ استخدمت الفهرسة والتجزئة وإضافة/حذف العناصر والفرز والنسخ.
# - الصفوف (Tuples) مرتبة لكنها غير قابلة للتغيير؛ تدربت على الحزم/فك الحزم واستخدامها للبيانات الثابتة.
# - القواميس تربط مفاتيح فريدة بقيم؛ قمت بالوصول والتعديل واستكشاف الدوال الشائعة والبنى المتداخلة.
# - المجموعات تخزن عناصر فريدة؛ طبقت الاتحاد والتقاطع والفرق واختبارات الانتماء وتعلمت `frozenset`.
# - النصوص تسلسلات غير قابلة للتغيير؛ استخدمت التجزئة والدمج والتهيئة ودوال مثل `split()` و`join()` و`replace()` و`strip()` وتغيير حالة الأحرف.
# - قارنت بين قابلية التغيير والترتيب عبر التراكيب لاختيار الأنسب للمهمة.
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# ## Comprehension Questions

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## اسئلة استيعابية
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# Questions 1 to 6 are sourced from pynative.com:
#
# https://pynative.com/python-list-exercise-with-solutions/#h-exercise-1-reverse-a-list-in-python

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# مصدر الاسئلة من 1 الى 6 من موقع pynative.com
#
# https://pynative.com/python-list-exercise-with-solutions/#h-exercise-1-reverse-a-list-in-python
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# 1. Reverse the order of items in list `list1`?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 1. اعكس ترتيب البيانات في القائمة  list1؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
## الجواب المتعوقع
## [500, 400, 300, 200, 100]

list1 = [100, 200, 300, 400, 500]
## اكتب الكود هنا

# %% [markdown]
# 2. Add elements of `list2` to elements of `list1`?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 2. أضف عناصر القائمة الثانية list2 إلى عناصر المجموعة الأولى list1؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
## الجواب المتوقع
## ['Hello Dear', 'Hello Sir', 'take Dear', 'take Sir']

list1 = ["Hello ", "take "]
list2 = ["Dear", "Sir"]

## اكتب الكود هنا

# %% [markdown]
# 3. Add the value 7000 after 6000 in list `list1`?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 3. أضف البيان 7000 بعد البيان 6000 الموجود في القائمة list1؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
## الجواب المتوقع
## [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]

## اكتب الكود هنا

# %% [markdown]
# 4. Add the sublist `sub_list` to the deepest list inside `list1` using `extend()`?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 4. أضف القائمة الفرعية sub_list إلى أعمق قائمة موجودة في القائمة الرئيسية list1 باستخدام الدالة ()extend؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
## الاجابة المتوقعة
## ['a', 'b', ['c', ['d', 'e', ['f', 'g', 'h', 'i', 'j'], 'k'], 'l'], 'm', 'n']

## القائمة الرئيسية
list1 = ["a", "b", ["c", ["d", "e", ["f", "g"], "k"], "l"], "m", "n"]

## القائمة الفرعية المطلوب اضافتها
sub_list = ["h", "i", "j"]

## اكتب الكود هنا

# %% [markdown]
# 5. Replace value 15 in list `list1` with 150?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 5. استبدل القيمة 15 في القائمة list1 بالقيمة 150؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
## الاجابة المتوقعة
## [5, 10, 150, 20, 25, 50, 20]

list1 = [5, 10, 15, 20, 25, 50, 20]

## اكتب الكود  هنا

# %% [markdown]
# 6. Remove the last item from list `list1`?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 6. أحذف آخر بيان في القائمة list1؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
## الاجابة المتوقعة
## [2,4,6,8,10]

list1=[2,4,6,8,10,20]

## اكتب الكود هنا

# %% [markdown]
# 7. Compute the sum of the numbers in list `list1`?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 7. احسب مجموع الأعداد الموجودة في القائمة list1؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
## الجواب المتوقع 55

list1=[12,11,4,6,5,10,7]

## اكتب الكود هنا

# %% [markdown]
# 8. Find the maximum value in list `list1`?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 8. احسب أعلى قيمة في القائمة list1؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
## الجواب المتوقع123

list1=[12,11,4,6,5,10,7]

## اكتب الكود هنا

# %% [markdown]
# 9. Find the minimum value in list `list1`?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 9. احسب أقل قيمة في القائمة list1؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
## الجواب المتوقع 4

list1=[12,11,4,6,5,10,7]

## اكتب الكود هنا

# %% [markdown]
# 10. Count the number of elements in list `list1`?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 10. احسب عدد العناصر في القائمة list1؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
## الجواب المتوقع 7

list1=[12,11,4,6,5,10,7]

## اكتب الكود هنا

# %% [markdown]
# 11. Convert the string `name` into a list?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 11. حول النص name إلى قائمة؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
## الجواب المتوقع
["A","h","m","a","d"]

name="Ahmad"

## اكتب الكود هنا

# %% [markdown]
# 12. Sort list `list1` in ascending order?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 12. رتب القائمة list1؟ تصاعدياً؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
## الجواب المتوقع
## [4,5,6,7,10,11,12]

list1=[12,11,4,6,5,10,7]

## اكتب الكود هنا

# %% [markdown]
# 13. Sort list `list1` in descending order?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 13. رتب القائمة list1 تنازلياً؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
## الجواب المتوقع
## [12,11,10,7,6,5,4]

list1=[12,11,4,6,5,10,7]

## اكتب الكود هنا

# %% [markdown]
# 14. Sort list `list1` alphabetically?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 14. رتب القائمة list1 ابجدياً؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
## الجواب المتوقع
## ["A","a","d","h","m"]

list1=["A","h","m","a","d"]

## اكتب الكود هنا

# %% [markdown]
# 15. Add the number 15 before the last element in `list1`?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 15. اضف الرقم 15 قبل البيان الأخير في القائمة list1؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
## الجواب المتوقع
## [12,11,10,7,6,5,15,4]

list1=[12,11,4,6,5,10,7]

## اكتب الكود هنا

# %% [markdown]
# 16. Write code to find the index of the value 10 in `list1`?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 16. اكتب كود برمجي يوجد مؤشر القيمة 10 في القائمة list1؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
## الجواب ا لمتوقع 5

list1=[12,11,4,6,5,10,7]

## اكتب الكود هنا

# %% [markdown]
# 17. Write a list of three fruits you like. Print the last element twice: once using a positive index and once using a negative index.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 17. اكتب قائمة بثلاثة فواكه تحبها؟ قم بطباعة آخر عنصر في القائمة التي كتبتها مرتين مره مستخدماً مؤشر القوائم الموجب ومرة مستخدماً مؤشر القوائم السالب؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# 18. Extract the list ["A", "D", "G"] from the base list `letters` using what you learned about list slicing.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 18. استخرج القائمة ["A", "D", "G"] من القائمة الأساسية letters  مستخدماً ما تعلمته من طرق تجزئة القوائم؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
letters = ['A', 'B', 'C', 'D', 'E', 'F', 'G']

## اكتب الكود هنا

# %% [markdown]
# 19. Slice the list `letters` so the result contains all letters from D to F.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 19. جزأ القائمة letters بحيث ينتج عن عملية التجزئة قائمة تحتوي على جميع الحروف من D الى F؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
## الاجابة المتوقعة
## ["D","E","F"]
letters = ['A', 'B', 'C', 'D', 'E', 'F', 'G']

## اكتب الكود هنا

# %% [markdown]
# 20. Create an empty list, then add three foods you like.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# 20. أنشئ قائمة فارغة ثم اضف لها ثلاثة من  الاطعمة التي تحبها؟
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %%
## اكت الكود هنا
