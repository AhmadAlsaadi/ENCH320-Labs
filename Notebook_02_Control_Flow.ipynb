# %% [markdown]
# # Lab 2: Control Flow
#
# <details>
# <summary>العنوان بالعربية</summary>
# المختبر 2: تدفق التحكم
# </details>

# %% [markdown]
# ## Concept 1: if Statements - Making Decisions
#
# An `if` statement allows your program to make decisions based on conditions. If the condition is True, the code inside the if block executes. If it's False, the code is skipped.
#
# **Key Points:**
# - Conditions evaluate to True or False
# - Use comparison operators: ==, !=, <, >, <=, >=
# - Indentation matters in Python

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### العربية: جملة if
#
# جملة `if` تسمح لبرنامجك باتخاذ قرارات بناءً على الشروط. إذا كان الشرط صحيحاً (True)، يتم تنفيذ الكود داخل كتلة if. إذا كان خاطئاً (False)، يتم تخطي الكود.
#
# **النقاط الرئيسية:**
# - الشروط تقيّم إلى صحيح أو خاطئ
# - استخدم مشغلات المقارنة: ==, !=, <, >, <=, >=
# - المحاذاة (Indentation) مهمة في Python
#
# </div>
# </details>

# %% [markdown]
# ### Example: Checking Age
#
# Let's check if someone is old enough to vote:

# %%
age = 18

if age >= 18:
    print("You are eligible to vote!")

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### مثال عربي: التحقق من السن
#
# إذا كان العمر 18 أو أكثر، سيتم طباعة رسالة.
#
# </div>
# </details>

# %% [markdown]
# ### Task: Check Student Status
#
# Write an if statement to check if a student's score is 80 or higher. If so, print "Pass!"

# %%
# TODO: Write an if statement
score = 85

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### المهمة بالعربية: التحقق من درجة الطالب
#
# اكتب جملة if للتحقق من أن درجة الطالب 80 أو أعلى.
#
# </div>
# </details>

# %% [markdown]
# ## Concept 2: if-else Statements - Two Paths
#
# An `if-else` statement provides two paths: one when the condition is True, and another when it's False. The `else` block always executes when the if condition is False.
#
# **Key Points:**
# - Use `else` to handle the False case
# - Only one block executes
# - Useful for binary decisions

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### العربية: جملة if-else
#
# جملة `if-else` توفر طريقين: أحدهما عندما يكون الشرط صحيحاً، والآخر عندما يكون خاطئاً.
#
# **النقاط الرئيسية:**
# - استخدم `else` للتعامل مع الحالة الخاطئة
# - تنفيذ كتلة واحدة فقط
# - مفيد للقرارات الثنائية
#
# </div>
# </details>

# %% [markdown]
# ### Example: Determining Weather Advice
#
# Let's give advice based on the temperature:

# %%
temperature = 5

if temperature > 15:
    print("It's warm! Wear light clothing.")
else:
    print("It's cold! Wear warm clothing.")

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### مثال عربي: نصيحة الطقس
#
# إذا كانت درجة الحرارة أعلى من 15، نطبع رسالة واحدة، وإلا نطبع رسالة أخرى.
#
# </div>
# </details>

# %% [markdown]
# ### Task: Check if Discount Applies
#
# Write an if-else statement to check if the purchase amount is 100 or more. If yes, print "Discount applied!", otherwise print "No discount."

# %%
# TODO: Write an if-else statement
purchase_amount = 150

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### المهمة بالعربية: التحقق من الخصم
#
# اكتب جملة if-else للتحقق من أن مبلغ الشراء 100 أو أكثر.
#
# </div>
# </details>

# %% [markdown]
# ## Concept 3: if-elif-else Statements - Multiple Paths
#
# When you need to check multiple conditions, use `if-elif-else`. Each `elif` (else if) block checks a new condition. Only the first True condition's block executes.
#
# **Key Points:**
# - `elif` checks another condition
# - Can have multiple `elif` statements
# - `else` is optional and catches all remaining cases

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### العربية: جملة if-elif-else
#
# عندما تحتاج للتحقق من عدة شروط، استخدم `if-elif-else`. كل كتلة `elif` تفحص شرطاً جديداً.
#
# **النقاط الرئيسية:**
# - `elif` يفحص شرطاً آخر
# - يمكن أن يكون هناك عدة جمل `elif`
# - `else` اختياري ويمسك جميع الحالات المتبقية
#
# </div>
# </details>

# %% [markdown]
# ### Example: Grading System
#
# Let's assign a letter grade based on a score:

# %%
score = 85

if score >= 90:
    print("Grade: A")
elif score >= 80:
    print("Grade: B")
elif score >= 70:
    print("Grade: C")
else:
    print("Grade: F")

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### مثال عربي: نظام التقييم
#
# نعطي درجة بناءً على النقاط: 90 أو أكثر = A، 80 أو أكثر = B، إلخ.
#
# </div>
# </details>

# %% [markdown]
# ### Task: Determine Ticket Price
#
# Write an if-elif-else statement: Age < 12 = $5, Age 12-64 = $10, Age > 64 = $7

# %%
# TODO: Write an if-elif-else statement
age = 25

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### المهمة بالعربية: تحديد سعر التذكرة
#
# اكتب جملة if-elif-else لتحديد سعر التذكرة حسب العمر.
#
# </div>
# </details>

# %% [markdown]
# ## Concept 4: Nested Conditionals - Conditions Within Conditions
#
# You can place an `if` statement inside another `if` statement. This is called nesting. Nested conditionals let you check multiple related conditions.
#
# **Key Points:**
# - Nested if must be indented further
# - Useful for dependent conditions
# - Can get complex; use carefully

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### العربية: الشروط المتداخلة
#
# يمكنك وضع جملة `if` داخل جملة `if` أخرى. هذا يسمى التداخل.
#
# **النقاط الرئيسية:**
# - جملة if المتداخلة يجب أن تكون مع مسافة إضافية
# - مفيد للشروط المترابطة
# - قد تصبح معقدة؛ استخدم بحذر
#
# </div>
# </details>

# %% [markdown]
# ### Example: Accessing Premium Content
#
# Let's check if a user is both a member and has paid:

# %%
is_member = True
has_paid = True

if is_member:
    if has_paid:
        print("Access granted!")
    else:
        print("Please complete payment.")
else:
    print("Please join first.")

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### مثال عربي: الوصول إلى المحتوى المميز
#
# نتحقق أولاً من أن المستخدم عضو، ثم نتحقق إذا دفع.
#
# </div>
# </details>

# %% [markdown]
# ### Task: Validate Login
#
# Write nested if statements: First check if username is correct, then check if password is correct. Print appropriate messages.

# %%
# TODO: Write nested if statements
username = "admin"
password = "12345"

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### المهمة بالعربية: التحقق من تسجيل الدخول
#
# اكتب جملات if متداخلة للتحقق من اسم المستخدم وكلمة المرور.
#
# </div>
# </details>

# %% [markdown]
# ## Concept 5: for Loops - Repeating With a Counter
#
# A `for` loop repeats a block of code a specific number of times. It's useful when you know exactly how many times to repeat something. Each iteration, a variable (called the counter) takes the next value.
#
# **Key Points:**
# - Loop counter changes each iteration
# - Indentation marks the loop body
# - Simple and predictable repetition

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### العربية: حلقة for
#
# حلقة `for` تكرر كتلة من الكود عدداً معيناً من المرات.
#
# **النقاط الرئيسية:**
# - عداد الحلقة يتغير في كل تكرار
# - المحاذاة تحدد جسم الحلقة
# - تكرار بسيط وقابل للتنبؤ به
#
# </div>
# </details>

# %% [markdown]
# ### Example: Counting Up
#
# Let's print the numbers from 1 to 5:

# %%
for i in range(1, 6):
    print(i)

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### مثال عربي: العد من 1 إلى 5
#
# نطبع الأرقام من 1 إلى 5 باستخدام حلقة for.
#
# </div>
# </details>

# %% [markdown]
# ### Task: Print a Multiplication Table
#
# Write a for loop that prints the 3 times table (3×1, 3×2, ... 3×10)

# %%
# TODO: Write a for loop for multiplication table

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### المهمة بالعربية: طباعة جدول الضرب
#
# اكتب حلقة for لطباعة جدول الضرب للعدد 3.
#
# </div>
# </details>

# %% [markdown]
# ## Concept 6: range() Function - Creating Sequences
#
# The `range()` function generates a sequence of numbers. It's commonly used with for loops. You can specify start, stop, and step values to control the sequence.
#
# **Key Points:**
# - `range(n)` goes from 0 to n-1
# - `range(start, stop)` goes from start to stop-1
# - `range(start, stop, step)` increments by step value

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### العربية: دالة range()
#
# دالة `range()` تولد سلسلة من الأرقام. تُستخدم عادة مع حلقات for.
#
# **النقاط الرئيسية:**
# - `range(n)` يذهب من 0 إلى n-1
# - `range(start, stop)` يذهب من start إلى stop-1
# - يمكنك تحديد الخطوة
#
# </div>
# </details>

# %% [markdown]
# ### Example: Different range() Uses
#
# Let's see different ways to use range():

# %%
# range(n) - 0 to n-1
print("range(5):")
for i in range(5):
    print(i)

# range(start, stop)
print("\nrange(2, 7):")
for i in range(2, 7):
    print(i)

# range(start, stop, step)
print("\nrange(0, 10, 2):")
for i in range(0, 10, 2):
    print(i)

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### مثال عربي: استخدامات مختلفة لـ range()
#
# نرى طرقاً مختلفة لاستخدام range() مع أرقام مختلفة.
#
# </div>
# </details>

# %% [markdown]
# ### Task: Print Even Numbers
#
# Write a for loop using range() to print all even numbers from 0 to 20

# %%
# TODO: Write a for loop with range() for even numbers

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### المهمة بالعربية: طباعة الأرقام الزوجية
#
# اكتب حلقة for باستخدام range() لطباعة جميع الأرقام الزوجية من 0 إلى 20.
#
# </div>
# </details>

# %% [markdown]
# ## Concept 7: for Loops with Lists - Looping Through Elements
#
# You can use a `for` loop to iterate through each element in a list. This is one of the most common uses of loops in Python.
#
# **Key Points:**
# - Loop variable gets each element in order
# - Works with any iterable (list, tuple, string)
# - Access each element inside the loop body

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### العربية: حلقة for مع القوائم
#
# يمكنك استخدام حلقة `for` للمرور عبر كل عنصر في قائمة.
#
# **النقاط الرئيسية:**
# - متغير الحلقة يحصل على كل عنصر بالترتيب
# - يعمل مع أي قابل للتكرار
# - الوصول إلى كل عنصر داخل جسم الحلقة
#
# </div>
# </details>

# %% [markdown]
# ### Example: Printing a Shopping List
#
# Let's iterate through a list of items:

# %%
shopping_list = ["apples", "bread", "milk", "eggs"]

for item in shopping_list:
    print(item)

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### مثال عربي: طباعة قائمة التسوق
#
# نمر عبر كل عنصر في القائمة ونطبعه.
#
# </div>
# </details>

# %% [markdown]
# ### Task: Calculate Sum of Scores
#
# Write a for loop to iterate through a list of test scores and calculate the sum. Print the total.

# %%
scores = [85, 90, 78, 92, 88]
# TODO: Write a for loop to sum the scores

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### المهمة بالعربية: حساب مجموع الدرجات
#
# اكتب حلقة for للمرور عبر قائمة درجات واحسب المجموع.
#
# </div>
# </details>

# %% [markdown]
# ## Concept 8: while Loops - Repeat Until Condition Changes
#
# A `while` loop repeats as long as a condition remains True. Unlike a for loop, you don't know in advance how many times it will repeat. The loop stops when the condition becomes False.
#
# **Key Points:**
# - Continues while condition is True
# - Must update the condition inside the loop
# - Risk of infinite loops if condition never changes

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### العربية: حلقة while
#
# حلقة `while` تكرر طالما الشرط صحيحاً. بخلاف حلقة for، لا تعرف مسبقاً كم مرة ستكرر.
#
# **النقاط الرئيسية:**
# - تستمر طالما الشرط صحيحاً
# - يجب تحديث الشرط داخل الحلقة
# - خطر الحلقات اللانهائية
#
# </div>
# </details>

# %% [markdown]
# ### Example: Countdown Timer
#
# Let's count down from 5 to 1:

# %%
count = 5

while count > 0:
    print(count)
    count = count - 1

print("Blastoff!")

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### مثال عربي: عداد معكوس
#
# نعد من 5 إلى 1 باستخدام حلقة while.
#
# </div>
# </details>

# %% [markdown]
# ### Task: Guessing Game
#
# Write a while loop that asks the user to guess a secret number (set it to 7). Keep asking until the correct number is guessed.

# %%
# TODO: Write a while loop for a guessing game
# Note: This is pseudocode - use input() function in actual implementation

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### المهمة بالعربية: لعبة التخمين
#
# اكتب حلقة while تطلب من المستخدم تخمين رقم سري حتى يخمنه بشكل صحيح.
#
# </div>
# </details>

# %% [markdown]
# ## Concept 9: break Statement - Exit Early
#
# The `break` statement immediately exits a loop, even if the loop condition hasn't been met yet. It's useful when you want to stop looping based on a certain condition.
#
# **Key Points:**
# - Exits the innermost loop immediately
# - Useful for early termination
# - Doesn't affect code after the loop

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### العربية: جملة break
#
# جملة `break` تخرج من الحلقة فوراً.
#
# **النقاط الرئيسية:**
# - تخرج من أعمق حلقة فوراً
# - مفيد للخروج المبكر
# - لا تؤثر على الكود بعد الحلقة
#
# </div>
# </details>

# %% [markdown]
# ### Example: Find a Number
#
# Let's search for the number 5 in a list and stop when found:

# %%
numbers = [1, 2, 3, 4, 5, 6, 7]

for num in numbers:
    if num == 5:
        print(f"Found {num}!")
        break
    print(num)

print("Search complete.")

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### مثال عربي: البحث عن رقم
#
# نبحث عن الرقم 5 في قائمة ونتوقف عندما نجده.
#
# </div>
# </details>

# %% [markdown]
# ### Task: Stop at First Negative
#
# Write a loop that prints numbers and breaks when it encounters a negative number.

# %%
values = [10, 20, 30, -5, 40]
# TODO: Write a loop with break for negative numbers

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### المهمة بالعربية: التوقف عند أول سالب
#
# اكتب حلقة تطبع الأرقام وتتوقف عندما تلتقي برقم سالب.
#
# </div>
# </details>

# %% [markdown]
# ## Concept 10: continue Statement - Skip to Next Iteration
#
# The `continue` statement skips the rest of the current loop iteration and jumps to the next iteration. It's useful when you want to skip certain items without exiting the loop.
#
# **Key Points:**
# - Skips current iteration, continues with next
# - Loop condition still applies
# - Useful for filtering or skipping items

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### العربية: جملة continue
#
# جملة `continue` تخطي بقية التكرار الحالي وتنتقل للتكرار التالي.
#
# **النقاط الرئيسية:**
# - تخطي التكرار الحالي
# - الحلقة تستمر
# - مفيد لتصفية العناصر
#
# </div>
# </details>

# %% [markdown]
# ### Example: Skip Even Numbers
#
# Let's print only odd numbers from 1 to 10:

# %%
for i in range(1, 11):
    if i % 2 == 0:
        continue
    print(i)

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### مثال عربي: تخطي الأرقام الزوجية
#
# نطبع الأرقام الفردية فقط من 1 إلى 10 باستخدام continue.
#
# </div>
# </details>

# %% [markdown]
# ### Task: Skip Empty Items
#
# Write a loop that prints list items, but skips empty strings.

# %%
items = ["apple", "", "banana", "", "cherry"]
# TODO: Write a loop with continue to skip empty strings

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### المهمة بالعربية: تخطي العناصر الفارغة
#
# اكتب حلقة تطبع عناصر القائمة لكن تخطي النصوص الفارغة باستخدام continue.
#
# </div>
# </details>

# %% [markdown]
# ## Congratulations!
#
# You've successfully completed Lab 2: Control Flow!
#
# You've learned:
# - How to make decisions with if, if-else, and if-elif-else
# - How to repeat code with for and while loops
# - How to control loop flow with break and continue
#
# Great job! 🎉

# %% [markdown]
# ## Summary of Key Concepts
#
# **Conditionals:**
# - `if`: Execute code if condition is true
# - `if-else`: Choose between two paths
# - `if-elif-else`: Choose among multiple paths
# - Nested if: Conditions within conditions
#
# **Loops:**
# - `for`: Loop a specific number of times
# - `range()`: Generate sequences of numbers
# - `while`: Loop while condition is true
# - `break`: Exit loop early
# - `continue`: Skip to next iteration

# %% [markdown]
# ## Helpful Resources
#
# - Python Documentation: https://docs.python.org/3/tutorial/controlflow.html
# - W3Schools Python Tutorial: https://www.w3schools.com/python/
# - Practice on LeetCode: https://leetcode.com/
# - Real Python Guides: https://realpython.com/
#
# Keep practicing to master control flow!

# %% [markdown]
# ## Achievement Badge
#
# ```
# ╔════════════════════════════════╗
# ║   CONTROL FLOW MASTERY BADGE   ║
# ║                                ║
# ║    🎯 If Statements Done      ║
# ║    🔄 Loops Completed         ║
# ║    ✅ All Concepts Learned    ║
# ║                                ║
# ║   Earned on: January 23, 2026  ║
# ╚════════════════════════════════╝
# ```

# %% [markdown]
# ## Capstone Project Introduction
#
# Now that you've mastered control flow, you're ready for a capstone project!
#
# The capstone project will combine:
# - Conditional statements to make decisions
# - Loops to repeat tasks
# - User input to make programs interactive
#
# In the next cell, you'll find the capstone challenge. This is your opportunity to apply everything you've learned!

# %% [markdown]
# ## Capstone Project: Interactive Grade Calculator
#
# **Project Description:**
#
# Create a program that:
# 1. Asks the user to enter their name
# 2. Uses a while loop to collect test scores until the user enters -1 to stop
# 3. For each score:
#    - Validate that it's between 0 and 100
#    - If invalid, skip it (use continue) and ask again
#    - If valid, add it to a total
# 4. After all scores are entered:
#    - Calculate the average
#    - Determine the letter grade using if-elif-else
#    - Display a summary with the student's name, average, and grade
# 5. Ask if they want to calculate another student's grades
#    - If yes, repeat from step 1
#    - If no, print a goodbye message and use break to exit
#
# **Requirements:**
# - Use at least one if-elif-else statement
# - Use nested conditionals where appropriate
# - Use at least one for or while loop
# - Use break and/or continue appropriately
# - Validate user input

# %%
# Capstone Project: Interactive Grade Calculator
# TODO: Implement the grade calculator as described above

# Starter code:
while True:
    # Get student name
    student_name = input("Enter student name (or 'quit' to exit): ")
    
    if student_name.lower() == 'quit':
        print("Goodbye!")
        break
    
    # TODO: Add score collection loop here
    # TODO: Add grade calculation and display here
    # TODO: Add another student prompt here

# %% [markdown]
# ---
#
# ## 📓 Run in Google Colab
#
# You can run this notebook directly in Google Colab by clicking the button below:
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AhmadAlsaadi/ENCH320-Labs/blob/main/Notebook_02_Control_Flow.ipynb)
