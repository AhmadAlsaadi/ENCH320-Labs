# %% [markdown]
# ## 📝 Important Instructions for Students
#
# ### Step 1: Make Your Own Copy
# When you open this notebook in Google Colab, you will be viewing a **read-only** version. To complete the assignments, you must:
#
# 1. Click **"File" → "Save a copy in Drive"** from the menu
# 2. This creates your personal copy in your Google Drive
# 3. Work on **your copy only** - all your answers will be saved there automatically
#
# ### Step 2: Rename Your Notebook
# After creating your copy, rename it to include your student ID:
#
# 1. Click on the notebook name at the top (currently "Copy of Notebook_02_Control_Flow.ipynb")
# 2. Rename it to: **`Notebook_02_Control_Flow_YourStudentID.ipynb`**
# 3. Example: `Notebook_02_Control_Flow_12345678.ipynb`
#
# ### Step 3: Share for Grading
# After completing all tasks, share your notebook with the instructor:
#
# 1. Click the **"Share"** button (top-right corner)
# 2. Enter instructor's email: **[instructor-email@university.edu]**
# 3. Set permission to **"Viewer"** or **"Commenter"**
# 4. Click **"Send"**
#
# **⚠️ Important:** Make sure to share **your copy** from Google Drive, not the original!
#
# ---

# %% [markdown]
# <details>
# <summary><b>🇸🇦 الإصدار العربي | Arabic Version</b></summary>
#
# <div dir="rtl" style="font-family: 'Amiri', serif; font-size: 16px;">
#
# ## 📝 تعليمات مهمة للطلاب
#
# ### الخطوة 1: إنشاء نسخة خاصة بك
# عند فتح هذا الدفتر في Google Colab، ستشاهد نسخة **للقراءة فقط**. لإكمال المهام، يجب عليك:
#
# 1. انقر على **"File" ← "Save a copy in Drive"** من القائمة
# 2. سيتم إنشاء نسخة شخصية في Google Drive الخاص بك
# 3. اعمل على **نسختك فقط** - سيتم حفظ جميع إجاباتك تلقائياً
#
# ### الخطوة 2: إعادة تسمية الدفتر
# بعد إنشاء نسختك، قم بإعادة تسميتها لتتضمن رقم الطالب الخاص بك:
#
# 1. انقر على اسم الدفتر في الأعلى (حالياً "Copy of Notebook_02_Control_Flow.ipynb")
# 2. أعد تسميته إلى: **`Notebook_02_Control_Flow_رقم_الطالب.ipynb`**
# 3. مثال: `Notebook_02_Control_Flow_12345678.ipynb`
#
# ### الخطوة 3: المشاركة للتقييم
# بعد إكمال جميع المهام، شارك دفترك مع المدرس:
#
# 1. انقر على زر **"Share"** (في الزاوية العلوية اليمنى)
# 2. أدخل البريد الإلكتروني للمدرس: **[instructor-email@university.edu]**
# 3. اضبط الصلاحية على **"Viewer"** أو **"Commenter"**
# 4. انقر على **"Send"**
#
# **⚠️ مهم:** تأكد من مشاركة **نسختك** من Google Drive، وليس النسخة الأصلية!
#
# ---
#
# </div>
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri&display=swap" rel="stylesheet">
#
# </details>

# %% [markdown]
# **Student Name:**
# **Student ID:**
# **Date:**

# %% [markdown]
# # 🎯 Control Flow & Decision Making in Python
#
# ## Learning Objectives
# By the end of this notebook, you will be able to:
# - ✅ Use the `input()` function to get user data
# - ✅ Convert user input to numbers (`int()`, `float()`)
# - ✅ Use `if` statements to make decisions in your code
# - ✅ Use `if-else` statements to provide alternative actions
# - ✅ Use `if-elif-else` for multiple conditions
# - ✅ Write nested conditional statements
# - ✅ Combine conditions using logical operators (`and`, `or`, `not`)
# - ✅ Apply decision-making to real-world problems with user input
#
# **⏱️ Estimated Time: 60 minutes**
#
# ---
#
# ## What is Control Flow?
#
# Control flow is the **order** in which your code executes. Instead of running every line sequentially, you can use conditional statements to:
# - Execute code **only if** certain conditions are true
# - Choose between **different paths** through your code
# - **Repeat** code multiple times
#
# This notebook focuses on **decision-making** using conditionals.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 16px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## أهداف التعلم
# بنهاية هذا الدفتر، ستكون قادراً على:
# - ✅ استخدام دالة `input()` للحصول على بيانات من المستخدم
# - ✅ تحويل إدخال المستخدم إلى أرقام (`int()`، `float()`)
# - ✅ استخدام جمل `if` لاتخاذ القرارات في الكود الخاص بك
# - ✅ استخدام جمل `if-else` لتوفير إجراءات بديلة
# - ✅ استخدام `if-elif-else` للعديد من الشروط
# - ✅ كتابة جمل شرطية متداخلة
# - ✅ دمج الشروط باستخدام عوامل منطقية (`and`، `or`، `not`)
# - ✅ تطبيق اتخاذ القرارات على المشاكل الحقيقية مع إدخال المستخدم
#
# **⏱️ الوقت المقدر: 60 دقيقة**
#
# ---
#
# ## ما هو التحكم في تدفق التنفيذ؟
#
# التحكم في تدفق التنفيذ هو **الترتيب** الذي يتم به تنفيذ الكود الخاص بك. بدلاً من تشغيل كل سطر بالتسلسل، يمكنك استخدام جمل شرطية من أجل:
# - تنفيذ الكود **فقط إذا** كان شرط معين صحيحاً
# - الاختيار بين **مسارات مختلفة** من خلال الكود الخاص بك
# - **تكرار** الكود عدة مرات
#
# يركز هذا الدفتر على **اتخاذ القرارات** باستخدام الجمل الشرطية.
#
# </div>
# </details>

# %% [markdown]
# ---
#
# ## 🎯 Essential Tool: The `input()` Function
#
# ### What is `input()`?
#
# The `input()` function allows your program to **ask the user for information**:
# - **Syntax**: `variable = input("Your question here")`
# - The user types their answer
# - The answer is **always stored as text (string)**
# - To use numbers, you must convert: `int(input(...))` or `float(input(...))`
#
# ### Examples:
#
# ```python
# # Get a name
# name = input("What is your name? ")
# print(f"Hello, {name}!")
#
# # Get a number (must convert to int)
# age = int(input("How old are you? "))
# print(f"You are {age} years old.")
#
# # Get a decimal number
# height = float(input("What is your height in meters? "))
# print(f"Your height is {height}m")
# ```
#
# ### Key Rules:
# 1. `input()` **always returns a string**
# 2. Use `int()` to convert to whole numbers
# 3. Use `float()` to convert to decimal numbers
# 4. The text inside `input("...")` appears as a **prompt** to the user

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 16px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### ما هي دالة `input()`؟
#
# دالة `input()` تسمح لبرنامجك **بطلب المعلومات من المستخدم**:
# - **الصيغة**: `variable = input("سؤالك هنا")`
# - يكتب المستخدم إجابته
# - يتم **تخزين الإجابة دائماً كنص (string)**
# - لاستخدام الأرقام، يجب عليك التحويل: `int(input(...))` أو `float(input(...))`
#
# ### أمثلة:
#
# ```python
# # الحصول على اسم
# name = input("ما هو اسمك؟ ")
# print(f"مرحبا، {name}!")
#
# # الحصول على رقم (يجب تحويله إلى int)
# age = int(input("كم عمرك؟ "))
# print(f"عمرك {age} سنة.")
#
# # الحصول على رقم عشري
# height = float(input("ما هو طولك بالمتر؟ "))
# print(f"طولك {height}م")
# ```
#
# ### القواعد الأساسية:
# 1. `input()` **يرجع دائماً نصاً**
# 2. استخدم `int()` للتحويل إلى أرقام صحيحة
# 3. استخدم `float()` للتحويل إلى أرقام عشرية
# 4. النص داخل `input("...")` يظهر كـ **سؤال** للمستخدم
#
# </div>
# </details>

# %%
# Example 1: Get user's name
name = input("What is your name? ")
print(f"Nice to meet you, {name}!")

# Example 2: Get user's age and check if it's a valid number
age_str = input("How old are you? ")
age = int(age_str)
print(f"In 10 years, you'll be {age + 10} years old.")

# Example 3: Get temperature in Celsius and convert
celsius = float(input("Enter temperature in Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print(f"{celsius}°C = {fahrenheit}°F")

# %% [markdown]
# ### 🎬 Practice Task: Using input()
#
# Write a program that:
# 1. Asks the user for their favorite color
# 2. Stores it in a variable
# 3. Prints back what they entered
#
# **Hint**: Use `input("What is your favorite color? ")`

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 16px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# اكتب برنامجاً يقوم بـ:
# 1. طلب لونك المفضل من المستخدم
# 2. تخزينه في متغير
# 3. طباعة ما أدخله المستخدم
#
# **تلميح**: استخدم `input("ما هو لونك المفضل؟ ")`
#
# </div>
# </details>

# %%
# Practice: Write your code here
# Ask user for favorite color and print it back

# %% [markdown]
# ## 📌 Concept 1: The `if` Statement
#
# ### What is an `if` Statement?
#
# An `if` statement allows your code to make a **decision**:
# - **Syntax**: `if condition:`
# - The code under `if` runs **only if** the condition is `True`
# - Conditions use **comparison operators**: `==`, `!=`, `>`, `<`, `>=`, `<=`
#
# ### Example:
# ```python
# age = 18
# if age >= 18:
#     print("You are an adult!")
# ```
#
# **Output**: `You are an adult!`
#
# ### How it Works:
# 1. Check the condition: `age >= 18` → `18 >= 18` → **True**
# 2. Since it's `True`, execute the indented code
# 3. Print the message

# %%
# Example 1: Simple if statement
score = int(input("Enter your test score: "))

if score >= 80:
    print("Great job! You passed!")
    print(f"Your score is {score}")

# Example 2: Check if a number is positive
number = int(input("Enter a number: "))

if number > 0:
    print(f"{number} is a positive number")

# Example 3: Check if something is in a list
fruits = ["apple", "banana", "orange"]
fruit_name = input("Are we looking for (apple/banana/orange)? ")

if fruit_name in fruits:
    print(f"We have {fruit_name}!")

# %% [markdown]
# ### 🎬 Task 1.1: Movie Rating
#
# A movie has a rating. Write an `if` statement that:
# - Checks if the rating is 8 or higher
# - If true, print: "This is a highly rated movie!"
#
# **Hint**: Use the variable `rating = 8.5`

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 16px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# اكتب جملة `if` تقوم بـ:
# - التحقق من أن التقييم 8 أو أعلى
# - إذا كان صحيحاً، اطبع: "هذا فيلم مقيم عالياً!"
#
# **تلميح**: استخدم `rating = float(input("أدخل تقييم الفيلم (0-10): "))`
#
# </div>
# </details>

# %%
# Task 1.1: Write your code here
rating = float(input("Enter the movie rating (0-10): "))

# Your if statement:

# %% [markdown]
# ---
#
# ## 📌 Concept 2: The `if-else` Statement
#
# ### What is `if-else`?
#
# Sometimes you want to do **something different** when the condition is false:
# - **Syntax**:
#   ```python
#   if condition:
#       # runs if True
#   else:
#       # runs if False
#   ```
#
# ### Example:
# ```python
# age = 16
# if age >= 18:
#     print("You can vote!")
# else:
#     print("You're too young to vote.")
# ```
#
# **Output**: `You're too young to vote.`
#
# ### How it Works:
# 1. Check: `age >= 18` → `16 >= 18` → **False**
# 2. Since it's `False`, skip the `if` block
# 3. Execute the `else` block
# 4. Print the message

# %%
# Example 1: Checking a password
correct_password = "secret123"
user_input = input("Enter password: ")

if user_input == correct_password:
    print("Access granted!")
else:
    print("Wrong password!")

# Example 2: Even or Odd
num = int(input("Enter a number: "))

if num % 2 == 0:
    print(f"{num} is even")
else:
    print(f"{num} is odd")

# Example 3: Weather decision
temperature = int(input("Enter temperature (°C): "))

if temperature > 20:
    print("It's warm! Go outside.")
else:
    print("It's cold. Stay inside.")

# %% [markdown]
# ### 🎬 Task 2.1: Login System
#
# Write an `if-else` statement that:
# - Checks if `username == "admin"`
# - If true, print: "Welcome, admin!"
# - If false, print: "You don't have permission."
#
# **Hint**: Use `username = "user"`

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 16px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# اكتب جملة `if-else` تقوم بـ:
# - التحقق من أن `username == "admin"`
# - إذا كان صحيحاً، اطبع: "مرحباً بك، مسؤول!"
# - إذا كان خاطئاً، اطبع: "ليس لديك صلاحية."
#
# **تلميح**: استخدم `username = input("أدخل اسم المستخدم: ")`
#
# </div>
# </details>

# %%
# Task 2.1: Write your code here
username = input("Enter username: ")

# Your if-else statement:

# %% [markdown]
# ---
#
# ## 📌 Concept 3: The `if-elif-else` Statement
#
# ### What is `if-elif-else`?
#
# When you have **multiple conditions** to check:
# - **Syntax**:
#   ```python
#   if condition1:
#       # runs if condition1 is True
#   elif condition2:
#       # runs if condition1 is False AND condition2 is True
#   else:
#       # runs if all conditions are False
#   ```
#
# ### Key Points:
# - **`elif`** = "else if" - check another condition
# - You can have **multiple `elif` blocks**
# - Only **one block executes** (the first true one)
#
# ### Example:
# ```python
# score = 75
# if score >= 90:
#     print("Grade: A")
# elif score >= 80:
#     print("Grade: B")
# elif score >= 70:
#     print("Grade: C")
# else:
#     print("Grade: F")
# ```
#
# **Output**: `Grade: C`

# %%
# Example 1: Traffic light
light = input("Enter light color (red/yellow/green): ")

if light == "red":
    print("STOP!")
elif light == "yellow":
    print("Prepare to stop")
elif light == "green":
    print("GO!")
else:
    print("Invalid light")

# Example 2: Size categorization
size = int(input("Enter a size (0-200): "))

if size < 30:
    print("Small")
elif size < 50:
    print("Medium")
elif size < 100:
    print("Large")
else:
    print("Extra Large")

# Example 3: Age groups
age = int(input("Enter your age: "))

if age < 13:
    print("Child")
elif age < 18:
    print("Teen")
elif age < 65:
    print("Adult")
else:
    print("Senior")

# %% [markdown]
# ### 🎬 Task 3.1: Student Grade
#
# Write an `if-elif-else` statement that assigns a grade letter based on score:
# - Score >= 90: "A"
# - Score >= 80: "B"
# - Score >= 70: "C"
# - Score >= 60: "D"
# - Score < 60: "F"
#
# **Hint**: Use `score = 85`. Print: `Grade: [letter]`

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 16px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# اكتب جملة `if-elif-else` تخصص حرف تقدير بناءً على الدرجة:
# - الدرجة >= 90: "أ"
# - الدرجة >= 80: "ب"
# - الدرجة >= 70: "ج"
# - الدرجة >= 60: "د"
# - الدرجة < 60: "ف"
#
# **تلميح**: استخدم `score = int(input("أدخل درجتك (0-100): "))`. اطبع: `التقدير: [حرف]`
#
# </div>
# </details>

# %%
# Task 3.1: Write your code here
score = int(input("Enter your test score (0-100): "))

# Your if-elif-else statement:

# %% [markdown]
# ---
#
# ## 📌 Concept 4: Nested Conditionals & Logical Operators
#
# ### What are Nested Conditionals?
#
# **Nested** means putting `if` statements **inside** other `if` statements:
#
# ```python
# if age >= 18:
#     if license:
#         print("You can drive!")
# ```
#
# ### Logical Operators for Complex Conditions
#
# Instead of nesting, you can use **logical operators**:
# - **`and`**: ALL conditions must be True
# - **`or`**: AT LEAST ONE condition must be True
# - **`not`**: Reverses True/False
#
# ### Examples:
#
# ```python
# # Using 'and'
# age = 20
# license = True
# if age >= 18 and license:
#     print("You can drive!")
#
# # Using 'or'
# is_student = True
# is_senior = False
# if is_student or is_senior:
#     print("Discount available!")
#
# # Using 'not'
# raining = False
# if not raining:
#     print("Go outside!")
# ```

# %%
# Example 1: Nested conditionals
balance = int(input("Enter your account balance ($): "))
amount = int(input("How much do you want to withdraw ($): "))

if amount > 0:
    if amount <= balance:
        print(f"Withdrawal approved! New balance: ${balance - amount}")
    else:
        print("Insufficient funds!")
else:
    print("Invalid amount!")

# Example 2: Using 'and'
temperature = int(input("Enter temperature (°C): "))
humidity = int(input("Enter humidity (%): "))

if temperature > 20 and humidity < 70:
    print("Perfect weather for outdoor activities!")

# Example 3: Using 'or'
print("Are you eligible for a discount?")
has_coupon = input("Do you have a coupon? (yes/no): ") == "yes"
is_member = input("Are you a member? (yes/no): ") == "yes"

if has_coupon or is_member:
    print("You get a discount!")

# Example 4: Using 'not'
is_broken = input("Is the machine broken? (yes/no): ") == "yes"

if not is_broken:
    print("Machine is working correctly.")

# %% [markdown]
# ### 🎬 Task 4.1: Movie Ticket Eligibility
#
# Write an `if-elif-else` with logical operators:
# - If age >= 18 AND has_ticket_money >= 12: Print "You can buy a ticket!"
# - Elif age < 18: Print "You need a parent to accompany you."
# - Else: Print "You don't have enough money."
#
# **Hint**: Use `age = 20` and `has_ticket_money = 15`

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 16px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# اكتب `if-elif-else` مع عوامل منطقية:
# - إذا كان العمر >= 18 **و** الأموال >= 12: اطبع "يمكنك شراء تذكرة!"
# - أم إذا كان العمر < 18: اطبع "تحتاج مرافق."
# - وإلا: اطبع "ليس لديك أموال كافية."
#
# **تلميح**: استخدم `age = int(input("أدخل عمرك: "))` و `has_ticket_money = int(input("كم أموالك ($): "))`
#
# </div>
# </details>

# %%
# Task 4.1: Write your code here
age = int(input("Enter your age: "))
has_ticket_money = int(input("How much money do you have ($): "))

# Your conditional statement:

# %% [markdown]
# ---
#
# ## 🏆 Capstone Project: Student Grade Report System
#
# ### Objective
# Create a **complete system** that analyzes student performance and provides actionable feedback.
#
# ### Requirements:
# 1. Input: `score` (0-100) and `attendance` (0-100)
# 2. Determine grade letter (A=90+, B=80+, C=70+, D=60+, F=<60)
# 3. Check if attendance is sufficient (>= 80%)
# 4. Provide feedback:
#    - **Good grade + Good attendance**: "Excellent work! Keep it up!"
#    - **Good grade + Poor attendance**: "Good grade, but improve attendance."
#    - **Poor grade + Good attendance**: "You attend well but need to study more."
#    - **Poor grade + Poor attendance**: "Both grades and attendance need improvement."
#
# ### Sample Output:
# ```
# Score: 85, Attendance: 90%
# Grade: B
# Feedback: Excellent work! Keep it up!
# ```

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 16px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### الهدف
# إنشاء **نظام كامل** يحلل أداء الطالب ويوفر ملاحظات قابلة للتنفيذ.
#
# ### المتطلبات:
# 1. الإدخال: `score` (0-100) و `attendance` (0-100)
# 2. تحديد حرف التقدير (A=90+, B=80+, C=70+, D=60+, F=<60)
# 3. التحقق من كفاية الحضور (>= 80%)
# 4. تقديم ملاحظات:
#    - **درجة جيدة + حضور جيد**: "عمل ممتاز! استمر!"
#    - **درجة جيدة + حضور سيء**: "درجة جيدة، لكن حسّن الحضور."
#    - **درجة ضعيفة + حضور جيد**: "تحضر بانتظام لكن تحتاج لدراسة أكثر."
#    - **درجة ضعيفة + حضور سيء**: "كل من الدرجات والحضور يحتاجان لتحسين."
#
# ### نموذج الإخراج:
# ```
# الدرجة: 85، الحضور: 90%
# التقدير: ب
# الملاحظات: عمل ممتاز! استمر!
# ```
#
# </div>
# </details>

# %%
# Capstone Project: Complete your solution here

score = int(input("Enter student score (0-100): "))
attendance = int(input("Enter attendance percentage (0-100): "))

# Step 1: Determine grade letter
if score >= 90:
    grade = "A"
elif score >= 80:
    grade = "B"
elif score >= 70:
    grade = "C"
elif score >= 60:
    grade = "D"
else:
    grade = "F"

# Step 2: Check attendance
good_grade = score >= 80
good_attendance = attendance >= 80

# Step 3: Provide feedback using nested conditionals
if good_grade and good_attendance:
    feedback = "Excellent work! Keep it up!"
elif good_grade and not good_attendance:
    feedback = "Good grade, but improve attendance."
elif not good_grade and good_attendance:
    feedback = "You attend well but need to study more."
else:
    feedback = "Both grades and attendance need improvement."

# Step 4: Display results
print(f"\n{'='*40}")
print(f"Score: {score}, Attendance: {attendance}%")
print(f"Grade: {grade}")
print(f"Feedback: {feedback}")
print(f"{'='*40}")

# %% [markdown]
# ### 🎯 Your Turn: Test Different Scenarios
#
# Modify the `score` and `attendance` variables above and run the code for different scenarios:
#
# 1. **High performer**: score=95, attendance=95
# 2. **Slacker**: score=55, attendance=40
# 3. **Hard worker with absences**: score=78, attendance=60
# 4. **Present but struggling**: score=65, attendance=92
#
# What feedback does each scenario generate?

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 16px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# عدّل متغيرات `score` و `attendance` أعلاه وشغّل الكود لسيناريوهات مختلفة:
#
# 1. **متفوق عالي**: score=95, attendance=95
# 2. **متكاسل**: score=55, attendance=40
# 3. **مجتهد مع الغياب**: score=78, attendance=60
# 4. **حاضر لكن يكافح**: score=65, attendance=92
#
# ما هي الملاحظات التي يولدها كل سيناريو؟
#
# </div>
# </details>

# %% [markdown]
# ---
#
# ## 📋 Key Takeaways
#
# | Concept | Syntax | Use Case |
# |---------|--------|----------|
# | **input()** | `variable = input("prompt")` | Get data from user (always a string) |
# | **int()** | `int(input(...))` | Convert string to integer |
# | **float()** | `float(input(...))` | Convert string to decimal number |
# | **if** | `if condition:` | Execute code only when condition is True |
# | **if-else** | `if condition: ... else: ...` | Choose between two options |
# | **if-elif-else** | `if c1: ... elif c2: ... else: ...` | Multiple conditions |
# | **and** | `condition1 and condition2` | ALL must be True |
# | **or** | `condition1 or condition2` | AT LEAST ONE must be True |
# | **not** | `not condition` | Reverse True/False |
#
# ## 🎓 What You Learned
#
# ✅ Use `input()` function to get user data
# ✅ Convert user input to numbers using `int()` and `float()`
# ✅ Use `if` statements for single conditions
#
# ✅ Use `if-else` for two-way decisions  ✅ Create interactive programs that respond to user input
#
# ✅ Use `if-elif-else` for multiple conditions  ✅ Build complex decision systems
# ✅ Combine conditions with `and`, `or`, `not`

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 16px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# | المفهوم | الصيغة | حالة الاستخدام |
# |--------|--------|----------|
# | **input()** | `variable = input("السؤال")` | الحصول على بيانات من المستخدم (نص دائماً) |
# | **int()** | `int(input(...))` | تحويل النص إلى عدد صحيح |
# | **float()** | `float(input(...))` | تحويل النص إلى رقم عشري |
# | **if** | `if condition:` | تنفيذ الكود فقط عندما يكون الشرط صحيحاً |
# | **if-else** | `if condition: ... else: ...` | الاختيار بين خيارين |
# | **if-elif-else** | `if c1: ... elif c2: ... else: ...` | عدة شروط |
# | **and** | `condition1 and condition2` | جميع الشروط يجب أن تكون صحيحة |
# | **or** | `condition1 or condition2` | على الأقل شرط واحد يجب أن يكون صحيحاً |
# | **not** | `not condition` | عكس True/False |
#
# ## 🎓 ما تعلمته
#
# ✅ استخدام دالة `input()` للحصول على بيانات من المستخدم
# ✅ تحويل إدخال المستخدم إلى أرقام باستخدام `int()` و `float()`
# ✅ استخدام جمل `if` للشروط الفردية
# ✅ استخدام `if-else` لقرارات ثنائية الاتجاه
# ✅ استخدام `if-elif-else` لعدة شروط
# ✅ دمج الشروط مع `and`, `or`, `not`
# ✅ بناء أنظمة قرارات معقدة
# ✅ إنشاء برامج تفاعلية تستجيب لإدخال المستخدم
#
# </div>
# </details>

# %% [markdown]
# ---
#
# ## 🧠 Visual Summary - Mindmap
# [![](https://mermaid.ink/img/pako:eNptU9uO2jAQ_ZWRH6pdCWhJIEDeKJdqJXZBkAqp4sWbDMRqYkeOs0AR_95xuCS0K0WWPXPmzJlLTixUETKfpUJGKc82EkArZZ6eRkoarRKYJmoPX2CMociFkvnzs8UA_MxRw4vMCnN5Awj7gGkhQ0PAmxVgmP--oLdKw5gbXnMle37MYYmm0DKHldFC7m7u4JghkIwP1PkDoZCm5FrHKkF4K9J3QlTubaL4BWBFpzy5-ogqElYaTygTN5iiNPc4sa2MFdeK9CRYhVaeQBf4dUrkCN81l2FcETXRWj9hC_YKFirPxTtxLriJa6onBwwLgzCXCCR9bmLUD5RX3iritUiMyOrqanRToXNTioS1qBxvmBuM6q2oxVALXmQuIqRbZR2plJIcqg24uGZqJ0Lq5DxDzY2qBsBldDfWJj2b1XSWwm5OW-3_-ABmk-EqgPnb5AEtlfkEvkS7JTQKRSvBr2NaIk-aa6WTCIZZlpDchybZCiSsjtSR9G78oTnVv8RM6Wo3hsErddHEkeb7WsfWyO2U_u3M5d9ojrX4QAkLrXaalwnuH1yA9mQNttMiYr6hGhssRZ1y-2SnEscoQYob5tM1wi2nkW_YRp4pLOPyl1LpLVKrYhczf2s3ssGKLKLtGwtuc9-tGmWEeqQKaZjv9QYlCfNP7MD8ZsdxW4Oe0-596w56Hc_tNtiRzG635fQdz3MGXcd1On333GB_yrztluc47b7X7rs9Opzu4PwX8txUKw?type=png)](https://mermaid.live/edit#pako:eNptU9uO2jAQ_ZWRH6pdCWhJIEDeKJdqJXZBkAqp4sWbDMRqYkeOs0AR_95xuCS0K0WWPXPmzJlLTixUETKfpUJGKc82EkArZZ6eRkoarRKYJmoPX2CMociFkvnzs8UA_MxRw4vMCnN5Awj7gGkhQ0PAmxVgmP--oLdKw5gbXnMle37MYYmm0DKHldFC7m7u4JghkIwP1PkDoZCm5FrHKkF4K9J3QlTubaL4BWBFpzy5-ogqElYaTygTN5iiNPc4sa2MFdeK9CRYhVaeQBf4dUrkCN81l2FcETXRWj9hC_YKFirPxTtxLriJa6onBwwLgzCXCCR9bmLUD5RX3iritUiMyOrqanRToXNTioS1qBxvmBuM6q2oxVALXmQuIqRbZR2plJIcqg24uGZqJ0Lq5DxDzY2qBsBldDfWJj2b1XSWwm5OW-3_-ABmk-EqgPnb5AEtlfkEvkS7JTQKRSvBr2NaIk-aa6WTCIZZlpDchybZCiSsjtSR9G78oTnVv8RM6Wo3hsErddHEkeb7WsfWyO2U_u3M5d9ojrX4QAkLrXaalwnuH1yA9mQNttMiYr6hGhssRZ1y-2SnEscoQYob5tM1wi2nkW_YRp4pLOPyl1LpLVKrYhczf2s3ssGKLKLtGwtuc9-tGmWEeqQKaZjv9QYlCfNP7MD8ZsdxW4Oe0-596w56Hc_tNtiRzG635fQdz3MGXcd1On333GB_yrztluc47b7X7rs9Opzu4PwX8txUKw)
