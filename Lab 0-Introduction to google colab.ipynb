# %% [markdown]
# # Getting Started with Your Python Coding Environment
#
# ⏱ Estimated time: 30–45 minutes
# 🎯 Purpose: Learn how to use Google Colab as a coding environment

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 10px; background-color: #F5F5F5; border-radius: 5px;">
#
# # ابدأ مع بيئة الترميز بلغة Python الخاصة بك
#
# ⏱ الوقت المقدر: 30-45 دقيقة
# 🎯 الهدف: تعلم كيفية استخدام Google Colab كبيئة ترميز
#
# </div>
# </details>

# %% [markdown]
# ✅ Learning Objectives
#
# By the end of this lab, you will be able to:
#
#     - Open and save notebooks in Google Colab
#     - Understand cells (code vs markdown)
#     - Run Python code
#     - Edit and add new cells
#     - Fix and re‑run code after errors
#     - Use Colab for future Python labs

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 10px; background-color: #F5F5F5; border-radius: 5px;">
#
# ✅ أهداف التعلم
#
# بنهاية هذا المختبر، ستكون قادراً على:
#
# - فتح وحفظ دفاتر الملاحظات في Google Colab
# - فهم الخلايا (الكود مقابل Markdown)
# - تشغيل كود Python
# - تحرير وإضافة خلايا جديدة
# - إصلاح وإعادة تشغيل الكود بعد الأخطاء
# - استخدام Colab للمختبرات المستقبلية
#
# </div>
# </details>

# %% [markdown]
# 🌐 What Is Google Colab?
#
# Google Colab is an online tool that lets you:
#
#     - Write and run Python code in your browser
#     - Use Jupyter Notebooks without installing anything
#     - Save your work to Google Drive
#
# You only need:
# ✅ A Google account
# ✅ A web browser

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 10px; background-color: #F5F5F5; border-radius: 5px;">
#
# 🌐 ما هو Google Colab؟
#
# Google Colab هي أداة عبر الإنترنت تتيح لك:
#
# - كتابة وتشغيل كود Python في متصفحك
# - استخدام Jupyter Notebooks بدون تثبيت أي شيء
# - حفظ عملك على Google Drive
#
# كل ما تحتاجه:
# ✅ حساب Google
# ✅ متصفح ويب
#
# </div>
# </details>

# %% [markdown]
# 🚀 Opening Google Colab
# Step 1
#
# Go to:
# 👉 https://colab.research.google.com
# Step 2
#
# Click:
#
#     New Notebook
#
# You are now ready to code 🎉

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 10px; background-color: #F5F5F5; border-radius: 5px;">
#
# 🚀 فتح Google Colab
# الخطوة 1
#
# اذهب إلى:
# 👉 https://colab.research.google.com
#
# الخطوة 2
#
# انقر على:
#
# ```
# New Notebook (دفتر ملاحظات جديد)
# ```
#
# أنت الآن جاهز للبرمجة 🎉
#
# </div>
# </details>

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 10px; background-color: #F5F5F5; border-radius: 5px;">
#
# ### خليتك الأولى
#
# انسخ الكود التالي وشغله:
#
# ```python
# print("تحياتي من Google Colab!")
# ```
#
# **كيفية التشغيل:**
# - انقر على الزر ▶️ على يسار الخلية
# - أو اضغط Ctrl+Enter (Windows) أو Cmd+Enter (Mac)
#
# أرسل لنا النتيجة! 🎉
#
# </div>
# </details>

# %% [markdown]
# 📓 Understanding the Notebook Interface
#
# A notebook is made of cells.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 10px; background-color: #F5F5F5; border-radius: 5px;">
#
# ## فهم واجهة دفتر الملاحظات
#
# 1. **شريط الأدوات:** في الأعلى، توجد أزرار لإضافة الخلايا وتشغيلها
# 2. **منطقة الخلايا:** المكان الذي تكتب فيه الكود أو النصوص
# 3. **زر التشغيل:** ▶️ يقع على يسار كل خلية (انقر لتشغيل الكود)
#
# الآن دعنا نجرب ذلك! ⚡
#
# </div>
# </details>

# %% [markdown]
# Two main types of cells:
# |Cell Type	| Purpose|
# |-----------|---------|
# |**Code**	|Run Python code|
# |**Markdown**	|Write text, instructions, notes|

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 10px; background-color: #F5F5F5; border-radius: 5px;">
#
# ## نوعا الخلايا الرئيسيتان
#
# | نوع الخلية | الاستخدام | مثال |
# |-----------|----------|------|
# | **خلية الكود** 💻 | تكتب وتشغل الكود البرمجي | `print("Hello")` |
# | **خلية Markdown** 📝 | تكتب النصوص والتوضيحات | # هذا عنوان |
#
# **اختر النوع الذي تريد من القائمة العلوية!**
#
# </div>
# </details>

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 10px; background-color: #F5F5F5; border-radius: 5px;">
#
# ### جرّب هذا:
#
# اكتب هذا الكود في خلية جديدة:
#
# ```python
# name = "يا ساعد"
# age = 15
# print(f"أنا {name} وعمري {age} سنة")
# ```
#
# ثم شغله وشاهد النتيجة! 🚀
#
# </div>
# </details>

# %% [markdown]
# ▶️ Your First Code Cell
#
# Click inside the cell below and press:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 10px; background-color: #F5F5F5; border-radius: 5px;">
#
# ### خلايا Markdown
#
# خلايا Markdown تستخدم لكتابة النصوص والشرح والتوثيق بدلاً من الكود.
#
# يمكنك استخدام:
# - **نصوص سميكة** باستخدام `**نص**`
# - *نصوص مائلة* باستخدام `*نص*`
# - `كود مضمن` باستخدام العلامات العكسية
#
# جرّب كتابة بعض النصوص المنسقة الآن! 📝
#
# </div>
# </details>

# %%
print("Hello from Google Colab!")

# %% [markdown]
# ➕ Adding and Editing Cells
# Try This:
#
#     1. Click + Code (top of the page)
#     2. In the new cell, type:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 10px; background-color: #F5F5F5; border-radius: 5px;">
#
# ### إضافة وتحرير الخلايا
#
# **لإضافة خلية جديدة:**
# - انقر على الزر **+ Code** أو **+ Text** في أعلى الدفتر
# - أو انقر على اختصار الخلية المرغوبة
#
# **لحذف خلية:**
# - انقر على ⋮ (الثلاث نقاط) على يمين الخلية واختر Delete
#
# </div>
# </details>

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 10px; background-color: #F5F5F5; border-radius: 5px;">
#
# ### تجربة Shift+Enter
#
# **اضغط Shift+Enter** لتشغيل الخلية الحالية والانتقال للخلية التالية مباشرة.
#
# يمكنك أيضاً:
# - اضغط **Ctrl+Enter** (أو **Cmd+Enter** على Mac) لتشغيل الخلية فقط
# - اضغط **Alt+Enter** لتشغيل الخلية وإضافة خلية جديدة بعدها
#
# </div>
# </details>

# %% [markdown]
# ```python
# print("This is a new code cell")

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 10px; background-color: #F5F5F5; border-radius: 5px;">
#
# ### مثال على كود Python
#
# إليك مثال بسيط على كود Python:
#
# ```python
# # هذا تعليق
# x = 5
# y = 3
# z = x + y
# print(f"النتيجة: {z}")
# ```
#
# شغل الخلية السابقة لترى النتيجة! 🎯
#
# </div>
# </details>

# %% [markdown]
#     3. Run the cell

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 10px; background-color: #F5F5F5; border-radius: 5px;">
#
# ### المهمة الأولى 📋
#
# **اكتب كود Python يفعل الآتي:**
#
# 1. أنشئ متغير باسم `student_name` وضع فيه اسمك
# 2. أنشئ متغير باسم `grade` وضع فيه درجتك المفضلة (من 0 إلى 100)
# 3. اطبع جملة تقول: "اسمي هو [الاسم] وأحب الدرجة [الدرجة]"
#
# **التلميح:** استخدم `print()` و `f-string`
#
# </div>
# </details>

# %% [markdown]
# ✏️ Task 1: Edit and Run Code
# ✅ Student Cell

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 10px; background-color: #F5F5F5; border-radius: 5px;">
#
# ### المهمة الثانية 🎨
#
# **أنشئ خلية Markdown جديدة وفعل الآتي:**
#
# 1. أضف عنوان يقول: "معلومات عني"
# 2. اكتب فقرة قصيرة عن نفسك (اسمك، هواياتك، أحلامك)
# 3. استخدم **نصوص سميكة** و *نصوص مائلة* لتجميل النص
# 4. أضف قائمة من اهتماماتك
#
# **تذكر:** خلايا Markdown لا تحتاج إلى `print()` - فقط نص ذي صيغة!
#
# </div>
# </details>

# %%
# Change the message below to include your name
print("Hello, my name is ...")

# %% [markdown]
# 📝 Markdown Cells (Text Cells)
#
# Markdown cells are used for:
#
#     - Instructions
#     - Notes
#     - Explanations

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 10px; background-color: #F5F5F5; border-radius: 5px;">
#
# ### مخزنك السحابي الشخصي ☁️
#
# بعض الفوائد المذهلة لـ Google Colab:
#
# - **مجاني تماماً** - لا تحتاج لدفع شيء
# - **على السحابة** - يعمل من أي مكان وفي أي وقت
# - **سهل الاستخدام** - واجهة بسيطة وسهلة الفهم
# - **معالج قوي** - يمكنه تشغيل أكواد معقدة بسرعة
# - **مدمج مع Python** - لا حاجة لتثبيت شيء
#
# هيا بنا نبدأ! 🚀
#
# </div>
# </details>

# %% [markdown]
# # Try This:
#
#     1. Click + Text
#     2. Type:

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 10px; background-color: #F5F5F5; border-radius: 5px;">
#
# ### نصائح مهمة لـ Google Colab ⚡
#
# **تشغيل الخلايا:**
# - استخدم ▶️ لتشغيل خلية واحدة
# - استخدم **Ctrl+Enter** لتشغيل الخلية الحالية
# - استخدم **Shift+Enter** لتشغيل والانتقال للتالية
#
# **اختصارات مفيدة:**
# - **Ctrl+M** ثم **C**: نسخ خلية
# - **Ctrl+M** ثم **X**: قطع خلية
# - **Ctrl+M** ثم **V**: لصق خلية
# - **Ctrl+M** ثم **D**: حذف خلية
#
# حفظ عملك بانتظام! 💾
#
# </div>
# </details>

# %% [markdown]
# ## My First Colab Notebook
# This is my first experience using Google Colab.

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 10px; background-color: #F5F5F5; border-radius: 5px;">
#
# ## مبروك! 🎉
#
# أنت الآن جاهز لبدء رحلتك البرمجية!
#
# **في الخطوات التالية:**
# - ستتعلم أساسيات لغة Python
# - ستكتب برامج حقيقية
# - ستحل مشاكل باستخدام الكود
#
# </div>
# </details>

# %% [markdown]
#     3. Press Shift + Enter

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 10px; background-color: #F5F5F5; border-radius: 5px;">
#
# ### ملخص سريع:
#
# Google Colab هو محرر أكواد قوي وسهل يعمل على الإنترنت. يمكنك:
# - كتابة وتشغيل أكواد Python
# - حفظ عملك تلقائياً
# - التعاون مع الآخرين
# - استخدام مكتبات قوية
#
# الآن أنت جاهز! 🚀
#
# </div>
# </details>

# %% [markdown]
# ✏️ Task 2: Create a Markdown Cell
# ✅ Instruction (No Code)
#
# Create a Markdown cell that includes:
#
#     1. A heading with your name
#     2. One sentence about how you feel learning Python

# %% [markdown]
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 10px; background-color: #F5F5F5; border-radius: 5px;">
#
# ### النقاط الرئيسية 📌
#
# ✅ Google Colab مجاني وسهل
# ✅ خليتان: كود و نصوص
# ✅ شغل الكود بـ ▶️ أو Ctrl+Enter
# ✅ استخدم Markdown لكتابة نصوص جميلة
# ✅ احفظ عملك تلقائياً
# ✅ يمكنك التعاون مع الآخرين
#
# **الآن ابدأ بـ Notebook_01_Python_Basics.ipynb** 💪
#
# </div>
# </details>
