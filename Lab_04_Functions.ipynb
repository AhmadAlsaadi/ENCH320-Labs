# %% [markdown]
# ## 📝 Important Instructions for Students
#
# ### Step 1: Make Your Own Copy
# When you open this notebook in Google Colab, you will be viewing a **read-only** version. To complete the assignments, you must:
#
# 1. Click **"File" → "Save a copy in Drive"** from the menu
# 2. This creates your personal copy in your Google Drive
# 3. Work on **your copy only** - all your answers will be saved there automatically
#
# ### Step 2: Rename Your Notebook
# After creating your copy, rename it to include your student ID:
#
# 1. Click on the notebook name at the top (currently "Copy of Lab_04_Functions.ipynb")
# 2. Rename it to: **`Lab_04_Functions_YourStudentID.ipynb`**
# 3. Example: `Lab_04_Functions_12345678.ipynb`
#
# ### Step 3: Add Your Information right after these instructions
#
# ### Step 4: Share for Grading
# After completing all tasks, share your notebook with the instructor:
#
# 1. Click the **"Share"** button (top-right corner)
# 2. Enter instructor's email: **ahmad.alsaadi@kaust.edu.sa**
# 3. Set permission to **"Editor"**
# 4. Click **"Send"**
#
# **⚠️ Important:** Make sure to share **your copy** from Google Drive, not the original!
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## 📝 تعليمات مهمة للطلاب
#
# ### الخطوة 1: إنشاء نسخة خاصة بك
# عند فتح هذا الدفتر في Google Colab، ستشاهد نسخة **للقراءة فقط**. لإكمال المهام، يجب عليك:
#
# 1. انقر على **"File" ← "Save a copy in Drive"** من القائمة
# 2. سيتم إنشاء نسخة شخصية في Google Drive الخاص بك
# 3. اعمل على **نسختك فقط** - سيتم حفظ جميع إجاباتك تلقائياً
#
# ### الخطوة 2: إعادة تسمية الدفتر
# بعد إنشاء نسختك، قم بإعادة تسميتها لتتضمن رقم الطالب الخاص بك:
#
# 1. انقر على اسم الدفتر في الأعلى (حالياً "Copy of Lab_04_Functions.ipynb")
# 2. أعد تسميته إلى: **`Lab_04_Functions_رقم_الطالب.ipynb`**
# 3. مثال: `Lab_04_Functions_12345678.ipynb`
#
# ### الخطوة 3: أضف معلوماتك مباشرة بعد هذه التعليمات
#
# ### الخطوة 4: المشاركة للتقييم
# بعد إكمال جميع المهام، شارك دفترك مع المدرس:
#
# 1. انقر على زر **"Share"** (في الزاوية العلوية اليمنى)
# 2. أدخل البريد الإلكتروني للمدرس: **ahmad.alsaadi@kaust.edu.sa**
# 3. اضبط الصلاحية على **"Editor"**
# 4. انقر على **"Send"**
#
# **⚠️ مهم:** تأكد من مشاركة **نسختك** من Google Drive، وليس النسخة الأصلية!
#
# </div>
#
# </details>

# %% [markdown]
# **Student Name:**
# **Student ID:**
# **Date:**

# %% [markdown]
# # Lab 04: Functions — Reusable Code in Micro Steps
#
# ## Learning Objectives
# By the end of this lab, you will be able to:
# - Define and call functions
# - Use parameters and arguments
# - Return values (single and multiple)
# - Use default parameters
# - Explain local vs global scope
# - Use built-in functions like `len`, `min`, `max`, and `sum`
# - Write docstrings and simple type hints
# - Apply basic function best practices
#
# **⏱️ Estimated time: 60–75 minutes**
#
# ---
#
# ## How this lab works
# Each micro-lesson includes:
# 1. A short idea (2–4 minutes)
# 2. A tiny example
# 3. A Quick Check (predict the output)
# 4. A Try It task (edit/run code)
#
# ---
#
# ## Micro-Lesson 1: Define and Call a Function
# A **function** is a named block of code you can reuse.
#
# **Goal:** Create a function and call it twice.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# # معمل 04: الدوال — كود قابل لإعادة الاستخدام بخطوات صغيرة
#
# ## أهداف التعلم
# بنهاية هذا المختبر، ستكون قادراً على:
# - تعريف الدوال واستدعاؤها
# - استخدام المعاملات والوسيطات
# - إرجاع القيم (قيمة واحدة أو عدة قيم)
# - استخدام المعاملات الافتراضية
# - شرح نطاق المتغيرات (محلي/عام)
# - استخدام الدوال المدمجة مثل `len` و `min` و `max` و `sum`
# - كتابة توثيق للدوال وإشارات نوع بسيطة
# - تطبيق أفضل الممارسات الأساسية
#
# **⏱️ الوقت المقدر: 60–75 دقيقة**
#
# ---
#
# ## كيف يعمل هذا المختبر
# كل درس مصغر يحتوي على:
# 1. فكرة قصيرة (2–4 دقائق)
# 2. مثال صغير
# 3. تحقق سريع (توقع الناتج)
# 4. مهمة جرّبها (عدّل الكود وشغّله)
#
# ---
#
# ## الدرس المصغر 1: تعريف الدالة واستدعاؤها
# **الدالة** هي كتلة كود باسم يمكن إعادة استخدامها.
#
# **الهدف:** أنشئ دالة واستدعها مرتين.
#
# </div>
# </details>

# %%
# Simple function with no parameters
def greet():
    print("Hello! Welcome to Python.")

# Call the function
greet()
greet()

# %% [markdown]
# ---
#
# ## Micro-Lesson 2: One Parameter
# A **parameter** lets a function receive data.
#
# **Quick Check:** What will `greet_person("Lina")` print?
#
# **Try It:** Call `greet_person` with your name.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## الدرس المصغر 2: معامل واحد
# **المعامل** يسمح للدالة باستقبال بيانات.
#
# **تحقق سريع:** ماذا سيطبع `greet_person("Lina")`؟
#
# **جرّبها:** استدعِ `greet_person` باسمك.
#
# </div>
# </details>

# %%
# Function with one parameter
def greet_person(name):
    print(f"Hello, {name}!")

greet_person("Alice")
greet_person("Bob")

# %% [markdown]
# ### Micro-Lesson 2.1: Multiple Parameters
# Use multiple parameters to pass more than one value.
#
# **Quick Check:** What is the area of a rectangle for `length=4` and `width=7`?
#
# **Try It:** Add one more call with different numbers.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### الدرس المصغر 2.1: عدة معاملات
# استخدم عدة معاملات لتمرير أكثر من قيمة.
#
# **تحقق سريع:** ما مساحة المستطيل عند `length=4` و `width=7`؟
#
# **جرّبها:** أضف استدعاءً آخر بأرقام مختلفة.
#
# </div>
# </details>

# %%
# Function with multiple parameters
def calculate_area(length, width):
    area = length * width
    print(f"Area: {length} x {width} = {area}")

calculate_area(5, 10)
calculate_area(3, 8)

# %% [markdown]
# ---
#
# ## Micro-Lesson 3: Return Values
# `return` sends a value back to the caller so you can store or print it.
#
# **Quick Check:** What is `add_numbers(2, 5)`?
#
# **Try It:** Change the inputs and predict the new result.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## الدرس المصغر 3: قيم الإرجاع
# كلمة `return` تعيد قيمة إلى من استدعى الدالة لكي نخزنها أو نطبعها.
#
# **تحقق سريع:** ما نتيجة `add_numbers(2, 5)`؟
#
# **جرّبها:** غيّر المدخلات وتوقع النتيجة.
#
# </div>
# </details>

# %%
# Function that returns a value
def add_numbers(a, b):
    result = a + b
    return result

sum1 = add_numbers(5, 3)
sum2 = add_numbers(10, 20)

print(f"Sum 1: {sum1}")
print(f"Sum 2: {sum2}")

# %% [markdown]
# ### Micro-Lesson 3.1: Built-in Functions
# Python includes built-in functions like `len`, `min`, `max`, and `sum`.
#
# **Quick Check:** What is `len(numbers)` for the list below?
#
# **Try It:** Change the list and predict the new `min` and `max`.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### الدرس المصغر 3.1: دوال بايثون المدمجة
# تحتوي بايثون على دوال مدمجة مفيدة مثل `len` و `min` و `max` و `sum`.
#
# **تحقق سريع:** ما قيمة `len(numbers)` للقائمة أدناه؟
#
# **جرّبها:** غيّر القائمة وتوقع القيم الجديدة لـ `min` و `max`.
#
# </div>
# </details>

# %%
# Built-in functions in action
numbers = [12, 5, 9, 21, 7]

print(f"Numbers: {numbers}")
print(f"len: {len(numbers)}")
print(f"min: {min(numbers)}")
print(f"max: {max(numbers)}")
print(f"sum: {sum(numbers)}")

# %% [markdown]
# ### Micro-Lesson 3.2: Returning Multiple Values
# You can return multiple values as a **tuple**.
#
# **Quick Check:** What do `minimum` and `maximum` become for the list shown?
#
# **Try It:** Change the list and check the new min/max.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### الدرس المصغر 3.2: إرجاع عدة قيم
# يمكنك إرجاع عدة قيم على شكل **tuple**.
#
# **تحقق سريع:** ما قيمتا `minimum` و `maximum` للقائمة المعروضة؟
#
# **جرّبها:** غيّر القائمة وتحقق من أصغر وأكبر قيمة.
#
# </div>
# </details>

# %%
# Function returning multiple values as a tuple
def get_min_max(numbers):
    min_val = min(numbers)
    max_val = max(numbers)
    return min_val, max_val

numbers = [45, 23, 89, 12, 67]
minimum, maximum = get_min_max(numbers)

print(f"Numbers: {numbers}")
print(f"Min: {minimum}, Max: {maximum}")

# %% [markdown]
# ---
#
# ## Micro-Lesson 4: Default Parameters
# Default values make functions flexible when a value is optional.
#
# **Quick Check:** What is `power(5)`? Why?
#
# **Try It:** Call `power(2, 5)` and predict the result.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## الدرس المصغر 4: المعاملات الافتراضية
# القيم الافتراضية تجعل الدالة مرنة عندما تكون بعض القيم اختيارية.
#
# **تحقق سريع:** ما ناتج `power(5)`؟ ولماذا؟
#
# **جرّبها:** استدعِ `power(2, 5)` وتوقع الناتج.
#
# </div>
# </details>

# %%
# Function with default parameters
def power(base, exponent=2):
    return base ** exponent

# Called with both parameters
print(f"5^2 = {power(5, 2)}")

# Called with default exponent
print(f"5^2 (default) = {power(5)}")
print(f"3^3 = {power(3, 3)}")

# %% [markdown]
# ---
#
# ## Micro-Lesson 5: Variable Scope
# - **Local** variables live inside a function.
# - **Global** variables live outside all functions.
#
# **Quick Check:** Which variable can be printed outside the function?
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## الدرس المصغر 5: نطاق المتغيرات
# - المتغير **المحلي** يعيش داخل الدالة.
# - المتغير **العام** يعيش خارج جميع الدوال.
#
# **تحقق سريع:** أي متغير يمكن طباعته خارج الدالة؟
#
# </div>
# </details>

# %%
# Global variable
global_var = "I'm global"

def my_function():
    # Local variable
    local_var = "I'm local"
    print(f"Inside function: {local_var}")
    print(f"Inside function: {global_var}")

my_function()

print(f"Outside function: {global_var}")
# print(local_var)  # This would cause an error!

# %% [markdown]
# ### Micro-Lesson 5.1: Modifying a Global Variable
# Use the `global` keyword **only** when you truly need to update a global variable.
#
# **Quick Check:** What will `counter` be after two calls to `increment()`?
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### الدرس المصغر 5.1: تعديل متغير عام
# استخدم كلمة `global` **فقط** عند الحاجة لتعديل متغير عام.
#
# **تحقق سريع:** ما قيمة `counter` بعد استدعاء `increment()` مرتين؟
#
# </div>
# </details>

# %%
# Working with global variables
counter = 0

def increment():
    global counter
    counter += 1

print(f"Initial counter: {counter}")
increment()
print(f"After increment: {counter}")
increment()
print(f"After second increment: {counter}")

# %% [markdown]
# ---
#
# ## Micro-Lesson 6: Docstrings and Type Hints
# A **docstring** explains what the function does. Type hints show expected input/output types.
#
# **Quick Check:** What does the docstring say for `celsius_to_fahrenheit`?
#
# **Try It:** Change the input to 25°C and predict the output.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## الدرس المصغر 6: التوثيق وإشارات النوع
# **سلسلة التوثيق** تشرح ما تفعله الدالة. وإشارات النوع توضح نوع المدخلات والمخرجات.
#
# **تحقق سريع:** ماذا تقول سلسلة التوثيق لـ `celsius_to_fahrenheit`؟
#
# **جرّبها:** غيّر الإدخال إلى 25°C وتوقع الناتج.
#
# </div>
# </details>

# %%
# Function with docstring and type hints
def celsius_to_fahrenheit(celsius: float) -> float:
    """
    Convert temperature from Celsius to Fahrenheit.
    
    Parameters:
    celsius (float): Temperature in Celsius
    
    Returns:
    float: Temperature in Fahrenheit
    """
    fahrenheit = (celsius * 9/5) + 32
    return fahrenheit

# Access the docstring
print(celsius_to_fahrenheit.__doc__)
print(f"0°C = {celsius_to_fahrenheit(0)}°F")

# %% [markdown]
# ---
#
# ## Micro-Lesson 7: Function Best Practices
# Good functions are:
# - Short and focused
# - Clear names
# - Clear inputs and outputs
#
# **Quick Check:** Why does `calculate_average` return 0 for an empty list?
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## الدرس المصغر 7: أفضل ممارسات الدوال
# الدالة الجيدة تكون:
# - قصيرة ومركزة
# - باسم واضح
# - بمدخلات ومخرجات واضحة
#
# **تحقق سريع:** لماذا تُرجع `calculate_average` القيمة 0 عند قائمة فارغة؟
#
# </div>
# </details>

# %%
# Good function example
from typing import List

def calculate_average(numbers: List[float]) -> float:
    """
    Calculate the average of a list of numbers.
    
    Args:
        numbers (list): A list of numeric values
    
    Returns:
        float: The average of the numbers
    """
    if len(numbers) == 0:
        return 0
    
    total = sum(numbers)
    average = total / len(numbers)
    return average

grades = [85, 90, 78, 92, 88]
avg = calculate_average(grades)
print(f"Average grade: {avg:.2f}")

# %% [markdown]
# ---
#
# ## ✅ Micro-Exercises
# Complete each task in the code cell directly below it. Keep your solutions short and readable.
#
# **Tip:** Use the provided test calls to check your work.
#
# ### Exercise 1: Simple Greeting
# Create a function `greet_formal(name)` that prints a formal greeting.
#
# **Example output:** `Good day, Ms. Johnson`
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## ✅ تمارين مصغرة
# أكمل كل مهمة في خلية الكود التي تليها مباشرة. حافظ على الحلول قصيرة وواضحة.
#
# **نصيحة:** استخدم استدعاءات الاختبار المرفقة للتحقق من الحل.
#
# ### التمرين 1: تحية رسمية
# أنشئ دالة `greet_formal(name)` تطبع تحية رسمية.
#
# **مثال للناتج:** `Good day, Ms. Johnson`
#
# </div>
# </details>

# %%
# TODO: Exercise 1 - Simple greeting function


# Test your function
# greet_formal("Johnson")

# %% [markdown]
# ### Exercise 2: Discount Calculator
# Create a function `calculate_discount(price, discount_percent)` that returns the final price.
#
# **Quick Check:** What should `calculate_discount(100, 20)` return?
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### التمرين 2: حساب الخصم
# أنشئ دالة `calculate_discount(price, discount_percent)` تعيد السعر النهائي.
#
# **تحقق سريع:** ما الناتج المتوقع لـ `calculate_discount(100, 20)`؟
#
# </div>
# </details>

# %%
# TODO: Exercise 2 - Discount calculator


# Test your function
# final_price = calculate_discount(100, 20)
# print(f"Final price: ${final_price}")

# %% [markdown]
# ### Exercise 3: Multiple Returns
# Create a function `get_student_info(name, grade)` that returns:
# 1. The name in uppercase
# 2. Whether the student passed (`grade >= 60`)
#
# **Example:** `get_student_info("alice", 75)` returns `("ALICE", True)`
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### التمرين 3: إرجاع عدة قيم
# أنشئ دالة `get_student_info(name, grade)` تعيد:
# 1. الاسم بحروف كبيرة
# 2. هل الطالب ناجح؟ (`grade >= 60`)
#
# **مثال:** `get_student_info("alice", 75)` تعيد `("ALICE", True)`
#
# </div>
# </details>

# %%
# TODO: Exercise 3 - Student info function


# Test your function
# name_upper, passed = get_student_info("alice", 75)
# print(f"Name: {name_upper}, Passed: {passed}")

# %% [markdown]
# ### Exercise 4: Default Parameter
# Create a function `calculate_tax(amount, tax_rate=0.1)` that returns the total including tax.
#
# **Examples:**
# - `calculate_tax(100)` → `110`
# - `calculate_tax(100, 0.2)` → `120`
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### التمرين 4: معامل افتراضي
# أنشئ دالة `calculate_tax(amount, tax_rate=0.1)` تعيد المجموع مع الضريبة.
#
# **أمثلة:**
# - `calculate_tax(100)` → `110`
# - `calculate_tax(100, 0.2)` → `120`
#
# </div>
# </details>

# %%
# TODO: Exercise 4 - Tax calculator with default


# Test your function
# print(calculate_tax(100))
# print(calculate_tax(100, 0.2))

# %% [markdown]
# ### Exercise 5: Email Validation
# Create a function `is_valid_email(email)` that returns `True` if the email contains **exactly one** `@`.
#
# **Examples:**
# - `user@example.com` → `True`
# - `user@@example.com` → `False`
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### التمرين 5: التحقق من البريد الإلكتروني
# أنشئ دالة `is_valid_email(email)` تعيد `True` إذا احتوى البريد على رمز `@` مرة واحدة فقط.
#
# **أمثلة:**
# - `user@example.com` → `True`
# - `user@@example.com` → `False`
#
# </div>
# </details>

# %%
# TODO: Exercise 5 - Email validation


# Test your function
# print(is_valid_email("user@example.com"))
# print(is_valid_email("invalid.email"))
# print(is_valid_email("user@@example.com"))

# %% [markdown]
# ### Exercise 6: Find Duplicates
# Create a function `find_duplicates(items)` that returns a list of duplicate values.
#
# **Example:** `find_duplicates([1, 2, 2, 3, 3, 3, 4])` returns `[2, 3]`
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### التمرين 6: إيجاد القيم المكررة
# أنشئ دالة `find_duplicates(items)` تعيد قائمة بالقيم المكررة.
#
# **مثال:** `find_duplicates([1, 2, 2, 3, 3, 3, 4])` تعيد `[2, 3]`
#
# </div>
# </details>

# %%
# TODO: Exercise 6 - Find duplicates


# Test your function
# test_list = [1, 2, 2, 3, 3, 3, 4]
# print(find_duplicates(test_list))

# %% [markdown]
# ### Exercise 7: GPA Calculator
# Create a function `calculate_gpa(grades)` that returns the average of the grades.
#
# **Requirement:** If the list is empty, return `0`.
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### التمرين 7: حساب المعدل
# أنشئ دالة `calculate_gpa(grades)` تعيد متوسط الدرجات.
#
# **شرط:** إذا كانت القائمة فارغة، أعد `0`.
#
# </div>
# </details>

# %%
# TODO: Exercise 7 - GPA calculator


# Test your function
# grades = [85, 90, 78, 92, 88]
# gpa = calculate_gpa(grades)
# print(f"GPA: {gpa:.2f}")

# %% [markdown]
# ---
#
# ## ⭐ Challenge Problems (Optional)
# Tackle these only after finishing the exercises.
#
# ### Challenge 1: Recursive Factorial
# Create a recursive function `factorial(n)`.
#
# **Reminder:** `factorial(5) = 5 * 4 * 3 * 2 * 1 = 120`
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## ⭐ مسائل التحدي (اختيارية)
# ابدأ بها بعد إنهاء التمارين الأساسية.
#
# ### التحدي 1: دالة العوامل (Factorial) بالاستدعاء الذاتي
# أنشئ دالة `factorial(n)` بطريقة تكرارية.
#
# **تذكير:** `factorial(5) = 5 * 4 * 3 * 2 * 1 = 120`
#
# </div>
# </details>

# %%
# TODO: Challenge 1 - Factorial recursive function


# Test your function
# print(factorial(5))
# print(factorial(0))

# %% [markdown]
# ### Challenge 2: Function Composition
# Create three functions:
# 1. `add(a, b)` - returns a + b
# 2. `multiply(a, b)` - returns a * b
# 3. `compute(x)` - uses the above functions: add(x, 5) then multiply result by 2
#
# Example: compute(3) should return (3+5)*2 = 16
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ### التحدي 2: تركيب الدوال
# أنشئ ثلاث دوال:
# 1. `add(a, b)` - تعيد a + b
# 2. `multiply(a, b)` - تعيد a * b
# 3. `compute(x)` - تستخدم الدالتين السابقتين: add(x, 5) ثم تضرب الناتج في 2
#
# مثال: ‎compute(3) يجب أن تعيد ‎(3+5)*2 = 16
#
# </div>
# </details>

# %%
# TODO: Challenge 2 - Function composition


# Test your functions
# print(compute(3))

# %% [markdown]
# ---
#
# ## 🎓 Lab 3 Summary
#
# You have successfully learned:
# - ✅ **Defining Functions** - Creating reusable blocks of code
# - ✅ **Parameters and Arguments** - Passing data to functions
# - ✅ **Return Values** - Getting results from functions
# - ✅ **Variable Scope** - Understanding where variables exist
# - ✅ **Default Parameters** - Making functions flexible
# - ✅ **Built-in Functions** - Using `len`, `min`, `max`, `sum`
# - ✅ **Docstrings** - Documenting your code
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ---
#
# ## 🎓 ملخص Lab 3
#
# لقد تعلمت بنجاح:
# - ✅ **تعريف الدوال** - إنشاء كتل من الكود قابلة لإعادة الاستخدام
# - ✅ **المعاملات والوسيطات** - تمرير البيانات إلى الدوال
# - ✅ **قيم الإرجاع** - الحصول على النتائج من الدوال
# - ✅ **نطاق المتغيرات** - فهم مكان وجود المتغيرات
# - ✅ **المعاملات الافتراضية** - جعل الدوال مرنة
# - ✅ **الدوال المدمجة** - استخدام `len` و `min` و `max` و `sum`
# - ✅ **السلاسل الموثقة** - توثيق الكود الخاص بك
#
# </div>
# </details>
