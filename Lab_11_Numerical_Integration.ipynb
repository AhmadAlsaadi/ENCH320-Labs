# %% [markdown]
# ## 📝 Important Instructions for Students
#
# ### Step 1: Make Your Own Copy
# When you open this notebook in Google Colab, you will be viewing a **read-only** version. To complete the assignments, you must:
#
# 1. Click **"File" → "Save a copy in Drive"** from the menu
# 2. This creates your personal copy in your Google Drive
# 3. Work on **your copy only** - all your answers will be saved there automatically
#
# ### Step 2: Rename Your Notebook
# After creating your copy, rename it to include your student ID:
#
# 1. Click on the notebook name at the top (currently "Copy of Lab_11_Numerical_Integration.ipynb")
# 2. Rename it to: **`Lab_11_Numerical_Integration_YourStudentID.ipynb`**
# 3. Example: `Lab_11_Numerical_Integration_12345678.ipynb`
#
# ### Step 3: Add Your Information right after these instructions
#
# ### Step 4: Share for Grading
# After completing all tasks, share your notebook with the instructor:
#
# 1. Click the **"Share"** button (top-right corner)
# 2. Enter instructor's email: **ahmad.alsaadi@kaust.edu.sa**
# 3. Set permission to **"Editor"**
# 4. Click **"Send"**
#
# **⚠️ Important:** Make sure to share **your copy** from Google Drive, not the original!
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## 📝 تعليمات مهمة للطلاب
#
# ### الخطوة 1: إنشاء نسخة خاصة بك
# عند فتح هذا الدفتر في Google Colab، ستشاهد نسخة **للقراءة فقط**. لإكمال المهام، يجب عليك:
#
# 1. انقر على **"File" ← "Save a copy in Drive"** من القائمة
# 2. سيتم إنشاء نسخة شخصية في Google Drive الخاص بك
# 3. اعمل على **نسختك فقط** - سيتم حفظ جميع إجاباتك تلقائياً
#
# ### الخطوة 2: إعادة تسمية الدفتر
# بعد إنشاء نسختك، قم بإعادة تسميتها لتتضمن رقم الطالب الخاص بك:
#
# 1. انقر على اسم الدفتر في الأعلى (حالياً "Copy of Lab_11_Numerical_Integration.ipynb")
# 2. أعد تسميته إلى: **`Lab_11_Numerical_Integration_رقم_الطالب.ipynb`**
# 3. مثال: `Lab_11_Numerical_Integration_12345678.ipynb`
#
# ### الخطوة 3: أضف معلوماتك مباشرة بعد هذه التعليمات
#
# ### الخطوة 4: المشاركة للتقييم
# بعد إكمال جميع المهام، شارك دفترك مع المدرس:
#
# 1. انقر على زر **"Share"** (في الزاوية العلوية اليمنى)
# 2. أدخل البريد الإلكتروني للمدرس: **ahmad.alsaadi@kaust.edu.sa**
# 3. اضبط الصلاحية على **"Editor"**
# 4. انقر على **"Send"**
#
# **⚠️ مهم:** تأكد من مشاركة **نسختك** من Google Drive، وليس النسخة الأصلية!
#
# </div>
#
# </details>

# %% [markdown]
# **Student Name:**
# **Student ID:**
# **Date:**

# %% [markdown]
# # Numerical Integration
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# # التكامل العددي
#
# </div>
# </details>

# %% [markdown]
# Numerical integration is a crucial technique in applied mathematics and computational science used to approximate the value of definite integrals. it refers to the methods for calculating the approximate value of integrals when they cannot be solved analytically. It  is widely used in various fields such as physics, engineering, statistics, and finance, where evaluating integrals is essential for modeling and analysis. It is particularly useful in cases where:
#
# - The function is complex or does not have a closed-form expression.
# - The function has singularities.
#
# The definite integral of a function $f(x)$ from `a` to `b` is given by:
# $$\int^b_a f(x)dx$$
# This represents the area under the curve $f(x)$ from $x=a$ to $x=b$.
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# التكامل العددي هو أسلوب حاسم في الرياضيات التطبيقية والعلوم الحسابية المستخدمة لتقريب قيمة التكاملات المحددة. يشير إلى طرق حساب القيمة التقريبية للتكاملات عندما لا يمكن حلها تحليليًا. يتم استخدامه على نطاق واسع في مجالات مختلفة مثل الفيزياء والهندسة والإحصاء والمالية، حيث يعد تقييم التكاملات أمرًا ضروريًا للنمذجة والتحليل. وهو مفيد بشكل خاص في الحالات التي:
#
# - الدالة معقدة أو لا تحتوي على تعبير مغلق.
# - الدالة لها فرديات.
#
# التكامل المحدد للدالة $f(x)$ من `a` إلى `b` يُعطى بواسطة:
# $$\int^b_a f(x)dx$$
# يمثل هذا المنطقة الواقعة أسفل المنحنى $f(x)$ من $x=a$ إلى $x=b$.
#
# </div>
# </details>

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ![image.png](attachment:image.png)
#
# </div>
# </details>

# %% [markdown]
# The goal of numerical integration is to find an approximate value `I` for the integral, often expressed as:
# $$I≈\int^b_a f(x)dx$$
# There are several methods to approximate the area under the curve which include:
# - Rectangle Method (curve approximation with constant function)
# - Trapezoidal Rule (curve approximation with linear function).
# - Simpson's Rule (curve approximation with 2nd order polynomial function).
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# الهدف من التكامل العددي هو إيجاد قيمة تقريبية `I` للتكامل، وغالبًا ما يتم التعبير عنها على النحو التالي:
# $$I≈\int^b_a f(x)dx$$
# هناك عدة طرق لتقريب المساحة تحت المنحنى منها:
# - طريقة المستطيل (تقريب المنحنى مع دالة ثابتة)
# - القاعدة شبه المنحرفة (تقريب المنحنى مع الدالة الخطية).
# - قاعدة سمبسون (تقريب المنحنى مع دالة متعددة الحدود من الرتبة الثانية).
#
# </div>
# </details>

# %% [markdown]
# ## Rectangle Method
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## طريقة المستطيل
#
# </div>
# </details>

# %% [markdown]
# The simplest method involves approximating the area under the curve using rectangles which includes the following steps:
# **Step one**: Divide the interval $[a,b]$ into $n$ equal subintervals of width $\Delta x=\frac{b-a}{n}$ which represent the widths of each rectangle you want to calculate its area.
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# تتضمن أبسط طريقة تقريب المساحة الموجودة أسفل المنحنى باستخدام المستطيلات والتي تتضمن الخطوات التالية:
# **الخطوة الأولى**: قسّم الفاصل الزمني $[a,b]$ إلى $n$ فترات فرعية متساوية بعرض $\Delta x=\frac{b-a}{n}$ والتي تمثل عرض كل مستطيل تريد حساب مساحته.
#
# </div>
# </details>

# %% [markdown]
# An interval is defined by two endpoints, say
# 𝑎 and 𝑏. For example, if 𝑎 = 0 and 𝑏 = 10, the interval is [0,10]. Decide how many equal parts (sub-intervals) you want to divide the interval into. Let’s call this number 𝑛. For example, if 𝑛 = 5, you will divide the interval into 5 equal parts. The width of each sub-interval, denoted as Δ𝑥, can be calculated using the formula:
# $$\Delta x =\frac{b-a}{n}$$
# For our example with
# 𝑎 = 0 and 𝑏 =10:
# $$\Delta x = \frac{10-0}{5}=2$$
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# يتم تعريف الفاصل الزمني بنقطتي نهاية، على سبيل المثال
# 𝑎 و𝑏. على سبيل المثال، إذا كان 𝑎 = 0 و𝑏 = 10، فإن الفترة الزمنية هي [0,10]. حدد عدد الأجزاء المتساوية (الفترات الفرعية) التي تريد تقسيم الفترة إليها. دعونا نسمي هذا العدد 𝑛‏. على سبيل المثال، إذا كان 𝑛 = 5، فسوف تقسم الفترة إلى خمسة أجزاء متساوية. يمكن حساب عرض كل فترة فرعية، يُشار إليها بـ Δ𝑥، باستخدام الصيغة:
# $$\Delta x =\frac{b-a}{n}$$
# على سبيل المثال لدينا مع
# 𝑎 = 0، 𝑏 =10:
# $$\Delta x = \frac{10-0}{5}=2$$
#
# </div>
# </details>

# %% [markdown]
# <center>
#
# ![image.png](attachment:image.png)
#
# </center>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <center>
#
# ![image.png](attachment:image.png)
#
# </center>
#
# </div>
# </details>

# %% [markdown]
# **Task 1**
# A. Write a function named `dx` that takes two endpoints 𝑎, 𝑏, and the number of sub-intervals 𝑛 as inputs, and returns the width of each sub-interval Δ𝑥?
# B. Test your function on dividing [10,30] into 10 sub-interval?
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 1**
# أ. اكتب دالة اسمها `dx` تأخذ نقطتي النهاية 𝑎 و𝑏 وعدد الفترات الفرعية 𝑛 كمدخلات، وترجع عرض كل فترة فرعية Δ𝑥؟
# ب. اختبر وظيفتك عند تقسيم [10,30] إلى 10 فترات فرعية؟
#
# </div>
# </details>

# %%
## write your code below for part A

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# def dx(a,b,n):
#     return (b-a)/n
# ```
# </details>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <details>
# <summary>انقر للكشف عن الإجابة</summary>
#
# ```python
# def dx(a,b,n):
#     return (b-a)/n
# ```
# </details>
#
# </div>
# </details>

# %%
## write your code below for Part B

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# dx(0,10,5)
# ```
# </details>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <details>
# <summary>انقر للكشف عن الإجابة</summary>
#
# ```python
# dx(0,10,5)
# ```
# </details>
#
# </div>
# </details>

# %% [markdown]
# **Step two**: Choose a sample point in each subinterval (left, middle, right).
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **الخطوة الثانية**: اختر نقطة عينة في كل فترة فرعية (يسار، وسط، يمين).
#
# </div>
# </details>

# %% [markdown]
# The endpoints of the sub-intervals can be found by starting at
# 𝑎 and adding Δ𝑥 repeatedly:
# - First sub-interval: [ 0 , 2]
# - Second sub-interval: [ 2 , 4]
# - Third sub-interval: [4 , 6]
# - Fourth sub-interval: [6 , 8]
# - Fifth sub-interval: [8 , 10]
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# يمكن العثور على نقاط النهاية للفترات الفرعية من خلال البدء بـ
# 𝑎 وإضافة Δ𝑥 بشكل متكرر:
# - الفاصل الفرعي الأول: [ 0 , 2]
# - الفاصل الفرعي الثاني: [ 2 , 4]
# - الفترة الفرعية الثالثة : [4 ، 6]
# - الفترة الفرعية الرابعة : [6 ، 8]
# - الفترة الفرعية الخامسة : [8 ، 10]
#
# </div>
# </details>

# %% [markdown]
# **Task 2**
# A. Write a function named sub_interval that generates sub-intervals given 𝑎 , 𝑏, and 𝑛?
# B. Test your function on the interval [10,30] with 10 intervals?
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ** المهمة 2 **
# أ. اكتب دالة اسمها sub_interval تولد فترات فرعية بمعلومية 𝑎 و 𝑏 و 𝑛؟
# ب. اختبر وظيفتك على الفترة [10،30] بـ 10 فترات؟
#
# </div>
# </details>

# %%
## write your code below for part A

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# def sub_interval(a,b,n):
#     width=(b-a)/n
#     sub_interval=[]
#     for i in range(n):
#         sub_interval.append([a+i*width,a+(i+1)*width])
#     return sub_interval
# ```
# </details>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <details>
# <summary>انقر للكشف عن الإجابة</summary>
#
# ```python
# def sub_interval(a,b,n):
#     width=(b-a)/n
#     sub_interval=[]
#     for i in range(n):
#         sub_interval.append([a+i*width,a+(i+1)*width])
#     return sub_interval
# ```
# </details>
#
# </div>
# </details>

# %%
## write your code below for part B

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# sub_interval(10,30,10)
# ```
# </details>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <details>
# <summary>انقر للكشف عن الإجابة</summary>
#
# ```python
# sub_interval(10,30,10)
# ```
# </details>
#
# </div>
# </details>

# %% [markdown]
# **Step three**: Calculate the height of each rectangle by calculating f(x) at a point in each interval.
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **الخطوة الثالثة**: احسب ارتفاع كل مستطيل عن طريق حساب f(x) عند نقطة في كل فاصل زمني.
#
# </div>
# </details>

# %% [markdown]
# Each rectangle has a width equal to a subinterval of the domain and a height equal to the function value at a specific point within that subinterval (could be taken as the left endpoint of the interval, the middle point or the right endpoint).
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# كل مستطيل له عرض يساوي فترة فرعية من المجال وارتفاع يساوي قيمة الدالة عند نقطة محددة داخل تلك الفترة الفرعية (يمكن اعتبارها نقطة النهاية اليسرى للفاصل الزمني، أو النقطة الوسطى أو نقطة النهاية اليمنى).
#
# </div>
# </details>

# %% [markdown]
# <div style="display:flex">
# <div width=33%>
#
# ![image.png](attachment:image.png)
#
# </div>
# <div width=33%>
#
# ![image-2.png](attachment:image-2.png)
#
# </div>
# <div width=33%>
#
# ![image-3.png](attachment:image-3.png)
#
# </div>
# </div>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <div style="display:flex">
# <div width=33%>
#
# ![image.png](attachment:image.png)
#
# </div>
# <div width=33%>
#
# ![image-2.png](attachment:image-2.png)
#
# </div>
# <div width=33%>
#
# ![image-3.png](attachment:image-3.png)
#
# </div>
# </div>
#
# </div>
# </details>

# %% [markdown]
# **task 3**
# A. write a python function named height that evaluate and return the value of a function f at one of three points within an interval [a,b] (at a or at b or at middle point of [a,b]). Use an optional parameter `point` that specify which point should the function be evaluate at.
# B. Test your function on $f(x)=x^2+2$ within the interval [0,3[?
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 3**
# A. اكتب دالة بايثون باسم height تقوم بتقييم وإرجاع قيمة الدالة f عند واحدة من ثلاث نقاط ضمن الفاصل الزمني [a,b] (عند a أو عند b أو عند النقطة الوسطى لـ [a,b]). استخدم معلمة اختيارية `point` تحدد النقطة التي يجب تقييم الدالة عندها.
# ب. اختبر وظيفتك على $f(x)=x^2+2$ خلال الفاصل الزمني [0,3[?
#
# </div>
# </details>

# %%
## write your code below for part A

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# def height(f,a,b,point="m"):
#     if point=="l":
#         return f(a)
#     elif point=="r":
#         return f(b)
#     else:
#         return f((a+b)/2)
# ```
# </details>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <details>
# <summary>انقر للكشف عن الإجابة</summary>
#
# ```python
# def height(f,a,b,point="m"):
#     if point=="l":
#         return f(a)
#     elif point=="r":
#         return f(b)
#     else:
#         return f((a+b)/2)
# ```
# </details>
#
# </div>
# </details>

# %%
## write your code below for part B.

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# height(lambda x:x**2+2,0,3)
# height(lambda x:x**2+2,0,3,point="l")
# height(lambda x:x**2+2,0,3,point="r")
# ```
# </details>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <details>
# <summary>انقر للكشف عن الإجابة</summary>
#
# ```python
# height(lambda x:x**2+2,0,3)
# height(lambda x:x**2+2,0,3,point="l")
# height(lambda x:x**2+2,0,3,point="r")
# ```
# </details>
#
# </div>
# </details>

# %% [markdown]
# **Step four**: Calculate the area of each rectangle and sum them up to find the approximate area under the curve from `a` to `b`.
#
# Since the width is the same for all rectangles which equal the width of the sub-nterval and the height is constant within its sub-interval when approximate the area under the curve as:
# $$\sum^n_{i=1}\Delta x.RH_i=\Delta x(RH_1+RH_2+RH_3+\cdots+RH_n)$$
#
# where,
# RH is the hight of the rectangle in each sub-interval.
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **الخطوة الرابعة**: احسب مساحة كل مستطيل واجمعها لإيجاد المساحة التقريبية أسفل المنحنى من `a` إلى `b`.
#
# حيث أن العرض هو نفسه لجميع المستطيلات التي تساوي عرض الفترة الفرعية ويكون الارتفاع ثابتًا ضمن الفترة الفرعية الخاصة بها عند تقريب المساحة تحت المنحنى على النحو التالي:
# $$\sum^n_{i=1}\Delta x.RH_i=\Delta x(RH_1+RH_2+RH_3+\cdots+RH_n)$$
#
# أين،
# RH هو ارتفاع المستطيل في كل فترة فرعية.
#
# </div>
# </details>

# %% [markdown]
# **Task 4**
# A. Write a python function named rect_method which implement the numerical integration with rectangle method?
# B. Use SymPy to calculate integral of $f(x)=x^2+2$ on the interval [0,5]?
# C. Use your function that you created in part A to calculate the integral of the same function in part B?
# D. Vary the point parameter in your function and find which point option would give better result?
# E. Vary the number of sub-interval and see how this variation would affect the accuracy of the result?
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ** المهمة 4 **
# أ. اكتب دالة بايثون باسم rect_method والتي تنفذ التكامل العددي مع طريقة المستطيل؟
# ب. استخدم SymPy لحساب تكامل $f(x)=x^2+2$ في الفاصل الزمني [0,5]؟
# ج. استخدم وظيفتك التي قمت بإنشائها في الجزء أ لحساب تكامل نفس الدالة في الجزء ب؟
# د. قم بتغيير معلمة النقطة في وظيفتك وابحث عن خيار النقطة الذي سيعطي نتيجة أفضل؟
# هـ. قم بتغيير عدد الفترات الفرعية وانظر كيف سيؤثر هذا الاختلاف على دقة النتيجة؟
#
# </div>
# </details>

# %%
## write your code below for part A

# %%
## write your code below for part B

# %%
## write your code below for part C

# %%
## write your code below for part D

# %%
## write your code below for part E

# %% [markdown]
# **Task 5**
# Write a function that use Numpy to do the same task that you did in task 4?
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 5**
# اكتب دالة تستخدم Numpy للقيام بنفس المهمة التي قمت بها في المهمة 4؟
#
# </div>
# </details>

# %%
## write your code below

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# import numpy as np
# def rect_np(f,a,b,n,point="m"):
#     x,dx=np.linspace(a,b,n+1,retstep=True)
#     if point=="l":
#         return dx*np.sum(f(x[:-1]))
#     elif point=="r":
#         return dx*np.sum(f(x[1:]))
#     return dx*np.sum(f((x[:-1]+x[1:])/2))
# rect_np(lambda x: x**2+2,0,5,1000,"m")
# ```
# </details>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <details>
# <summary>انقر للكشف عن الإجابة</summary>
#
# ```python
# import numpy as np
# def rect_np(f,a,b,n,point="m"):
#     x,dx=np.linspace(a,b,n+1,retstep=True)
#     if point=="l":
#         return dx*np.sum(f(x[:-1]))
#     elif point=="r":
#         return dx*np.sum(f(x[1:]))
#     return dx*np.sum(f((x[:-1]+x[1:])/2))
# rect_np(lambda x: x**2+2,0,5,1000,"m")
# ```
# </details>
#
# </div>
# </details>

# %% [markdown]
# ## Trapezoidal Rule
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## القاعدة شبه المنحرفة
#
# </div>
# </details>

# %% [markdown]
# The trapezoidal rule approximates the area under a curve by dividing it into trapezoids rather than rectangles.For a function
# 𝑓(𝑥) defined on the interval [𝑎,𝑏], the trapezoidal rule can be expressed as:
# $$I≈∫_a^bf(x)dx=\frac{b-a}{2}(f(a)-f(b))$$
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# تعمل قاعدة شبه المنحرف على تقريب المساحة الموجودة أسفل المنحنى عن طريق تقسيمها إلى شبه منحرف بدلاً من مستطيلات.للدالة
# 𝑓(𝑥) المعرفة في الفترة [𝑎,𝑏]، يمكن التعبير عن قاعدة شبه المنحرف على النحو التالي:
# $$I≈∫_a^bf(x)dx=\frac{b-a}{2}(f(a)-f(b))$$
#
# </div>
# </details>

# %% [markdown]
# <div>
# <center>
# <div width=40%>
#
# ![image.png](attachment:image.png)
#
# </div>
# </div>
# <br>
# This formula represents the area of a single trapezoid formed by the endpoints 𝑎 and 𝑏 of the interval.
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <div>
# <center>
# <div width=40%>
#
# ![image.png](attachment:image.png)
#
# </div>
# </div>
# <br>
# تمثل هذه الصيغة مساحة شبه منحرف واحد يتكون من نقطتي النهاية 𝑎 و𝑏 في الفترة.
#
# </div>
# </details>

# %% [markdown]
# The area 𝐴 of a trapezoid can be calculated using the formula:
# $$A=\frac{1}{2}(b_1+b_2)\cdot h$$
# where $b_1$ and $b_2$ are the lengths of the two parallel sides (bases) and h is the height. For the trapezoid formed by $f(a)$ and $f(b)$:
# - **Bases**: $b_1=f(a)$  and $b_2=f(a)$
# - **Height**: $h = b-a$
#
# Thus, the area of the trapezoid is:
# $$A=\frac{1}{2}(f(a)+f(b))\cdot (b-a)$$
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# يمكن حساب مساحة 𝐴 لشبه المنحرف باستخدام الصيغة:
# $$A=\frac{1}{2}(b_1+b_2)\cdot h$$
# حيث $b_1$ و$b_2$ هما طولا الضلعين المتوازيين (القاعدتين) وh هو الارتفاع. بالنسبة لشبه المنحرف المكون من $f(a)$ و$f(b)$:
# - **القواعد**: $b_1=f(a)$ و$b_2=f(a)$
# - **الارتفاع**: $h = b-a$
#
# وبالتالي فإن مساحة شبه المنحرف هي:
# $$A=\frac{1}{2}(f(a)+f(b))\cdot (b-a)$$
#
# </div>
# </details>

# %% [markdown]
# For each subinterval $[x_i,x_{i+1}]$ where $x_i=a+i\Delta x$ (for $i=0,1,2,\cdots,n$) the trapezoidal rule can be applied:
# $$I≈\sum_{i=0}^{n-1}\frac{1}{2}(f(x_i)+f(x_{i+1}))\Delta x$$
#
# The final approximation for the integral over
# [𝑎,𝑏] becomes:
# $$I≈\frac{\Delta x}{2}\Bigg( f(a)+2\sum_{i=1}^{n-1}f(x_i)+f(b)\Bigg)$$
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لكل فترة فرعية $[x_i,x_{i+1}]$ حيث $x_i=a+i\Delta x$ (لـ $i=0,1,2,\cdots,n$) يمكن تطبيق القاعدة شبه المنحرفة:
# $$I≈\sum_{i=0}^{n-1}\frac{1}{2}(f(x_i)+f(x_{i+1}))\Delta x$$
#
# التقريب النهائي للتكامل
# يصبح [𝑎,𝑏]:
# $$I≈\frac{\Delta x}{2}\Bigg( f(a)+2\sum_{i=1}^{n-1}f(x_i)+f(b)\Bigg)$$
#
# </div>
# </details>

# %% [markdown]
# <div>
# <center>
# <div width=50%>
#
# ![image.png](attachment:image.png)
#
# </div>
# </div>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <div>
# <center>
# <div width=50%>
#
# ![image.png](attachment:image.png)
#
# </div>
# </div>
#
# </div>
# </details>

# %% [markdown]
# **Task 6**
# A. Write python function named trapezoid that implement numerical integration with trapezoidal rule?
# B. Use your function that you created in part A to calculate the integral of $f(x)=x^2+2$ on the interval [0,5]?
# C. Vary the number of sub-interval and see how this variation would affect the accuracy of the result?
# D. Compare your function result with the function that you created in task 5?
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ** المهمة 6 **
# أ. اكتب دالة بايثون باسم شبه منحرف تنفذ التكامل العددي مع قاعدة شبه منحرف؟
# ب. استخدم وظيفتك التي قمت بإنشائها في الجزء أ لحساب تكامل $f(x)=x^2+2$ في الفترة [0,5]؟
# ج. قم بتغيير عدد الفترات الفرعية وانظر كيف سيؤثر هذا الاختلاف على دقة النتيجة؟
# د. قارن نتيجة وظيفتك بالدالة التي قمت بإنشائها في المهمة 5؟
#
# </div>
# </details>

# %%
## write your code below for part A

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# def trapezoid(f,a,b,n):
#     w=(b-a)/n
#     total_h = f(a)/2 + f(b)/2
#     for i in range(1,n):
#         total_h += f(a+w*i)
#     return total_h*w
# ```
# </details>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <details>
# <summary>انقر للكشف عن الإجابة</summary>
#
# ```python
# def trapezoid(f,a,b,n):
#     w=(b-a)/n
#     total_h = f(a)/2 + f(b)/2
#     for i in range(1,n):
#         total_h += f(a+w*i)
#     return total_h*w
# ```
# </details>
#
# </div>
# </details>

# %%
## write your code below for part B

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# trapezoid(lambda x:x**2+2,0,5,100)
# ```
# </details>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <details>
# <summary>انقر للكشف عن الإجابة</summary>
#
# ```python
# trapezoid(lambda x:x**2+2,0,5,100)
# ```
# </details>
#
# </div>
# </details>

# %%
## write your code below for part C

# %%
## write your code below for part D

# %% [markdown]
# **Task 7**
# A. write python function named np_trapezoid that use Numpy array to do the numerical integration with trapezoidal rule?
# B. Test your function on the function of task 6 part B?
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ** المهمة 7 **
# أ. اكتب دالة بايثون باسم np_trapezoid والتي تستخدم مصفوفة Numpy للقيام بالتكامل العددي مع قاعدة شبه منحرف؟
# ب. اختبر وظيفتك في دالة المهمة 6 الجزء ب؟
#
# </div>
# </details>

# %%
## write your code below for part A

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# import numpy as np
# def np_trapezoid(f,a,b,n):
#     x,dx=np.linspace(a,b,n+1,retstep=True)
#     return dx*np.sum(np.concatenate([f(x[1:-1]),f(x[[0,-1]])/2]))
# ```
# </details>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <details>
# <summary>انقر للكشف عن الإجابة</summary>
#
# ```python
# import numpy as np
# def np_trapezoid(f,a,b,n):
#     x,dx=np.linspace(a,b,n+1,retstep=True)
#     return dx*np.sum(np.concatenate([f(x[1:-1]),f(x[[0,-1]])/2]))
# ```
# </details>
#
# </div>
# </details>

# %%
## write your code below for part B

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# np_trapezoid(lambda x:x**2+2,0,5,100)
# ```
# </details>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <details>
# <summary>انقر للكشف عن الإجابة</summary>
#
# ```python
# np_trapezoid(lambda x:x**2+2,0,5,100)
# ```
# </details>
#
# </div>
# </details>

# %% [markdown]
# ## Simpson's Rule 1/3
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ## قاعدة سيمبسون 1/3
#
# </div>
# </details>

# %% [markdown]
# Simpson's Rule approximates the integral of a function by fitting parabolas to segments of the function. The $\frac{1}{3}$ version specifically applies when the interval is divided into an even number of subintervals. For a function $f(x)$ defined on the interval [a,b], Simpson's Rule can be expressed as:
# $$I≈\int^b_a f(x)dx≈\frac{w}{3}\Bigg(f(a)+4f(\frac{a+b}{2})+f(b)\Bigg)$$
#
# To approximate the area under the curve by a single parabola passing through the points $(a,f(a)),(b,f(b)),(\frac{a+b}{2},f(\frac{a+b}{2}))$ we will divide [a,b] into two subinterval, $w=\frac{b-a}{n}$ where n=2, thus:
# $$I≈\int^b_a f(x)dx≈\frac{b-a}{6}\Bigg(f(a)+4f(\frac{a+b}{2})+f(b)\Bigg)$$
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# تعمل قاعدة سمبسون على تقريب تكامل الدالة عن طريق تركيب القطع المكافئة على أجزاء من الدالة. ينطبق الإصدار $\frac{1}{3}$ بشكل خاص عندما يتم تقسيم الفاصل الزمني إلى عدد زوجي من الفترات الفرعية. بالنسبة للدالة $f(x)$ المحددة في الفاصل الزمني [a,b]، يمكن التعبير عن قاعدة Simpson على النحو التالي:
# $$I≈\int^b_a f(x)dx≈\frac{w}{3}\Bigg(f(a)+4f(\frac{a+b}{2})+f(b)\Bigg)$$
#
# لتقريب المساحة أسفل المنحنى بواسطة قطع مكافئ واحد يمر عبر النقاط $(a,f(a)),(b,f(b)),(\frac{a+b}{2},f(\frac{a+b}{2}))$ سنقسم [a,b] إلى فترتين فرعيتين، $w=\frac{b-a}{n}$ حيث n=2، وبالتالي:
# $$I≈\int^b_a f(x)dx≈\frac{b-a}{6}\Bigg(f(a)+4f(\frac{a+b}{2})+f(b)\Bigg)$$
#
# </div>
# </details>

# %% [markdown]
# <div>
# <center>
#
# ![image.png](attachment:image.png)
#
# </div>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <div>
# <center>
#
# ![image.png](attachment:image.png)
#
# </div>
#
# </div>
# </details>

# %% [markdown]
# To improve accuracy, divide the interval [a,b] into n subintervals, where n is an even number. The width of each subinterval is:
# $$w=\frac{b-a}{n}$$
# - $x_0=a$
# - $x_0=a+w$
# - $x_0=a+2w$
# - $\cdots$
# - $x_n=b$
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# لتحسين الدقة، قم بتقسيم الفاصل الزمني [a,b] إلى n فترات فرعية، حيث n هو رقم زوجي. عرض كل فترة فرعية هو:
# $$w=\frac{b-a}{n}$$
# - $x_0=a$
# - $x_0=a+w$
# - $x_0=a+2w$
# - $\cdots$
# - $x_n=b$
#
# </div>
# </details>

# %% [markdown]
# <div>
# <center>
# <div width=40%>
#
# ![image.png](attachment:image.png)
#
# </div>
# </div>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <div>
# <center>
# <div width=40%>
#
# ![image.png](attachment:image.png)
#
# </div>
# </div>
#
# </div>
# </details>

# %% [markdown]
# Applying Simpson's rule for each pair of subintervals (three poin) will give:
# $$I≈\frac{w}{3}\Bigg( f(x_0)+4f(x_1)+2f(x_2)+4f(f(x_3)+2f(x_4)+\cdots+f(x_n)\Bigg)$$
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# سيؤدي تطبيق قاعدة سيمبسون لكل زوج من الفترات الفرعية (ثلاث نقاط) إلى الحصول على:
# $$I≈\frac{w}{3}\Bigg( f(x_0)+4f(x_1)+2f(x_2)+4f(f(x_3)+2f(x_4)+\cdots+f(x_n)\Bigg)$$
#
# </div>
# </details>

# %% [markdown]
# The final approximation for the integral over [a,b] becomes:
# $$I≈\frac{w}{3}\Bigg(f(a) + 4\sum_{i=1,odd}^{n-1}f(x_i)+ 2\sum_{i=2,even}^{n-2}f(x_i)+f(b)\Bigg)$$
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# يصبح التقريب النهائي للتكامل على [a,b]:
# $$I≈\frac{w}{3}\Bigg(f(a) + 4\sum_{i=1,odd}^{n-1}f(x_i)+ 2\sum_{i=2,even}^{n-2}f(x_i)+f(b)\Bigg)$$
#
# </div>
# </details>

# %% [markdown]
# **Task 8**
# A. Write python function named simpson3 that implement numerical integration with Simpson's 1/3 rule?
# B. Use your function that you created in part A to calculate the integral of $f(x)=x^2+2$ on the interval [0,5]?
# C. Vary the number of sub-interval and see how this variation would affect the accuracy of the result?
# D. Compare your function result with the functions that you created in task 5 and 6?
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ** المهمة 8 **
# أ. اكتب دالة بايثون باسم simpson3 تنفذ التكامل العددي مع قاعدة سيمبسون 1/3؟
# ب. استخدم وظيفتك التي قمت بإنشائها في الجزء أ لحساب تكامل $f(x)=x^2+2$ في الفترة [0,5]؟
# ج. قم بتغيير عدد الفترات الفرعية وانظر كيف سيؤثر هذا الاختلاف على دقة النتيجة؟
# د. قارن نتيجة وظيفتك بالدوال التي قمت بإنشائها في المهمة 5 و6؟
#
# </div>
# </details>

# %%
## write your code below for part A

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# def simpson3(f,a,b,n):
#     w=(b-a)/n
#     total_h = f(a) + f(b)
#     for i in range(1,n,2): total_h += 4 * f(a+w*i)
#     for j in range(2,n-1,2):total_h += 2 * f(a+w*j)
#     return w*total_h/3
# ```
# </details>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <details>
# <summary>انقر للكشف عن الإجابة</summary>
#
# ```python
# def simpson3(f,a,b,n):
#     w=(b-a)/n
#     total_h = f(a) + f(b)
#     for i in range(1,n,2): total_h += 4 * f(a+w*i)
#     for j in range(2,n-1,2):total_h += 2 * f(a+w*j)
#     return w*total_h/3
# ```
# </details>
#
# </div>
# </details>

# %%
## write your code below for part B

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# simpson3(lambda x:x**2+2,0,5,100)
# ```
# </details>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <details>
# <summary>انقر للكشف عن الإجابة</summary>
#
# ```python
# simpson3(lambda x:x**2+2,0,5,100)
# ```
# </details>
#
# </div>
# </details>

# %%
## write your code below for part C

# %%
## write your code below for part D

# %% [markdown]
# **Task 9**
# A. write python function named np_simpson3 that use Numpy array to do the numerical integration with simpson 1/3 rule?
# B. Test your function on the function of task 8 part B?
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 9**
# أ. اكتب دالة بايثون باسم np_simpson3 التي تستخدم مجموعة Numpy للقيام بالتكامل العددي مع قاعدة simpson 1/3؟
# ب. اختبر وظيفتك في دالة المهمة 8 الجزء ب؟
#
# </div>
# </details>

# %%
## write your code below for part A

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# import numpy as np
# def np_simpson3(f,a,b,n):
#     x,dx=np.linspace(a,b,n+1,retstep=True)
#     return dx/3*np.sum(np.concatenate([4*f(x[1:-1:2]),2*f(x[2:-2:2]),f(x[[0,-1]])]))
# np_simpson(lambda x: x**2+2,0,5,100)
# ```
# </details>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <details>
# <summary>انقر للكشف عن الإجابة</summary>
#
# ```python
# import numpy as np
# def np_simpson3(f,a,b,n):
#     x,dx=np.linspace(a,b,n+1,retstep=True)
#     return dx/3*np.sum(np.concatenate([4*f(x[1:-1:2]),2*f(x[2:-2:2]),f(x[[0,-1]])]))
# np_simpson(lambda x: x**2+2,0,5,100)
# ```
# </details>
#
# </div>
# </details>

# %%
## write your code below for part b

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# np_simpson3(lambda x:x**2+2,0,5,100)
# ```
# </details>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <details>
# <summary>انقر للكشف عن الإجابة</summary>
#
# ```python
# np_simpson3(lambda x:x**2+2,0,5,100)
# ```
# </details>
#
# </div>
# </details>

# %% [markdown]
# **Task 10**
# Use the `trapezoid()` function in Scipy library to approximate the integral of $f(x)=x^2+2$ on the interval [0,5]?
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# ** المهمة 10 **
# استخدم الدالة `trapezoid()` في مكتبة Scipy لتقريب تكامل $f(x)=x^2+2$ على الفاصل الزمني [0,5]؟
#
# </div>
# </details>

# %%
## write your code below

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# import numpy as np
# from scipy.integrate import trapezoid
# x=np.linspace(0,5,100)
# y=x**2+2
# trapezoid(y,x)
# ```
# </details>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <details>
# <summary>انقر للكشف عن الإجابة</summary>
#
# ```python
# import numpy as np
# from scipy.integrate import trapezoid
# x=np.linspace(0,5,100)
# y=x**2+2
# trapezoid(y,x)
# ```
# </details>
#
# </div>
# </details>

# %% [markdown]
# **Task 11**
# Use the `simpson()` function in Scipy library to approximate the integral of $f(x)=x^2+2$ on the interval [0,5]?
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# **المهمة 11**
# استخدم الدالة `simpson()` في مكتبة Scipy لتقريب تكامل $f(x)=x^2+2$ على الفاصل الزمني [0,5]؟
#
# </div>
# </details>

# %%
## write your code below

# %% [markdown]
# <details>
# <summary>Click to reveal answer</summary>
#
# ```python
# import numpy as np
# from scipy.integrate import simpson
# x=np.linspace(0,5,100)
# y=x**2+2
# simpson(y=y,x=x)
# ```
# </details>
#
# ---
#
# <details>
# <summary style="cursor: pointer; color: #667EEA; font-weight: bold; font-size: 14px; font-family: 'Amiri', serif;">🌍 Arabic Translation / الترجمة العربية</summary>
#
# <div dir="rtl" style="text-align: right; margin-top: 10px; padding: 15px; background: linear-gradient(135deg, #F5F5F5 0%, #FAFAFA 100%); border-radius: 8px; border-right: 4px solid #667EEA; font-family: 'Amiri', serif; font-size: 16px; line-height: 1.8;">
#
# <link href="https://fonts.googleapis.com/css2?family=Amiri:wght@400;700&display=swap" rel="stylesheet">
#
# <details>
# <summary>انقر للكشف عن الإجابة</summary>
#
# ```python
# import numpy as np
# from scipy.integrate import simpson
# x=np.linspace(0,5,100)
# y=x**2+2
# simpson(y=y,x=x)
# ```
# </details>
#
# </div>
# </details>
